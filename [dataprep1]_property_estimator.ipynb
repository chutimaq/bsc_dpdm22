# %% [markdown]
# <a href="https://colab.research.google.com/github/chutimaq/bsc_dpdm22/blob/main/%5Bdataprep1%5D_property_estimator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#เชื่อม google drive 
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd

# %%
home= pd.read_excel('/content/gdrive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='บ้าน')
home.head(3)
# Out:
#    ID ผู้ประเมิน                             post id property_type  \
# 0              1  https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 1              2  https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2              1  https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ   2700000.0            2500000.0
# 1                        มั่นใจ   2700000.0            2700000.0
# 2                        มั่นใจ   2600000.0            2200000.0
#
#                       ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0                                       5,000-15,000
# 1  โครงการนี้ราคาเสนอขาย 2,500,000-3,000,000 บาท/...
# 2                                       5,000-15,000
#
#   เหตุผลไม่มั่นใจราคาประเมิน                      ให้คะแนนทรัพย์  Unnamed: 9  \
# 0                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# ...

# %%
home = home[['ID ผู้ประเมิน','ความมั่นใจในการเมินราคาทรัพย์','ประเมินราคาซื้อ-ขาย','ให้คะแนนทรัพย์']]
home
# Out:
#      ID ผู้ประเมิน ความมั่นใจในการเมินราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                1                        มั่นใจ            2500000.0
# 1                2                        มั่นใจ            2700000.0
# 2                1                        มั่นใจ            2200000.0
# 3                2                        มั่นใจ            2400000.0
# 4                1                        มั่นใจ            5000000.0
# ..             ...                           ...                  ...
# 185              2                        มั่นใจ            5000000.0
# 186              2                        มั่นใจ            7400000.0
# 187              2                        มั่นใจ            2500000.0
# 188              2                        มั่นใจ            3900000.0
# 189              2                        มั่นใจ            1400000.0
#
#                          ให้คะแนนทรัพย์
# 0     3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 1      4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน
# ...

# %%
ass1 = home[home['ID ผู้ประเมิน']==1]
ass1.head(3)
# Out:
#    ID ผู้ประเมิน ความมั่นใจในการเมินราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0              1                        มั่นใจ            2500000.0
# 2              1                        มั่นใจ            2200000.0
# 4              1                        มั่นใจ            5000000.0
#
#                        ให้คะแนนทรัพย์
# 0   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 2  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 4   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน

# %%
ass1.describe()
# Out:
#        ID ผู้ประเมิน  ประเมินราคาซื้อ-ขาย
# count          100.0         1.000000e+02
# mean             1.0         3.938500e+06
# std              0.0         2.368553e+06
# min              1.0         6.000000e+05
# 25%              1.0         2.775000e+06
# 50%              1.0         3.600000e+06
# 75%              1.0         4.500000e+06
# max              1.0         1.600000e+07

# %%
ass1['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ    100
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %%
ass1['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี    54
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     43
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน       2
# 1 ขายไม่ได้แน่นอน                      1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %%
ass2 = home[home['ID ผู้ประเมิน']==2]
ass2.head(3)
# Out:
#    ID ผู้ประเมิน ความมั่นใจในการเมินราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1              2                        มั่นใจ            2700000.0
# 3              2                        มั่นใจ            2400000.0
# 5              2                        มั่นใจ            9000000.0
#
#                       ให้คะแนนทรัพย์
# 1   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน
# 3  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 5  5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน

# %%
ass2.describe()
# Out:
#        ID ผู้ประเมิน  ประเมินราคาซื้อ-ขาย
# count           90.0         8.900000e+01
# mean             2.0         4.153258e+06
# std              0.0         2.386901e+06
# min              2.0         9.900000e+05
# 25%              2.0         2.600000e+06
# 50%              2.0         3.900000e+06
# 75%              2.0         4.900000e+06
# max              2.0         1.700000e+07

# %%
ass2['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ       89
# ไม่มั่นใจ     1
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %%
ass2['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     64
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน      23
# 5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน      1
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี     1
# Name: ให้คะแนนทรัพย์, dtype: int64
