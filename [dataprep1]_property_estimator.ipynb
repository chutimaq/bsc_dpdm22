# %% [markdown]
# <a href="https://colab.research.google.com/github/chutimaq/bsc_dpdm22/blob/main/%5Bdataprep1%5D_property_estimator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#เชื่อม google drive 
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

# %% [markdown]
# #สรุปข้อมูลของนักประเมินแต่ละคน โดยพิจารณาจาก ความมั่นใจในการประเมิน ประเมินราคาซื้อ-ขาย ให้คะแนนทรัพย์

# %%
home= pd.read_excel('/content/gdrive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='บ้าน')
home.head(3)
# Out:
#    ID ผู้ประเมิน                             post id property_type  \
# 0              1  https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 1              2  https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2              1  https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ   2700000.0            2500000.0
# 1                        มั่นใจ   2700000.0            2700000.0
# 2                        มั่นใจ   2600000.0            2200000.0
#
#                       ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0                                       5,000-15,000
# 1  โครงการนี้ราคาเสนอขาย 2,500,000-3,000,000 บาท/...
# 2                                       5,000-15,000
#
#   เหตุผลไม่มั่นใจราคาประเมิน                      ให้คะแนนทรัพย์  Unnamed: 9  \
# 0                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 1                        NaN    4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         NaN
# 2                        NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         NaN
#
#    Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# 0          NaN          NaN          NaN        100.0
# 1          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN

# %%
ass1 = home[home['ID ผู้ประเมิน']==1]
ass1.head(3)
# Out:
#    ID ผู้ประเมิน                              post id property_type  \
# 0              1   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2              1   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4              1  https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ   2700000.0            2500000.0
# 2                        มั่นใจ   2600000.0            2200000.0
# 4                        มั่นใจ   5900000.0            5000000.0
#
#   ปัจจัยในการประเมินราคาซื้อ-ขาย เหตุผลไม่มั่นใจราคาประเมิน  \
# 0                   5,000-15,000                        NaN
# 2                   5,000-15,000                        NaN
# 4                   5,000-15,000                        NaN
#
#                        ให้คะแนนทรัพย์  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 2  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         NaN          NaN          NaN
# 4   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
#
#    Unnamed: 12  Unnamed: 13
# 0          NaN        100.0
# 2          NaN          NaN
# 4          NaN          NaN

# %%
ass1.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  Unnamed: 9  \
# count          100.0  1.000000e+02         1.000000e+02         0.0
# mean             1.0  4.316360e+06         3.938500e+06         NaN
# std              0.0  2.865391e+06         2.368553e+06         NaN
# min              1.0  3.900000e+05         6.000000e+05         NaN
# 25%              1.0  2.892750e+06         2.775000e+06         NaN
# 50%              1.0  3.962000e+06         3.600000e+06         NaN
# 75%              1.0  5.000000e+06         4.500000e+06         NaN
# max              1.0  2.094900e+07         1.600000e+07         NaN
#
#        Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# count          0.0          0.0          0.0          1.0
# mean           NaN          NaN          NaN        100.0
# std            NaN          NaN          NaN          NaN
# min            NaN          NaN          NaN        100.0
# 25%            NaN          NaN          NaN        100.0
# 50%            NaN          NaN          NaN        100.0
# 75%            NaN          NaN          NaN        100.0
# max            NaN          NaN          NaN        100.0

# %%
ass1['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ    100
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %%
ass1['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี    54
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     43
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน       2
# 1 ขายไม่ได้แน่นอน                      1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %%
ass2 = home[home['ID ผู้ประเมิน']==2]
ass2.head(3)
# Out:
#    ID ผู้ประเมิน                              post id property_type  \
# 1              2   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3              2   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5              2  https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                        มั่นใจ   2700000.0            2700000.0
# 3                        มั่นใจ   2600000.0            2400000.0
# 5                        มั่นใจ   5900000.0            9000000.0
#
#                       ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 1  โครงการนี้ราคาเสนอขาย 2,500,000-3,000,000 บาท/...
# 3   ราคาเสนอขายประมาณ 2,200,000 - 2,500,000 บาท/หลัง
# 5  โซนนี้ราคาซื้อขาย ประมาณ 10,000-20,000 บาท/ตาร...
#
#   เหตุผลไม่มั่นใจราคาประเมิน                     ให้คะแนนทรัพย์  Unnamed: 9  \
# 1                        NaN   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         NaN
# 3                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 5                        NaN  5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน         NaN
#
#    Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# 1          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN
# 5          NaN          NaN          NaN          NaN

# %%
ass2.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  Unnamed: 9  \
# count           90.0  9.000000e+01         8.900000e+01         0.0
# mean             2.0  4.240733e+06         4.153258e+06         NaN
# std              0.0  2.714815e+06         2.386901e+06         NaN
# min              2.0  3.900000e+05         9.900000e+05         NaN
# 25%              2.0  2.860000e+06         2.600000e+06         NaN
# 50%              2.0  4.000000e+06         3.900000e+06         NaN
# 75%              2.0  5.000000e+06         4.900000e+06         NaN
# max              2.0  2.094900e+07         1.700000e+07         NaN
#
#        Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# count          0.0          0.0          0.0          0.0
# mean           NaN          NaN          NaN          NaN
# std            NaN          NaN          NaN          NaN
# min            NaN          NaN          NaN          NaN
# 25%            NaN          NaN          NaN          NaN
# 50%            NaN          NaN          NaN          NaN
# 75%            NaN          NaN          NaN          NaN
# max            NaN          NaN          NaN          NaN

# %%
ass2['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ       89
# ไม่มั่นใจ     1
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %%
ass2['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     64
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน      23
# 5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน      1
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี     1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %% [markdown]
# ##HW1 เปรียบเทียบความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของนักประเมินแต่ละคนและของราคาตั้งขาย ใช้ MAPE เป็นเกณฑ์ในการเปรียบเทียบ

# %% [markdown]
# ###Home

# %%
ass2['ประเมิน1'] = ass2['post id'].map(ass1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
ass2
# Out:
# <ipython-input-12-91656c2d09a1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ass2['ประเมิน1'] = ass2['post id'].map(ass1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5                2    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7                2    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9                2    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 185              2  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 186              2  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 187              2     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 188              2     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 189              2    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                          มั่นใจ   2700000.0            2700000.0
# 3                          มั่นใจ   2600000.0            2400000.0
# 5                          มั่นใจ   5900000.0            9000000.0
# 7                          มั่นใจ   4400000.0            3700000.0
# 9                          มั่นใจ   2750000.0            2500000.0
# ..                            ...         ...                  ...
# 185                        มั่นใจ   5500000.0            5000000.0
# 186                        มั่นใจ   7911000.0            7400000.0
# 187                        มั่นใจ   2000000.0            2500000.0
# 188                        มั่นใจ   4000000.0            3900000.0
# 189                        มั่นใจ   1375000.0            1400000.0
#
#                         ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 1    โครงการนี้ราคาเสนอขาย 2,500,000-3,000,000 บาท/...
# 3     ราคาเสนอขายประมาณ 2,200,000 - 2,500,000 บาท/หลัง
# 5    โซนนี้ราคาซื้อขาย ประมาณ 10,000-20,000 บาท/ตาร...
# 7               เสนอขาย 3,500,000 - 4,200,000 บาท/หลัง
# 9          ราคาเสนอขาย 2,000,0000 - 2,800,000 บาท/หลัง
# ..                                                 ...
# 185              ราคาเสนอขาย 20,000-30,000 บาท/ตารางวา
# 186            ราคาเสนอขาย 20,000 - 30,000 บาท/ตารางวา
# 187                   ราคาเสนอขาย 2.2-3.0 ล้านบาท/หลัง
# 188                    ราคาเสนอขาย 3.5-4.0ล้านบาท/หลัง
# 189                   ราคาเสนอขาย 1.2-1.5 ล้านบาท/หลัง
#
#     เหตุผลไม่มั่นใจราคาประเมิน                     ให้คะแนนทรัพย์  Unnamed: 9  \
# 1                          NaN   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         NaN
# 3                          NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 5                          NaN  5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน         NaN
# 7                          NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 9                          NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# ..                         ...                                ...         ...
# 185                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 186                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 187                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 188                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 189                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
#
#      Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13   ประเมิน1
# 1            NaN          NaN          NaN          NaN  2500000.0
# 3            NaN          NaN          NaN          NaN  2200000.0
# 5            NaN          NaN          NaN          NaN  5000000.0
# 7            NaN          NaN          NaN          NaN  3500000.0
# 9            NaN          NaN          NaN          NaN  2500000.0
# ..           ...          ...          ...          ...        ...
# 185          NaN          NaN          NaN          NaN  4500000.0
# 186          NaN          NaN          NaN          NaN  5200000.0
# 187          NaN          NaN          NaN          NaN  3600000.0
# 188          NaN          NaN          NaN          NaN  4000000.0
# 189          NaN          NaN          NaN          NaN  1200000.0
#
# [90 rows x 15 columns]

# %%
ass2['ประเมิน2'] = ass2['post id'].map(ass2.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
ass2
# Out:
# <ipython-input-13-0dca72d2c29e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ass2['ประเมิน2'] = ass2['post id'].map(ass2.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5                2    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7                2    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9                2    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 185              2  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 186              2  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 187              2     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 188              2     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 189              2    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                          มั่นใจ   2700000.0            2700000.0
# 3                          มั่นใจ   2600000.0            2400000.0
# 5                          มั่นใจ   5900000.0            9000000.0
# 7                          มั่นใจ   4400000.0            3700000.0
# 9                          มั่นใจ   2750000.0            2500000.0
# ..                            ...         ...                  ...
# 185                        มั่นใจ   5500000.0            5000000.0
# 186                        มั่นใจ   7911000.0            7400000.0
# 187                        มั่นใจ   2000000.0            2500000.0
# 188                        มั่นใจ   4000000.0            3900000.0
# 189                        มั่นใจ   1375000.0            1400000.0
#
#                         ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 1    โครงการนี้ราคาเสนอขาย 2,500,000-3,000,000 บาท/...
# 3     ราคาเสนอขายประมาณ 2,200,000 - 2,500,000 บาท/หลัง
# 5    โซนนี้ราคาซื้อขาย ประมาณ 10,000-20,000 บาท/ตาร...
# 7               เสนอขาย 3,500,000 - 4,200,000 บาท/หลัง
# 9          ราคาเสนอขาย 2,000,0000 - 2,800,000 บาท/หลัง
# ..                                                 ...
# 185              ราคาเสนอขาย 20,000-30,000 บาท/ตารางวา
# 186            ราคาเสนอขาย 20,000 - 30,000 บาท/ตารางวา
# 187                   ราคาเสนอขาย 2.2-3.0 ล้านบาท/หลัง
# 188                    ราคาเสนอขาย 3.5-4.0ล้านบาท/หลัง
# 189                   ราคาเสนอขาย 1.2-1.5 ล้านบาท/หลัง
#
#     เหตุผลไม่มั่นใจราคาประเมิน                     ให้คะแนนทรัพย์  Unnamed: 9  \
# 1                          NaN   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         NaN
# 3                          NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 5                          NaN  5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน         NaN
# 7                          NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 9                          NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# ..                         ...                                ...         ...
# 185                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 186                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 187                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 188                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 189                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
#
#      Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13   ประเมิน1   ประเมิน2
# 1            NaN          NaN          NaN          NaN  2500000.0  2700000.0
# 3            NaN          NaN          NaN          NaN  2200000.0  2400000.0
# 5            NaN          NaN          NaN          NaN  5000000.0  9000000.0
# 7            NaN          NaN          NaN          NaN  3500000.0  3700000.0
# 9            NaN          NaN          NaN          NaN  2500000.0  2500000.0
# ..           ...          ...          ...          ...        ...        ...
# 185          NaN          NaN          NaN          NaN  4500000.0  5000000.0
# 186          NaN          NaN          NaN          NaN  5200000.0  7400000.0
# 187          NaN          NaN          NaN          NaN  3600000.0  2500000.0
# 188          NaN          NaN          NaN          NaN  4000000.0  3900000.0
# 189          NaN          NaN          NaN          NaN  1200000.0  1400000.0
#
# [90 rows x 16 columns]

# %%
ht = ass2[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2']]
ht
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0  2500000.0  2700000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0  2200000.0  2400000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0  5000000.0  9000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0  3500000.0  3700000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0  2500000.0  2500000.0
# ..                                     ...         ...        ...        ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0  4500000.0  5000000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0  5200000.0  7400000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0  3600000.0  2500000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0  4000000.0  3900000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0  1200000.0  1400000.0
#
# [90 rows x 4 columns]

# %%
ht.isnull().any()
# Out:
# post id       False
# ราคาทรัพย์    False
# ประเมิน1      False
# ประเมิน2       True
# dtype: bool

# %%
ht = ht.fillna(value={'ประเมิน2':ass2['ประเมิน2'].mean()})
ht
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0  2500000.0  2700000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0  2200000.0  2400000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0  5000000.0  9000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0  3500000.0  3700000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0  2500000.0  2500000.0
# ..                                     ...         ...        ...        ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0  4500000.0  5000000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0  5200000.0  7400000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0  3600000.0  2500000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0  4000000.0  3900000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0  1200000.0  1400000.0
#
# [90 rows x 4 columns]

# %%
ht.isnull().any()
# Out:
# post id       False
# ราคาทรัพย์    False
# ประเมิน1      False
# ประเมิน2      False
# dtype: bool

# %% [markdown]
# #### MAPE

# %%
from sklearn.metrics import mean_absolute_percentage_error as mape

# %%
ac = ht['ราคาทรัพย์']
pr1 = ht['ประเมิน1']
pr2 = ht['ประเมิน2']

# %%
pred1 = mape(ac, pr1)
pred2 = mape(ac, pr2)
mape_h = mape(pr1,pr2)

# %%
print(f'ค่า MAPE ของผู้ประเมินคนที่ 1 เท่ากับ {pred1:.3f}\nค่า MAPE ของผู้ประเมินคนที่ 2 เท่ากับ {pred2:.3f}\nค่า MAPE ราคาตั้งขายของผู้ประเมินคนที่ 1 และ ผู้ประเมินคนที่ 2  เท่ากับ {mape_h:.3f}')
# Out:
# ค่า MAPE ของผู้ประเมินคนที่ 1 เท่ากับ 0.123
# ค่า MAPE ของผู้ประเมินคนที่ 2 เท่ากับ 0.105
# ค่า MAPE ราคาตั้งขายของผู้ประเมินคนที่ 1 และ ผู้ประเมินคนที่ 2  เท่ากับ 0.136

# %% [markdown]
# ### Land

# %%
land= pd.read_excel('/content/gdrive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='ที่ดิน')
land.head(3)
# Out:
#    ID ผู้ประเมิน                               post id property_type  \
# 0              1  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 1              2  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 2              4  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ     2800000            1800000.0
# 1                        มั่นใจ     2800000            2000000.0
# 2                        มั่นใจ     2800000            3000000.0
#
#           ปัจจัยในการประเมินราคาซื้อ-ขาย เหตุผลไม่มั่นใจราคาประเมิน  \
# 0                           8,000-25,000                        NaN
# 1  ราคาเสนอขาย 7,000-12,0000 บาท/ตารางวา                        NaN
# 2                            12000-18000                        NaN
#
#                        ให้คะแนนทรัพย์  Unnamed: 9  \
# 0   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         3.0
# 1  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         2.0
# 2   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         3.0
#
#                      Unnamed: 10  Unnamed: 11  Unnamed: 12
# 0  ขายได้ ใช้ระยะเวลา 7-12 เดือน          NaN        100.0
# 1   ขายได้ ใช้ระยะเวลา 4-6 เดือน          NaN          NaN
# 2  ขายได้ ใช้ระยะเวลา 7-12 เดือน          NaN          NaN

# %%
land['ID ผู้ประเมิน'].value_counts()
# Out:
# 1    100
# 2    100
# 4     10
# Name: ID ผู้ประเมิน, dtype: int64

# %%
ass1_l = land[land['ID ผู้ประเมิน']==1]

# %%
ass2_l = land[land['ID ผู้ประเมิน']==2]

# %%
ass2_l['ประเมิน1'] = ass2_l['post id'].map(ass1_l.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
ass2_l
# Out:
# <ipython-input-26-5595cb6c0e4a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ass2_l['ประเมิน1'] = ass2_l['post id'].map(ass1_l.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 4                2   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 7                2   https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 10               2   https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 13               2   https://nayoo.co/khonkaen/posts/1866        ที่ดิน
# ..             ...                                    ...           ...
# 200              2  https://nayoo.co/khonkaen/posts/14539        ที่ดิน
# 202              2  https://nayoo.co/khonkaen/posts/16072        ที่ดิน
# 204              2  https://nayoo.co/khonkaen/posts/17093        ที่ดิน
# 206              2  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 208              2  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                          มั่นใจ     2800000            2000000.0
# 4                          มั่นใจ    14900000           12000000.0
# 7                          มั่นใจ    90000000           70000000.0
# 10                         มั่นใจ    65000000           60000000.0
# 13                         มั่นใจ     3000000            2500000.0
# ..                            ...         ...                  ...
# 200                        มั่นใจ     5000000            4000000.0
# 202                        มั่นใจ      750000             750000.0
# 204                        มั่นใจ     2650000            2500000.0
# 206                        มั่นใจ     1300000            1500000.0
# 208                        มั่นใจ     3000000            2800000.0
#
#               ปัจจัยในการประเมินราคาซื้อ-ขาย เหตุผลไม่มั่นใจราคาประเมิน  \
# 1      ราคาเสนอขาย 7,000-12,0000 บาท/ตารางวา                        NaN
# 4    ราคาเสนอขาย 100,000-150,000 บาท/ตารางวา                        NaN
# 7                  30,000-40,000 บาท/ตารางวา                        NaN
# 10   ราคาเสนอขาย 12,000 - 15,000 บาท/ตารางวา                        NaN
# 13     ราคาเสนอขาย 2,000 - 4,000 บาท/ตารางวา                        NaN
# ..                                       ...                        ...
# 200   ราคาเสนอขาย 8,000 - 10,000 บาท/ตารางวา                        NaN
# 202      ราคาเสนอขาย 7,000-8,000 บาท/ตารางวา                        NaN
# 204    ราคาเสนอขาย 3,000 - 5,000 บาท/ตารางวา                        NaN
# 206    ราคาเสนอขาย 3,000 - 5,000 บาท/ตารางวา                        NaN
# 208  ราคาเสนอขาย 10,000 - 15,000 บาท/ตารางวา                        NaN
#
#                          ให้คะแนนทรัพย์  Unnamed: 9  \
# 1    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         2.0
# 4    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         2.0
# 7    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         2.0
# 10   2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         2.0
# 13    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         3.0
# ..                                  ...         ...
# 200  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         NaN
# 202   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 204  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         NaN
# 206   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 208  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         NaN
#
#                        Unnamed: 10  Unnamed: 11  Unnamed: 12    ประเมิน1
# 1     ขายได้ ใช้ระยะเวลา 4-6 เดือน          NaN          NaN   1800000.0
# 4     ขายได้ ใช้ระยะเวลา 4-6 เดือน          NaN          NaN   8000000.0
# 7     ขายได้ ใช้ระยะเวลา 4-6 เดือน          NaN          NaN  18000000.0
# 10    ขายได้ ใช้ระยะเวลา 4-6 เดือน          NaN          NaN  35000000.0
# 13   ขายได้ ใช้ระยะเวลา 7-12 เดือน          NaN          NaN   2200000.0
# ..                             ...          ...          ...         ...
# 200                            NaN          NaN          NaN   4000000.0
# 202                            NaN          NaN          NaN    500000.0
# 204                            NaN          NaN          NaN   2000000.0
# 206                            NaN          NaN          NaN   1500000.0
# 208                            NaN          NaN          NaN   2500000.0
#
# [100 rows x 14 columns]

# %%
ass2_l['ประเมิน2'] = ass2_l['post id'].map(ass2_l.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
ass2_l
# Out:
# <ipython-input-27-62c51c339074>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ass2_l['ประเมิน2'] = ass2_l['post id'].map(ass2_l.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 4                2   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 7                2   https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 10               2   https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 13               2   https://nayoo.co/khonkaen/posts/1866        ที่ดิน
# ..             ...                                    ...           ...
# 200              2  https://nayoo.co/khonkaen/posts/14539        ที่ดิน
# 202              2  https://nayoo.co/khonkaen/posts/16072        ที่ดิน
# 204              2  https://nayoo.co/khonkaen/posts/17093        ที่ดิน
# 206              2  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 208              2  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                          มั่นใจ     2800000            2000000.0
# 4                          มั่นใจ    14900000           12000000.0
# 7                          มั่นใจ    90000000           70000000.0
# 10                         มั่นใจ    65000000           60000000.0
# 13                         มั่นใจ     3000000            2500000.0
# ..                            ...         ...                  ...
# 200                        มั่นใจ     5000000            4000000.0
# 202                        มั่นใจ      750000             750000.0
# 204                        มั่นใจ     2650000            2500000.0
# 206                        มั่นใจ     1300000            1500000.0
# 208                        มั่นใจ     3000000            2800000.0
#
#               ปัจจัยในการประเมินราคาซื้อ-ขาย เหตุผลไม่มั่นใจราคาประเมิน  \
# 1      ราคาเสนอขาย 7,000-12,0000 บาท/ตารางวา                        NaN
# 4    ราคาเสนอขาย 100,000-150,000 บาท/ตารางวา                        NaN
# 7                  30,000-40,000 บาท/ตารางวา                        NaN
# 10   ราคาเสนอขาย 12,000 - 15,000 บาท/ตารางวา                        NaN
# 13     ราคาเสนอขาย 2,000 - 4,000 บาท/ตารางวา                        NaN
# ..                                       ...                        ...
# 200   ราคาเสนอขาย 8,000 - 10,000 บาท/ตารางวา                        NaN
# 202      ราคาเสนอขาย 7,000-8,000 บาท/ตารางวา                        NaN
# 204    ราคาเสนอขาย 3,000 - 5,000 บาท/ตารางวา                        NaN
# 206    ราคาเสนอขาย 3,000 - 5,000 บาท/ตารางวา                        NaN
# 208  ราคาเสนอขาย 10,000 - 15,000 บาท/ตารางวา                        NaN
#
#                          ให้คะแนนทรัพย์  Unnamed: 9  \
# 1    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         2.0
# 4    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         2.0
# 7    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         2.0
# 10   2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         2.0
# 13    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         3.0
# ..                                  ...         ...
# 200  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         NaN
# 202   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 204  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         NaN
# 206   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 208  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         NaN
#
#                        Unnamed: 10  Unnamed: 11  Unnamed: 12    ประเมิน1  \
# 1     ขายได้ ใช้ระยะเวลา 4-6 เดือน          NaN          NaN   1800000.0
# 4     ขายได้ ใช้ระยะเวลา 4-6 เดือน          NaN          NaN   8000000.0
# 7     ขายได้ ใช้ระยะเวลา 4-6 เดือน          NaN          NaN  18000000.0
# 10    ขายได้ ใช้ระยะเวลา 4-6 เดือน          NaN          NaN  35000000.0
# 13   ขายได้ ใช้ระยะเวลา 7-12 เดือน          NaN          NaN   2200000.0
# ..                             ...          ...          ...         ...
# 200                            NaN          NaN          NaN   4000000.0
# 202                            NaN          NaN          NaN    500000.0
# 204                            NaN          NaN          NaN   2000000.0
# 206                            NaN          NaN          NaN   1500000.0
# 208                            NaN          NaN          NaN   2500000.0
#
#        ประเมิน2
# 1     2000000.0
# 4    12000000.0
# 7    70000000.0
# 10   60000000.0
# 13    2500000.0
# ..          ...
# 200   4000000.0
# 202    750000.0
# 204   2500000.0
# 206   1500000.0
# 208   2800000.0
#
# [100 rows x 15 columns]

# %%
lt = ass2_l[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2']]
lt
# Out:
#                                    post id  ราคาทรัพย์    ประเมิน1    ประเมิน2
# 1     https://nayoo.co/khonkaen/posts/1033     2800000   1800000.0   2000000.0
# 4     https://nayoo.co/khonkaen/posts/1711    14900000   8000000.0  12000000.0
# 7     https://nayoo.co/khonkaen/posts/1726    90000000  18000000.0  70000000.0
# 10    https://nayoo.co/khonkaen/posts/1732    65000000  35000000.0  60000000.0
# 13    https://nayoo.co/khonkaen/posts/1866     3000000   2200000.0   2500000.0
# ..                                     ...         ...         ...         ...
# 200  https://nayoo.co/khonkaen/posts/14539     5000000   4000000.0   4000000.0
# 202  https://nayoo.co/khonkaen/posts/16072      750000    500000.0    750000.0
# 204  https://nayoo.co/khonkaen/posts/17093     2650000   2000000.0   2500000.0
# 206  https://nayoo.co/khonkaen/posts/17112     1300000   1500000.0   1500000.0
# 208  https://nayoo.co/khonkaen/posts/17145     3000000   2500000.0   2800000.0
#
# [100 rows x 4 columns]

# %%
lt.isnull().any()
# Out:
# post id       False
# ราคาทรัพย์    False
# ประเมิน1      False
# ประเมิน2      False
# dtype: bool

# %% [markdown]
# #### MAPE

# %%
ac_l = lt['ราคาทรัพย์']
pr1_l = lt['ประเมิน1']
pr2_l = lt['ประเมิน2']

# %%
pred1_l = mape(ac_l, pr1_l)
pred2_l = mape(ac_l, pr2_l)
mape_l = mape(pr1_l,pr2_l)

# %%
print(f'ค่า MAPE ของผู้ประเมินคนที่ 1 เท่ากับ {pred1_l:.3f}\nค่า MAPE ของผู้ประเมินคนที่ 2 เท่ากับ {pred2_l:.3f}\nค่า MAPE ราคาตั้งขายของผู้ประเมินคนที่ 1 และ ผู้ประเมินคนที่ 2  เท่ากับ {mape_l:.3f}')
# Out:
# ค่า MAPE ของผู้ประเมินคนที่ 1 เท่ากับ 0.413
# ค่า MAPE ของผู้ประเมินคนที่ 2 เท่ากับ 0.401
# ค่า MAPE ราคาตั้งขายของผู้ประเมินคนที่ 1 และ ผู้ประเมินคนที่ 2  เท่ากับ 0.741

# %% [markdown]
# ### Condo

# %%
condo= pd.read_excel('/content/gdrive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='คอนโด')
condo.head(3)
# Out:
#    ID ผู้ประเมิน  post id property_type ความมั่นใจในการเมินราคาทรัพย์  \
# 0              1     32.0         คอนโด                        มั่นใจ
# 1              1     36.0         คอนโด                        มั่นใจ
# 2              1    603.0         คอนโด                        มั่นใจ
#
#    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0   3500000.0            3500000.0   60,000-130,000 บาท/ตารางเมตร
# 1   1930000.0            2200000.0    50,000-90,000 บาท/ตารางเมตร
# 2   2438000.0            2800000.0    35,000-80,000 บาท/ตารางเมตร
#
#    เหตุผลไม่มั่นใจราคาประเมิน                    ให้คะแนนทรัพย์  Unnamed: 9  \
# 0                         NaN  4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         4.0
# 1                         NaN  4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         4.0
# 2                         NaN  4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         4.0
#
#                         Unnamed: 10
# 0  ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 1  ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 2  ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี

# %%
condo['ID ผู้ประเมิน'].value_counts()
# Out:
# 1    10
# Name: ID ผู้ประเมิน, dtype: int64

# %%
condo.rename(columns={'ประเมินราคาซื้อ-ขาย':'ประเมิน1'}, inplace=True)

# %%
ct = condo[['post id','ราคาทรัพย์','ประเมิน1']]
ct
# Out:
#    post id  ราคาทรัพย์   ประเมิน1
# 0     32.0   3500000.0  3500000.0
# 1     36.0   1930000.0  2200000.0
# 2    603.0   2438000.0  2800000.0
# 3   1395.0   1600000.0  2300000.0
# 4   1443.0   1860000.0  1800000.0
# 5   1609.0   1490000.0  1500000.0
# 6   1640.0   1280000.0  1600000.0
# 7   1641.0   4290000.0  2700000.0
# 8   1650.0   1700000.0  1550000.0
# 9   1840.0   3790000.0  2800000.0

# %% [markdown]
# #### MAPE

# %%
ac_c = ct['ราคาทรัพย์']
pr1_c = ct['ประเมิน1']
pred1_c = mape(ac_c,pr1_c)

# %%
print(f'ค่า MAPE ของผู้ประเมินคนที่ 1 เท่ากับ {pred1_c:.3f}')
# Out:
# ค่า MAPE ของผู้ประเมินคนที่ 1 เท่ากับ 0.173

# %% [markdown]
# ###Townhome

# %%
townhome= pd.read_excel('/content/gdrive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='ทาวน์โฮม')
townhome.head(3)
# Out:
#    ID ผู้ประเมิน                              post id property_type  \
# 0              1  https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 1              2  https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 2              1  https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ   1045000.0             700000.0
# 1                        มั่นใจ   1045000.0            1500000.0
# 2                        มั่นใจ    935000.0             700000.0
#
#   ปัจจัยในการประเมินราคาซื้อ-ขาย  เหตุผลไม่มั่นใจราคาประเมิน  \
# 0                   5,000-15,000                         NaN
# 1      ราคาซื้อขาย 1-2 ล้าน/คูหา                         NaN
# 2                   5,000-15,000                         NaN
#
#                        ให้คะแนนทรัพย์  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         NaN          NaN          NaN
# 1                   1 ขายไม่ได้แน่นอน         NaN          NaN          NaN
# 2  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         NaN          NaN          NaN
#
#    Unnamed: 12
# 0        120.0
# 1          NaN
# 2          NaN

# %%
townhome['ID ผู้ประเมิน'].value_counts()
# Out:
# 1    120
# 2    120
# Name: ID ผู้ประเมิน, dtype: int64

# %%
ass1_th = townhome[townhome['ID ผู้ประเมิน']==1]

# %%
ass2_th = townhome[townhome['ID ผู้ประเมิน']==2]

# %%
ass2_th['ประเมิน1'] = ass2_th['post id'].map(ass1_th.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
# Out:
# <ipython-input-43-f0959c25ba7c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ass2_th['ประเมิน1'] = ass2_th['post id'].map(ass1_th.set_index('post id')['ประเมินราคาซื้อ-ขาย']);

# %%
ass2_th['ประเมิน2'] = ass2_th['post id'].map(ass2_th.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
# Out:
# <ipython-input-44-d041727ea83f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ass2_th['ประเมิน2'] = ass2_th['post id'].map(ass2_th.set_index('post id')['ประเมินราคาซื้อ-ขาย']);

# %%
tht = ass2_th[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2']]
tht
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2
# 1      https://nayoo.co/khonkaen/posts/548   1045000.0   700000.0  1500000.0
# 3      https://nayoo.co/khonkaen/posts/549    935000.0   700000.0  1500000.0
# 5      https://nayoo.co/khonkaen/posts/579   3520000.0  3500000.0  4000000.0
# 7      https://nayoo.co/khonkaen/posts/580   3850000.0  3500000.0  3200000.0
# 9      https://nayoo.co/khonkaen/posts/582    990000.0  1000000.0   800000.0
# ..                                     ...         ...        ...        ...
# 235  https://nayoo.co/khonkaen/posts/18547   1430000.0  1000000.0  1200000.0
# 236  https://nayoo.co/khonkaen/posts/18551   1980000.0  1500000.0  1700000.0
# 237  https://nayoo.co/khonkaen/posts/19434   2000000.0  1600000.0  1900000.0
# 238  https://nayoo.co/khonkaen/posts/19501   1790000.0  1600000.0  1700000.0
# 239  https://nayoo.co/khonkaen/posts/20367   1590000.0  1700000.0  1700000.0
#
# [120 rows x 4 columns]

# %%
tht.isnull().any()
# Out:
# post id       False
# ราคาทรัพย์    False
# ประเมิน1      False
# ประเมิน2      False
# dtype: bool

# %% [markdown]
# #### MAPE

# %%
ac_th = tht['ราคาทรัพย์']
pr1_th = tht['ประเมิน1']
pr2_th = tht['ประเมิน2']

# %%
pred1_th = mape(ac_th, pr1_th)
pred2_th = mape(ac_th, pr2_th)
mape_th = mape(pr1_th,pr2_th)

# %%
print(f'ค่า MAPE ของผู้ประเมินคนที่ 1 เท่ากับ {pred1_th:.3f}\nค่า MAPE ของผู้ประเมินคนที่ 2 เท่ากับ {pred2_th:.3f}\nค่า MAPE ราคาตั้งขายของผู้ประเมินคนที่ 1 และ ผู้ประเมินคนที่ 2  เท่ากับ {mape_th:.3f}')
# Out:
# ค่า MAPE ของผู้ประเมินคนที่ 1 เท่ากับ 0.114
# ค่า MAPE ของผู้ประเมินคนที่ 2 เท่ากับ 0.088
# ค่า MAPE ราคาตั้งขายของผู้ประเมินคนที่ 1 และ ผู้ประเมินคนที่ 2  เท่ากับ 0.112

# %% [markdown]
# ### Shop house

# %%
shophouse= pd.read_excel('/content/gdrive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='อาคารพาณิชย์')
shophouse.head(3)
# Out:
#    ID ผู้ประเมิน                             post id          property_type  \
# 0              1   https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 1              2   https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 2              1  https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ   7000000.0            6000000.0
# 1                        มั่นใจ   7000000.0            8000000.0
# 2                        มั่นใจ  12000000.0           12000000.0
#
#              ปัจจัยในการประเมินราคาซื้อ-ขาย  เหตุผลไม่มั่นใจราคาประเมิน  \
# 0                              8,000-30,000                         NaN
# 1  ราคาเสนอขาย 4,000,000-6,000,000 บาท/คูหา                         NaN
# 2                              8,000-40,000                         NaN
#
#                       ให้คะแนนทรัพย์  Unnamed: 9  \
# 0  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         3.0
# 1   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         4.0
# 2   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         4.0
#
#                         Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# 0     ขายได้ ใช้ระยะเวลา 7-12 เดือน          NaN          NaN         10.0
# 1  ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี          NaN          NaN          NaN
# 2  ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี          NaN          NaN          NaN

# %%
shophouse['ID ผู้ประเมิน'].value_counts()
# Out:
# 1    10
# 2    10
# Name: ID ผู้ประเมิน, dtype: int64

# %%
ass1_sh = shophouse[shophouse['ID ผู้ประเมิน']==1]

# %%
ass2_sh = shophouse[shophouse['ID ผู้ประเมิน']==2]

# %%
ass2_sh['ประเมิน1'] = ass2_sh['post id'].map(ass1_sh.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
# Out:
# <ipython-input-54-76e2dbbf8a3d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ass2_sh['ประเมิน1'] = ass2_sh['post id'].map(ass1_sh.set_index('post id')['ประเมินราคาซื้อ-ขาย']);

# %%
ass2_sh['ประเมิน2'] = ass2_sh['post id'].map(ass2_sh.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
# Out:
# <ipython-input-55-8d1096c3ce9a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ass2_sh['ประเมิน2'] = ass2_sh['post id'].map(ass2_sh.set_index('post id')['ประเมินราคาซื้อ-ขาย']);

# %%
sht = ass2_sh[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2']]
sht
# Out:
#                                 post id  ราคาทรัพย์    ประเมิน1    ประเมิน2
# 1     https://nayoo.co/khonkaen/posts/6   7000000.0   6000000.0   8000000.0
# 3    https://nayoo.co/khonkaen/posts/17  12000000.0  12000000.0  12000000.0
# 5    https://nayoo.co/khonkaen/posts/21  22500000.0  13500000.0  20000000.0
# 7    https://nayoo.co/khonkaen/posts/22   3500000.0   4000000.0   4000000.0
# 9    https://nayoo.co/khonkaen/posts/24   3900000.0   2200000.0   3000000.0
# 11   https://nayoo.co/khonkaen/posts/30   4800000.0   3600000.0   4000000.0
# 13   https://nayoo.co/khonkaen/posts/35   2400000.0   2500000.0   2100000.0
# 15  https://nayoo.co/khonkaen/posts/497   5000000.0   3800000.0   5000000.0
# 17  https://nayoo.co/khonkaen/posts/498   7000000.0   7000000.0   8000000.0
# 19  https://nayoo.co/khonkaen/posts/499   9000000.0   8000000.0  10000000.0

# %%
sht.isnull().any()
# Out:
# post id       False
# ราคาทรัพย์    False
# ประเมิน1      False
# ประเมิน2      False
# dtype: bool

# %% [markdown]
# #### MAPE

# %%
ac_sh = sht['ราคาทรัพย์']
pr1_sh = sht['ประเมิน1']
pr2_sh = sht['ประเมิน2']

# %%
pred1_sh = mape(ac_sh, pr1_sh)
pred2_sh = mape(ac_sh, pr2_sh)
mape_sh = mape(pr1_sh,pr2_sh)

# %%
print(f'ค่า MAPE ของผู้ประเมินคนที่ 1 เท่ากับ {pred1_sh:.3f}\nค่า MAPE ของผู้ประเมินคนที่ 2 เท่ากับ {pred2_sh:.3f}\nค่า MAPE ราคาตั้งขายของผู้ประเมินคนที่ 1 และ ผู้ประเมินคนที่ 2  เท่ากับ {mape_sh:.3f}')
# Out:
# ค่า MAPE ของผู้ประเมินคนที่ 1 เท่ากับ 0.176
# ค่า MAPE ของผู้ประเมินคนที่ 2 เท่ากับ 0.117
# ค่า MAPE ราคาตั้งขายของผู้ประเมินคนที่ 1 และ ผู้ประเมินคนที่ 2  เท่ากับ 0.216

# %% [markdown]
# ###.

# %%
ass2['ประเมิน1'] = ass2['post id'].map(ass1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
ass2
# Out:
# <ipython-input-61-91656c2d09a1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ass2['ประเมิน1'] = ass2['post id'].map(ass1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5                2    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7                2    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9                2    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 185              2  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 186              2  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 187              2     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 188              2     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 189              2    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                          มั่นใจ   2700000.0            2700000.0
# 3                          มั่นใจ   2600000.0            2400000.0
# 5                          มั่นใจ   5900000.0            9000000.0
# 7                          มั่นใจ   4400000.0            3700000.0
# 9                          มั่นใจ   2750000.0            2500000.0
# ..                            ...         ...                  ...
# 185                        มั่นใจ   5500000.0            5000000.0
# 186                        มั่นใจ   7911000.0            7400000.0
# 187                        มั่นใจ   2000000.0            2500000.0
# 188                        มั่นใจ   4000000.0            3900000.0
# 189                        มั่นใจ   1375000.0            1400000.0
#
#                         ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 1    โครงการนี้ราคาเสนอขาย 2,500,000-3,000,000 บาท/...
# 3     ราคาเสนอขายประมาณ 2,200,000 - 2,500,000 บาท/หลัง
# 5    โซนนี้ราคาซื้อขาย ประมาณ 10,000-20,000 บาท/ตาร...
# 7               เสนอขาย 3,500,000 - 4,200,000 บาท/หลัง
# 9          ราคาเสนอขาย 2,000,0000 - 2,800,000 บาท/หลัง
# ..                                                 ...
# 185              ราคาเสนอขาย 20,000-30,000 บาท/ตารางวา
# 186            ราคาเสนอขาย 20,000 - 30,000 บาท/ตารางวา
# 187                   ราคาเสนอขาย 2.2-3.0 ล้านบาท/หลัง
# 188                    ราคาเสนอขาย 3.5-4.0ล้านบาท/หลัง
# 189                   ราคาเสนอขาย 1.2-1.5 ล้านบาท/หลัง
#
#     เหตุผลไม่มั่นใจราคาประเมิน                     ให้คะแนนทรัพย์  Unnamed: 9  \
# 1                          NaN   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         NaN
# 3                          NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 5                          NaN  5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน         NaN
# 7                          NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 9                          NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# ..                         ...                                ...         ...
# 185                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 186                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 187                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 188                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 189                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
#
#      Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13   ประเมิน1   ประเมิน2
# 1            NaN          NaN          NaN          NaN  2500000.0  2700000.0
# 3            NaN          NaN          NaN          NaN  2200000.0  2400000.0
# 5            NaN          NaN          NaN          NaN  5000000.0  9000000.0
# 7            NaN          NaN          NaN          NaN  3500000.0  3700000.0
# 9            NaN          NaN          NaN          NaN  2500000.0  2500000.0
# ..           ...          ...          ...          ...        ...        ...
# 185          NaN          NaN          NaN          NaN  4500000.0  5000000.0
# 186          NaN          NaN          NaN          NaN  5200000.0  7400000.0
# 187          NaN          NaN          NaN          NaN  3600000.0  2500000.0
# 188          NaN          NaN          NaN          NaN  4000000.0  3900000.0
# 189          NaN          NaN          NaN          NaN  1200000.0  1400000.0
#
# [90 rows x 16 columns]

# %%
home = ass2[['post id','ราคาทรัพย์','ประเมินราคาซื้อ-ขาย','ประเมิน1']]

# %%
from sklearn.metrics import mean_absolute_percentage_error as MAPE

# %%
temp = pd.read_excel('/content/gdrive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='บ้าน')
id1 = temp[temp['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id2 = temp[temp['ID ผู้ประเมิน']==2]
id2 = id2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = MAPE(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
id2MAPE = MAPE(id2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nบ้าน\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id2MAPE*100:.2f}%')
id2['ประเมิน2'] = id2['post id'].map(id1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_d = id2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
one2two = MAPE(id2_d['ประเมินราคาซื้อ-ขาย'],id2_d['ประเมิน2'])
two2one = MAPE(id2_d['ประเมิน2'],id2_d['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_d)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# บ้าน
# นักประเมิน คนที่ 1 = 13.00%
# นักประเมิน คนที่ 2 = 8.52%
# ความผิดพลาดระหว่างนักประเมินทั้ง 12.60%
# จำนวนทรัพย์ทั้งหมด 89 ทรัพย์

# %%
temp = pd.read_excel('/content/gdrive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='ที่ดิน')
id1 = temp[temp['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id2 = temp[temp['ID ผู้ประเมิน']==2]
id2 = id2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = MAPE(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
id2MAPE = MAPE(id2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nที่ดิน\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id2MAPE*100:.2f}%')
id2['ประเมิน2'] = id2['post id'].map(id1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_d = id2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
one2two = MAPE(id2_d['ประเมินราคาซื้อ-ขาย'],id2_d['ประเมิน2'])
two2one = MAPE(id2_d['ประเมิน2'],id2_d['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_d)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ที่ดิน
# นักประเมิน คนที่ 1 = 83.48%
# นักประเมิน คนที่ 2 = 48.38%
# ความผิดพลาดระหว่างนักประเมินทั้ง 58.41%
# จำนวนทรัพย์ทั้งหมด 100 ทรัพย์

# %%
home
# Out:
#                                    post id  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0            2700000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0            2400000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0            9000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0            3700000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0            2500000.0
# ..                                     ...         ...                  ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0            5000000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0            7400000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0            2500000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0            3900000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0            1400000.0
#
#       ประเมิน1
# 1    2500000.0
# 3    2200000.0
# 5    5000000.0
# 7    3500000.0
# 9    2500000.0
# ..         ...
# 185  4500000.0
# 186  5200000.0
# 187  3600000.0
# 188  4000000.0
# 189  1200000.0
#
# [90 rows x 4 columns]

# %% [markdown]
# #เขียน function ตรวจสอบค่าที่เติม 0 ผิด

# %%
max(10,2)
# Out:
# 10

# %%
def check_v(in1,in2):
    return max(in1/in2,in2/in1)

# %%
check_v(100,12)
# Out:
# 8.333333333333334

# %%
check_v(100,1200)
# Out:
# 12.0

# %% [markdown]
# ## สร้าง column ใหม่ ลงในตาราง home โดย ค่าใน column คือค่า จาก function check(ราคาตั้งขาย,ราคาประเมิน1)

# %% [markdown]
# ## HW2 แก้ไข ข้อมูลแล้วคำนวณ MAPE ใหม่อีกรอบมาเทียบกัน

# %% [markdown]
# ###Home

# %%
ht['check1']=ht.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)
ht['check2']=ht.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน2']),axis=1)

# %%
ht
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0  2500000.0  2700000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0  2200000.0  2400000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0  5000000.0  9000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0  3500000.0  3700000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0  2500000.0  2500000.0
# ..                                     ...         ...        ...        ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0  4500000.0  5000000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0  5200000.0  7400000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0  3600000.0  2500000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0  4000000.0  3900000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0  1200000.0  1400000.0
#
#        check1    check2
# 1    1.080000  1.000000
# 3    1.181818  1.083333
# 5    1.180000  1.525424
# 7    1.257143  1.189189
# 9    1.100000  1.100000
# ..        ...       ...
# 185  1.222222  1.100000
# 186  1.521346  1.069054
# 187  1.800000  1.250000
# 188  1.000000  1.025641
# 189  1.145833  1.018182
#
# [90 rows x 6 columns]

# %%
check1 = list()
for row in ht.iterrows():
    check1.append(check_v(row[1]['ราคาทรัพย์'],row[1]['ประเมิน1']))
check1
# Out:
# [1.08,
#  1.1818181818181819,
#  1.18,
#  1.2571428571428571,
#  1.1,
#  1.271111111111111,
#  1.36,
#  1.0153846153846153,
#  1.3684,
#  1.031941031941032,
#  1.0476190476190477,
#  1.1785714285714286,
#  1.0592592592592593,
#  1.188,
#  1.1275,
#  1.1,
#  1.1157142857142857,
#  1.0371428571428571,
#  1.0588235294117647,
#  1.2571428571428571,
#  1.13125,
#  1.0,
#  1.0888888888888888,
#  1.0892333472978635,
#  1.0444444444444445,
#  1.0,
#  1.0434782608695652,
#  1.02,
#  1.25,
#  1.13,
#  1.0714285714285714,
#  1.0,
#  1.0,
#  1.3833333333333333,
#  1.03125,
#  1.1611111111111112,
#  1.0526315789473684,
#  1.5384615384615385,
#  1.0227272727272727,
#  1.1363636363636365,
#  1.1111111111111112,
#  1.1290322580645162,
#  1.1388888888888888,
#  1.0,
#  1.0933333333333333,
#  1.3093125,
#  1.21,
#  1.24,
#  1.1642857142857144,
#  1.1,
#  1.4685314685314685,
#  1.1111111111111112,
#  1.1942857142857144,
#  1.0714285714285714,
#  1.0710526315789475,
#  1.4575,
#  1.046,
#  1.09375,
#  1.044932079414838,
#  1.1090909090909091,
#  1.1333333333333333,
#  1.1866666666666668,
#  1.036,
#  1.0031347962382444,
#  1.0606060606060606,
#  1.2,
#  1.2340425531914894,
#  1.0,
#  1.0857142857142856,
#  1.1607142857142858,
#  1.1290322580645162,
#  1.0263929618768328,
#  1.1628571428571428,
#  1.083720930232558,
#  1.1333333333333333,
#  1.0526315789473684,
#  1.1111111111111112,
#  1.5238095238095237,
#  1.0666666666666667,
#  1.0167768174885612,
#  1.0,
#  1.0526315789473684,
#  1.0083333333333333,
#  1.0697727272727273,
#  1.1,
#  1.2222222222222223,
#  1.521346153846154,
#  1.8,
#  1.0,
#  1.1458333333333333]

# %%
check2 = list()
for row in ht.iterrows():
    check2.append(check_v(row[1]['ราคาทรัพย์'],row[1]['ประเมิน2']))
check2
# Out:
# [1.0,
#  1.0833333333333333,
#  1.5254237288135593,
#  1.1891891891891893,
#  1.1,
#  1.0314685314685315,
#  1.050420168067227,
#  1.0416666666666667,
#  1.1403333333333334,
#  1.0175,
#  1.0476190476190477,
#  1.03125,
#  1.0214285714285714,
#  1.0607142857142857,
#  1.025,
#  1.0607142857142857,
#  1.0847222222222221,
#  1.0371428571428571,
#  1.0,
#  1.125,
#  1.1049723756906078,
#  1.1904761904761905,
#  1.0888888888888888,
#  1.0054461667364893,
#  1.0425531914893618,
#  1.125,
#  1.0434782608695652,
#  1.0364145658263306,
#  1.0,
#  1.0324483775811208,
#  1.04,
#  1.2,
#  1.04,
#  1.1318181818181818,
#  1.0,
#  1.045,
#  1.0526315789473684,
#  3.3333333333333335,
#  1.0227272727272727,
#  1.04,
#  1.08,
#  1.2903225806451613,
#  1.1219512195121952,
#  1.125,
#  1.2195121951219512,
#  1.2322941176470588,
#  1.0755555555555556,
#  1.1366666666666667,
#  1.0736196319018405,
#  1.1,
#  1.048951048951049,
#  1.1111111111111112,
#  1.045,
#  1.0666666666666667,
#  1.0435897435897437,
#  1.4575,
#  1.046,
#  1.0857142857142856,
#  1.1484,
#  1.1090909090909091,
#  1.0408163265306123,
#  1.1125,
#  1.036,
#  1.0031347962382444,
#  1.1,
#  1.1666666666666667,
#  1.0344827586206897,
#  1.0285714285714285,
#  1.0857142857142856,
#  1.0,
#  1.0769230769230769,
#  1.0263929618768328,
#  1.031941031941032,
#  1.0355555555555556,
#  1.0625,
#  1.1578947368421053,
#  1.2038740396061032,
#  1.0476190476190477,
#  1.0227272727272727,
#  1.0167768174885612,
#  1.125,
#  1.05,
#  1.05875,
#  1.046,
#  1.056,
#  1.1,
#  1.069054054054054,
#  1.25,
#  1.0256410256410255,
#  1.018181818181818]

# %%
ht.sort_values(by=['check1'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0  3600000.0  2500000.0
# 75       https://nayoo.co/khonkaen/posts/1    390000.0   600000.0  1300000.0
# 177  https://nayoo.co/khonkaen/posts/19450   2100000.0  3200000.0  2200000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0  5200000.0  7400000.0
# 101   https://nayoo.co/khonkaen/posts/6010   2860000.0  4200000.0  3000000.0
# ..                                     ...         ...        ...        ...
# 43    https://nayoo.co/khonkaen/posts/1128   4200000.0  4200000.0  5000000.0
# 87    https://nayoo.co/khonkaen/posts/3905   1200000.0  1200000.0  1350000.0
# 65    https://nayoo.co/khonkaen/posts/2143   5200000.0  5200000.0  5000000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0  4000000.0  3900000.0
# 167   https://nayoo.co/khonkaen/posts/9141   3500000.0  3500000.0  3600000.0
#
#        check1    check2
# 187  1.800000  1.250000
# 75   1.538462  3.333333
# 177  1.523810  1.047619
# 186  1.521346  1.069054
# 101  1.468531  1.048951
# ..        ...       ...
# 43   1.000000  1.190476
# 87   1.000000  1.125000
# 65   1.000000  1.040000
# 188  1.000000  1.025641
# 167  1.000000  1.028571
#
# [90 rows x 6 columns]

# %%
ht.sort_values(by=['check2'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 75       https://nayoo.co/khonkaen/posts/1    390000.0   600000.0  1300000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0  5000000.0  9000000.0
# 111   https://nayoo.co/khonkaen/posts/6045   2915000.0  2000000.0  2000000.0
# 83    https://nayoo.co/khonkaen/posts/3721   3100000.0  3500000.0  4000000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0  3600000.0  2500000.0
# ..                                     ...         ...        ...        ...
# 169  https://nayoo.co/khonkaen/posts/11264   6500000.0  5600000.0  6500000.0
# 69    https://nayoo.co/khonkaen/posts/2262   3200000.0  3300000.0  3200000.0
# 57    https://nayoo.co/khonkaen/posts/1895   1200000.0  1500000.0  1200000.0
# 37     https://nayoo.co/khonkaen/posts/760   1800000.0  1700000.0  1800000.0
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0  2500000.0  2700000.0
#
#        check1    check2
# 75   1.538462  3.333333
# 5    1.180000  1.525424
# 111  1.457500  1.457500
# 83   1.129032  1.290323
# 187  1.800000  1.250000
# ..        ...       ...
# 169  1.160714  1.000000
# 69   1.031250  1.000000
# 57   1.250000  1.000000
# 37   1.058824  1.000000
# 1    1.080000  1.000000
#
# [90 rows x 6 columns]

# %% [markdown]
# ####เทียบ MAPE

# %%
#MAPE เก่า

temp = pd.read_excel('/content/gdrive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='บ้าน')
id1 = temp[temp['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id2 = temp[temp['ID ผู้ประเมิน']==2]
id2 = id2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = mape(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
id2MAPE = mape(id2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nบ้าน\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id2MAPE*100:.2f}%')
id2['ประเมิน2'] = id2['post id'].map(id1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_d = id2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
one2two = mape(id2_d['ประเมินราคาซื้อ-ขาย'],id2_d['ประเมิน2'])
two2one = mape(id2_d['ประเมิน2'],id2_d['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_d)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# บ้าน
# นักประเมิน คนที่ 1 = 13.00%
# นักประเมิน คนที่ 2 = 8.52%
# ความผิดพลาดระหว่างนักประเมินทั้ง 12.60%
# จำนวนทรัพย์ทั้งหมด 89 ทรัพย์

# %%
#MAPE ใหม่

temp = pd.read_excel('/content/gdrive/MyDrive/bsc_DPDM_data/คำตอบนักประเมินแก้.xlsx',sheet_name='บ้าน')
id1 = temp[temp['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id2 = temp[temp['ID ผู้ประเมิน']==2]
id2 = id2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = mape(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
id2MAPE = mape(id2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nบ้าน\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id2MAPE*100:.2f}%')
id2['ประเมิน2'] = id2['post id'].map(id1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_d = id2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
one2two = mape(id2_d['ประเมินราคาซื้อ-ขาย'],id2_d['ประเมิน2'])
two2one = mape(id2_d['ประเมิน2'],id2_d['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_d)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# บ้าน
# นักประเมิน คนที่ 1 = 13.75%
# นักประเมิน คนที่ 2 = 11.65%
# ความผิดพลาดระหว่างนักประเมินทั้ง 15.75%
# จำนวนทรัพย์ทั้งหมด 61 ทรัพย์

# %% [markdown]
# ### Land

# %%
lt['check1']=lt.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)
lt['check2']=lt.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน2']),axis=1)
# Out:
# <ipython-input-79-614a3106acb9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lt['check1']=lt.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)
# <ipython-input-79-614a3106acb9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lt['check2']=lt.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน2']),axis=1)

# %%
lt
# Out:
#                                    post id  ราคาทรัพย์    ประเมิน1  \
# 1     https://nayoo.co/khonkaen/posts/1033     2800000   1800000.0
# 4     https://nayoo.co/khonkaen/posts/1711    14900000   8000000.0
# 7     https://nayoo.co/khonkaen/posts/1726    90000000  18000000.0
# 10    https://nayoo.co/khonkaen/posts/1732    65000000  35000000.0
# 13    https://nayoo.co/khonkaen/posts/1866     3000000   2200000.0
# ..                                     ...         ...         ...
# 200  https://nayoo.co/khonkaen/posts/14539     5000000   4000000.0
# 202  https://nayoo.co/khonkaen/posts/16072      750000    500000.0
# 204  https://nayoo.co/khonkaen/posts/17093     2650000   2000000.0
# 206  https://nayoo.co/khonkaen/posts/17112     1300000   1500000.0
# 208  https://nayoo.co/khonkaen/posts/17145     3000000   2500000.0
#
#        ประเมิน2    check1    check2
# 1     2000000.0  1.555556  1.400000
# 4    12000000.0  1.862500  1.241667
# 7    70000000.0  5.000000  1.285714
# 10   60000000.0  1.857143  1.083333
# 13    2500000.0  1.363636  1.200000
# ..          ...       ...       ...
# 200   4000000.0  1.250000  1.250000
# 202    750000.0  1.500000  1.000000
# 204   2500000.0  1.325000  1.060000
# 206   1500000.0  1.153846  1.153846
# 208   2800000.0  1.200000  1.071429
#
# [100 rows x 6 columns]

# %%
lt.sort_values(by=['check1'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์    ประเมิน1  \
# 194  https://nayoo.co/khonkaen/posts/13702    90000000   4500000.0
# 112   https://nayoo.co/khonkaen/posts/7955     2600000  32000000.0
# 58    https://nayoo.co/khonkaen/posts/9203   160000000  14000000.0
# 47    https://nayoo.co/khonkaen/posts/7349   245000000  24000000.0
# 7     https://nayoo.co/khonkaen/posts/1726    90000000  18000000.0
# ..                                     ...         ...         ...
# 182   https://nayoo.co/khonkaen/posts/9598     3900000   4000000.0
# 78    https://nayoo.co/khonkaen/posts/3447      980000   1000000.0
# 100   https://nayoo.co/khonkaen/posts/1663     1485000   1500000.0
# 122  https://nayoo.co/khonkaen/posts/12762      650000    650000.0
# 130   https://nayoo.co/khonkaen/posts/1599     2500000   2500000.0
#
#        ประเมิน2     check1     check2
# 194  75000000.0  20.000000   1.200000
# 112   2000000.0  12.307692   1.300000
# 58   11000000.0  11.428571  14.545455
# 47   18000000.0  10.208333  13.611111
# 7    70000000.0   5.000000   1.285714
# ..          ...        ...        ...
# 182   4000000.0   1.025641   1.025641
# 78     800000.0   1.020408   1.225000
# 100   1200000.0   1.010101   1.237500
# 122    700000.0   1.000000   1.076923
# 130   2200000.0   1.000000   1.136364
#
# [100 rows x 6 columns]

# %%
lt.sort_values(by=['check2'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์    ประเมิน1  \
# 58    https://nayoo.co/khonkaen/posts/9203   160000000  14000000.0
# 47    https://nayoo.co/khonkaen/posts/7349   245000000  24000000.0
# 148   https://nayoo.co/khonkaen/posts/3561     7374550   6000000.0
# 188  https://nayoo.co/khonkaen/posts/12250     2300000   2500000.0
# 144   https://nayoo.co/khonkaen/posts/3341     1700000   1600000.0
# ..                                     ...         ...         ...
# 104   https://nayoo.co/khonkaen/posts/1921     8080000   2800000.0
# 60   https://nayoo.co/khonkaen/posts/12607     7990000  10000000.0
# 158   https://nayoo.co/khonkaen/posts/6732     3500000   2800000.0
# 202  https://nayoo.co/khonkaen/posts/16072      750000    500000.0
# 37    https://nayoo.co/khonkaen/posts/3305    14000000  12000000.0
#
#        ประเมิน2     check1     check2
# 58   11000000.0  11.428571  14.545455
# 47   18000000.0  10.208333  13.611111
# 148  80000000.0   1.229092  10.848120
# 188  24000000.0   1.086957  10.434783
# 144   9000000.0   1.062500   5.294118
# ..          ...        ...        ...
# 104   8000000.0   2.885714   1.010000
# 60    8000000.0   1.251564   1.001252
# 158   3500000.0   1.250000   1.000000
# 202    750000.0   1.500000   1.000000
# 37   14000000.0   1.166667   1.000000
#
# [100 rows x 6 columns]

# %% [markdown]
# ####เทียบ MAPE

# %%
#MAPE เก่า

temp = pd.read_excel('/content/gdrive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='ที่ดิน')
id1 = temp[temp['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id2 = temp[temp['ID ผู้ประเมิน']==2]
id2 = id2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = mape(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
id2MAPE = mape(id2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nที่ดิน\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id2MAPE*100:.2f}%')
id2['ประเมิน2'] = id2['post id'].map(id1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_d = id2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
one2two = mape(id2_d['ประเมินราคาซื้อ-ขาย'],id2_d['ประเมิน2'])
two2one = mape(id2_d['ประเมิน2'],id2_d['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_d)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ที่ดิน
# นักประเมิน คนที่ 1 = 83.48%
# นักประเมิน คนที่ 2 = 48.38%
# ความผิดพลาดระหว่างนักประเมินทั้ง 58.41%
# จำนวนทรัพย์ทั้งหมด 100 ทรัพย์

# %%
#MAPE ใหม่

temp = pd.read_excel('/content/gdrive/MyDrive/bsc_DPDM_data/คำตอบนักประเมินแก้.xlsx',sheet_name='ที่ดิน')
id1 = temp[temp['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id2 = temp[temp['ID ผู้ประเมิน']==2]
id2 = id2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = mape(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
id2MAPE = mape(id2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nที่ดิน\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id2MAPE*100:.2f}%')
id2['ประเมิน2'] = id2['post id'].map(id1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_d = id2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
one2two = mape(id2_d['ประเมินราคาซื้อ-ขาย'],id2_d['ประเมิน2'])
two2one = mape(id2_d['ประเมิน2'],id2_d['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_d)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ที่ดิน
# นักประเมิน คนที่ 1 = 39.11%
# นักประเมิน คนที่ 2 = 24.01%
# ความผิดพลาดระหว่างนักประเมินทั้ง 33.16%
# จำนวนทรัพย์ทั้งหมด 40 ทรัพย์

# %% [markdown]
# ###Townhome

# %%
tht['check1']=tht.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)
tht['check2']=tht.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน2']),axis=1)
# Out:
# <ipython-input-85-e3ce8b647358>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tht['check1']=tht.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)
# <ipython-input-85-e3ce8b647358>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tht['check2']=tht.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน2']),axis=1)

# %%
tht
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 1      https://nayoo.co/khonkaen/posts/548   1045000.0   700000.0  1500000.0
# 3      https://nayoo.co/khonkaen/posts/549    935000.0   700000.0  1500000.0
# 5      https://nayoo.co/khonkaen/posts/579   3520000.0  3500000.0  4000000.0
# 7      https://nayoo.co/khonkaen/posts/580   3850000.0  3500000.0  3200000.0
# 9      https://nayoo.co/khonkaen/posts/582    990000.0  1000000.0   800000.0
# ..                                     ...         ...        ...        ...
# 235  https://nayoo.co/khonkaen/posts/18547   1430000.0  1000000.0  1200000.0
# 236  https://nayoo.co/khonkaen/posts/18551   1980000.0  1500000.0  1700000.0
# 237  https://nayoo.co/khonkaen/posts/19434   2000000.0  1600000.0  1900000.0
# 238  https://nayoo.co/khonkaen/posts/19501   1790000.0  1600000.0  1700000.0
# 239  https://nayoo.co/khonkaen/posts/20367   1590000.0  1700000.0  1700000.0
#
#        check1    check2
# 1    1.492857  1.435407
# 3    1.335714  1.604278
# 5    1.005714  1.136364
# 7    1.100000  1.203125
# 9    1.010101  1.237500
# ..        ...       ...
# 235  1.430000  1.191667
# 236  1.320000  1.164706
# 237  1.250000  1.052632
# 238  1.118750  1.052941
# 239  1.069182  1.069182
#
# [120 rows x 6 columns]

# %%
tht.sort_values(by=['check1'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 176   https://nayoo.co/khonkaen/posts/3528   2190000.0   350000.0   400000.0
# 180   https://nayoo.co/khonkaen/posts/6095   2420000.0  1500000.0  1500000.0
# 132    https://nayoo.co/khonkaen/posts/619   1430000.0   950000.0  1000000.0
# 1      https://nayoo.co/khonkaen/posts/548   1045000.0   700000.0  1500000.0
# 174   https://nayoo.co/khonkaen/posts/3478   2190000.0  1500000.0  2200000.0
# ..                                     ...         ...        ...        ...
# 228  https://nayoo.co/khonkaen/posts/17923   1990000.0  2000000.0  2200000.0
# 167   https://nayoo.co/khonkaen/posts/2829   2490000.0  2500000.0  2300000.0
# 220  https://nayoo.co/khonkaen/posts/17545   2800000.0  2800000.0  2800000.0
# 200  https://nayoo.co/khonkaen/posts/13411   3200000.0  3200000.0  3200000.0
# 203  https://nayoo.co/khonkaen/posts/17503   1500000.0  1500000.0  1300000.0
#
#        check1    check2
# 176  6.257143  5.475000
# 180  1.613333  1.613333
# 132  1.505263  1.430000
# 1    1.492857  1.435407
# 174  1.460000  1.004566
# ..        ...       ...
# 228  1.005025  1.105528
# 167  1.004016  1.082609
# 220  1.000000  1.000000
# 200  1.000000  1.000000
# 203  1.000000  1.153846
#
# [120 rows x 6 columns]

# %%
tht.sort_values(by=['check2'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 176   https://nayoo.co/khonkaen/posts/3528   2190000.0   350000.0   400000.0
# 234  https://nayoo.co/khonkaen/posts/18090   3000000.0  2800000.0  1500000.0
# 180   https://nayoo.co/khonkaen/posts/6095   2420000.0  1500000.0  1500000.0
# 3      https://nayoo.co/khonkaen/posts/549    935000.0   700000.0  1500000.0
# 225  https://nayoo.co/khonkaen/posts/17742   2500000.0  2200000.0  1700000.0
# ..                                     ...         ...        ...        ...
# 188   https://nayoo.co/khonkaen/posts/8101   3200000.0  3300000.0  3200000.0
# 220  https://nayoo.co/khonkaen/posts/17545   2800000.0  2800000.0  2800000.0
# 199  https://nayoo.co/khonkaen/posts/12957   1500000.0  1600000.0  1500000.0
# 151   https://nayoo.co/khonkaen/posts/1978   2500000.0  2700000.0  2500000.0
# 181   https://nayoo.co/khonkaen/posts/6104   2200000.0  2500000.0  2200000.0
#
#        check1    check2
# 176  6.257143  5.475000
# 234  1.071429  2.000000
# 180  1.613333  1.613333
# 3    1.335714  1.604278
# 225  1.136364  1.470588
# ..        ...       ...
# 188  1.031250  1.000000
# 220  1.000000  1.000000
# 199  1.066667  1.000000
# 151  1.080000  1.000000
# 181  1.136364  1.000000
#
# [120 rows x 6 columns]

# %% [markdown]
# ####เทียบ MAPE

# %%
#MAPE เก่า

temp = pd.read_excel('/content/gdrive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='ทาวน์โฮม')
id1 = temp[temp['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id2 = temp[temp['ID ผู้ประเมิน']==2]
id2 = id2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = mape(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
id2MAPE = mape(id2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nทาวน์โฮม\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id2MAPE*100:.2f}%')
id2['ประเมิน2'] = id2['post id'].map(id1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_d = id2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
one2two = mape(id2_d['ประเมินราคาซื้อ-ขาย'],id2_d['ประเมิน2'])
two2one = mape(id2_d['ประเมิน2'],id2_d['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_d)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ทาวน์โฮม
# นักประเมิน คนที่ 1 = 16.21%
# นักประเมิน คนที่ 2 = 12.75%
# ความผิดพลาดระหว่างนักประเมินทั้ง 10.92%
# จำนวนทรัพย์ทั้งหมด 120 ทรัพย์

# %%
#MAPE ใหม่

temp = pd.read_excel('/content/gdrive/MyDrive/bsc_DPDM_data/คำตอบนักประเมินแก้.xlsx',sheet_name='ทาวน์โฮม')
id1 = temp[temp['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id2 = temp[temp['ID ผู้ประเมิน']==2]
id2 = id2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = mape(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
id2MAPE = mape(id2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nทาวน์โฮม\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id2MAPE*100:.2f}%')
id2['ประเมิน2'] = id2['post id'].map(id1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_d = id2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
one2two = mape(id2_d['ประเมินราคาซื้อ-ขาย'],id2_d['ประเมิน2'])
two2one = mape(id2_d['ประเมิน2'],id2_d['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_d)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ทาวน์โฮม
# นักประเมิน คนที่ 1 = 11.69%
# นักประเมิน คนที่ 2 = 8.64%
# ความผิดพลาดระหว่างนักประเมินทั้ง 11.63%
# จำนวนทรัพย์ทั้งหมด 60 ทรัพย์

# %% [markdown]
# ### Shop house

# %%
sht['check1']=sht.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)
sht['check2']=sht.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน2']),axis=1)
# Out:
# <ipython-input-91-c9ada16e4a71>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sht['check1']=sht.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)
# <ipython-input-91-c9ada16e4a71>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sht['check2']=sht.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน2']),axis=1)

# %%
sht
# Out:
#                                 post id  ราคาทรัพย์    ประเมิน1    ประเมิน2  \
# 1     https://nayoo.co/khonkaen/posts/6   7000000.0   6000000.0   8000000.0
# 3    https://nayoo.co/khonkaen/posts/17  12000000.0  12000000.0  12000000.0
# 5    https://nayoo.co/khonkaen/posts/21  22500000.0  13500000.0  20000000.0
# 7    https://nayoo.co/khonkaen/posts/22   3500000.0   4000000.0   4000000.0
# 9    https://nayoo.co/khonkaen/posts/24   3900000.0   2200000.0   3000000.0
# 11   https://nayoo.co/khonkaen/posts/30   4800000.0   3600000.0   4000000.0
# 13   https://nayoo.co/khonkaen/posts/35   2400000.0   2500000.0   2100000.0
# 15  https://nayoo.co/khonkaen/posts/497   5000000.0   3800000.0   5000000.0
# 17  https://nayoo.co/khonkaen/posts/498   7000000.0   7000000.0   8000000.0
# 19  https://nayoo.co/khonkaen/posts/499   9000000.0   8000000.0  10000000.0
#
#       check1    check2
# 1   1.166667  1.142857
# 3   1.000000  1.000000
# 5   1.666667  1.125000
# 7   1.142857  1.142857
# 9   1.772727  1.300000
# 11  1.333333  1.200000
# 13  1.041667  1.142857
# 15  1.315789  1.000000
# 17  1.000000  1.142857
# 19  1.125000  1.111111

# %%
sht.sort_values(by=['check1'],ascending=False)
# Out:
#                                 post id  ราคาทรัพย์    ประเมิน1    ประเมิน2  \
# 9    https://nayoo.co/khonkaen/posts/24   3900000.0   2200000.0   3000000.0
# 5    https://nayoo.co/khonkaen/posts/21  22500000.0  13500000.0  20000000.0
# 11   https://nayoo.co/khonkaen/posts/30   4800000.0   3600000.0   4000000.0
# 15  https://nayoo.co/khonkaen/posts/497   5000000.0   3800000.0   5000000.0
# 1     https://nayoo.co/khonkaen/posts/6   7000000.0   6000000.0   8000000.0
# 7    https://nayoo.co/khonkaen/posts/22   3500000.0   4000000.0   4000000.0
# 19  https://nayoo.co/khonkaen/posts/499   9000000.0   8000000.0  10000000.0
# 13   https://nayoo.co/khonkaen/posts/35   2400000.0   2500000.0   2100000.0
# 3    https://nayoo.co/khonkaen/posts/17  12000000.0  12000000.0  12000000.0
# 17  https://nayoo.co/khonkaen/posts/498   7000000.0   7000000.0   8000000.0
#
#       check1    check2
# 9   1.772727  1.300000
# 5   1.666667  1.125000
# 11  1.333333  1.200000
# 15  1.315789  1.000000
# 1   1.166667  1.142857
# 7   1.142857  1.142857
# 19  1.125000  1.111111
# 13  1.041667  1.142857
# 3   1.000000  1.000000
# 17  1.000000  1.142857

# %%
sht.sort_values(by=['check2'],ascending=False)
# Out:
#                                 post id  ราคาทรัพย์    ประเมิน1    ประเมิน2  \
# 9    https://nayoo.co/khonkaen/posts/24   3900000.0   2200000.0   3000000.0
# 11   https://nayoo.co/khonkaen/posts/30   4800000.0   3600000.0   4000000.0
# 1     https://nayoo.co/khonkaen/posts/6   7000000.0   6000000.0   8000000.0
# 7    https://nayoo.co/khonkaen/posts/22   3500000.0   4000000.0   4000000.0
# 13   https://nayoo.co/khonkaen/posts/35   2400000.0   2500000.0   2100000.0
# 17  https://nayoo.co/khonkaen/posts/498   7000000.0   7000000.0   8000000.0
# 5    https://nayoo.co/khonkaen/posts/21  22500000.0  13500000.0  20000000.0
# 19  https://nayoo.co/khonkaen/posts/499   9000000.0   8000000.0  10000000.0
# 3    https://nayoo.co/khonkaen/posts/17  12000000.0  12000000.0  12000000.0
# 15  https://nayoo.co/khonkaen/posts/497   5000000.0   3800000.0   5000000.0
#
#       check1    check2
# 9   1.772727  1.300000
# 11  1.333333  1.200000
# 1   1.166667  1.142857
# 7   1.142857  1.142857
# 13  1.041667  1.142857
# 17  1.000000  1.142857
# 5   1.666667  1.125000
# 19  1.125000  1.111111
# 3   1.000000  1.000000
# 15  1.315789  1.000000

# %% [markdown]
# ####MAPE

# %%
temp = pd.read_excel('/content/gdrive/MyDrive/bsc_DPDM_data/คำตอบนักประเมินแก้.xlsx',sheet_name='อาคารพาณิชย์')
id1 = temp[temp['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id2 = temp[temp['ID ผู้ประเมิน']==2]
id2 = id2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = mape(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
id2MAPE = mape(id2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nอาคารพาณิชย์\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id2MAPE*100:.2f}%')
id2['ประเมิน2'] = id2['post id'].map(id1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_d = id2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
one2two = mape(id2_d['ประเมินราคาซื้อ-ขาย'],id2_d['ประเมิน2'])
two2one = mape(id2_d['ประเมิน2'],id2_d['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_d)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# อาคารพาณิชย์
# นักประเมิน คนที่ 1 = 25.45%
# นักประเมิน คนที่ 2 = 12.43%
# ความผิดพลาดระหว่างนักประเมินทั้ง 19.28%
# จำนวนทรัพย์ทั้งหมด 10 ทรัพย์

# %% [markdown]
# ##Load

# %%
import pandas as pd

# %%
url = 'https://docs.google.com/spreadsheets/d/1AwN9DH9evvEvWosT_K6Ic8XpytYdciBteQ22cklUuYE/export?format=xlsx'
land = pd.read_excel(url, sheet_name='ที่ดิน')
land.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-126-6b543ccebdf0> in <module>
#       1 url = 'https://docs.google.com/spreadsheets/d/1AwN9DH9evvEvWosT_K6Ic8XpytYdciBteQ22cklUuYE/export?format=xlsx'
# ----> 2 land = pd.read_excel(url, sheet_name='ที่ดิน')
#       3 land.head()
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# --> 364         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365     elif engine and engine != io.engine:
#     366         raise ValueError(
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1193                 )
#    1194                 if ext is None:
# -> 1195                     raise ValueError(
#    1196                         "Excel file format cannot be determined, you must specify "
#    1197                         "an engine manually."
#
# ValueError: Excel file format cannot be determined, you must specify an engine manually.

# %% [markdown]
# ###HW3 vi
