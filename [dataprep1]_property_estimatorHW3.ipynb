# %% [markdown]
# <a href="https://colab.research.google.com/github/chutimaq/bsc_dpdm22/blob/main/%5Bdataprep1%5D_property_estimatorHW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
link = 'https://docs.google.com/spreadsheets/d/1xOUyJLF4NZTDkYCDTIj5bCuumi6d5ZnQT7-e7LpEe4o/export?format=xlsx'
house = pd.read_excel(link,sheet_name='บ้าน')
land = pd.read_excel(link,sheet_name='ที่ดิน')
condo = pd.read_excel(link,sheet_name='คอนโด')
townhome = pd.read_excel(link,sheet_name='ทาวน์โฮม')
commercial = pd.read_excel(link,sheet_name='อาคารพาณิชย์')

# %% [markdown]
# #สรุปข้อมูลนักประเมินแต่ละคน โดยพิจารณาจาก ความมั่นใจในการประเมิน ประเมินราคาซื้อ-ขาย ให้คะแนนทรัพย์

# %% [markdown]
# ##บ้านเดี่ยว

# %%
house
# Out:
#       ID ผู้ประเมิน                               post id property_type  \
# 0                 1    https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 1                 2    https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2                 1    https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 3                 2    https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4                 1   https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# ...             ...                                   ...           ...
# 1215              1  https://nayoo.co/khonkaen/posts/6257    บ้านเดี่ยว
# 1216              2  https://nayoo.co/khonkaen/posts/6258    บ้านเดี่ยว
# 1217              1  https://nayoo.co/khonkaen/posts/6258    บ้านเดี่ยว
# 1218              2  https://nayoo.co/khonkaen/posts/6260    บ้านเดี่ยว
# 1219              1  https://nayoo.co/khonkaen/posts/6260    บ้านเดี่ยว
#
#      ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                           มั่นใจ     2890000            2500000.0
# 1                           มั่นใจ     2890000            2700000.0
# 2                           มั่นใจ     2600000            2200000.0
# 3                           มั่นใจ     2600000            2400000.0
# 4                           มั่นใจ     6050000            5000000.0
# ...                            ...         ...                  ...
# 1215                        มั่นใจ      295000             500000.0
# 1216                        มั่นใจ      615000             500000.0
# 1217                        มั่นใจ      615000             600000.0
# 1218                        มั่นใจ      620000             700000.0
# 1219                        มั่นใจ      620000             750000.0
#
#                          ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0                                          5,000-15,000
# 1     โครงการนี้ราคาเสนอขาย 2,500,000-3,000,000 บาท/...
# 2                                          5,000-15,000
# 3      ราคาเสนอขายประมาณ 2,200,000 - 2,500,000 บาท/หลัง
# 4                                          5,000-15,000
# ...                                                 ...
# 1215  เพื่อป้องกันปัญหาที่อาจเกิดขึ้นภายหลังหากต้องม...
# 1216                     ราคาเสนอขาย 3-5 พันบาท/ตารางวา
# 1217  เพื่อป้องกันปัญหาที่อาจเกิดขึ้นภายหลังหากต้องม...
# 1218                     ราคาเสนอขาย 4-5 พันบาท/ตารางวา
# 1219  เพื่อป้องกันปัญหาที่อาจเกิดขึ้นภายหลังหากต้องม...
#
#      เหตุผลไม่มั่นใจราคาประเมิน                      ให้คะแนนทรัพย์
# 0                           NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 1                           NaN    4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน
# 2                           NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 3                           NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 4                           NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# ...                         ...                                 ...
# 1215                        NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 1216                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 1217                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 1218                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 1219                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
#
# [1220 rows x 9 columns]

# %%
est1 = house[house['ID ผู้ประเมิน']==1]
est1
# Out:
#       ID ผู้ประเมิน                               post id property_type  \
# 0                 1    https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2                 1    https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4                 1   https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 6                 1   https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 8                 1   https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ...             ...                                   ...           ...
# 1211              1  https://nayoo.co/khonkaen/posts/6255    บ้านเดี่ยว
# 1213              1  https://nayoo.co/khonkaen/posts/6256    บ้านเดี่ยว
# 1215              1  https://nayoo.co/khonkaen/posts/6257    บ้านเดี่ยว
# 1217              1  https://nayoo.co/khonkaen/posts/6258    บ้านเดี่ยว
# 1219              1  https://nayoo.co/khonkaen/posts/6260    บ้านเดี่ยว
#
#      ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                           มั่นใจ     2890000            2500000.0
# 2                           มั่นใจ     2600000            2200000.0
# 4                           มั่นใจ     6050000            5000000.0
# 6                           มั่นใจ     4400000            3500000.0
# 8                           มั่นใจ     2750000            2500000.0
# ...                            ...         ...                  ...
# 1211                        มั่นใจ      260000             550000.0
# 1213                        มั่นใจ      610000             700000.0
# 1215                        มั่นใจ      295000             500000.0
# 1217                        มั่นใจ      615000             600000.0
# 1219                        มั่นใจ      620000             750000.0
#
#                          ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0                                          5,000-15,000
# 2                                          5,000-15,000
# 4                                          5,000-15,000
# 6                                          5,000-18,000
# 8                                          5,000-25,000
# ...                                                 ...
# 1211  เพื่อป้องกันปัญหาที่อาจเกิดขึ้นภายหลังหากต้องม...
# 1213  เพื่อป้องกันปัญหาที่อาจเกิดขึ้นภายหลังหากต้องม...
# 1215  เพื่อป้องกันปัญหาที่อาจเกิดขึ้นภายหลังหากต้องม...
# 1217  เพื่อป้องกันปัญหาที่อาจเกิดขึ้นภายหลังหากต้องม...
# 1219  เพื่อป้องกันปัญหาที่อาจเกิดขึ้นภายหลังหากต้องม...
#
#      เหตุผลไม่มั่นใจราคาประเมิน                      ให้คะแนนทรัพย์
# 0                           NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 2                           NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 4                           NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 6                           NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 8                           NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# ...                         ...                                 ...
# 1211                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 1213                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 1215                        NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 1217                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 1219                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
#
# [610 rows x 9 columns]

# %%
est1.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย
# count          610.0  6.100000e+02         6.090000e+02
# mean             1.0  3.382782e+06         3.240345e+06
# std              0.0  5.000758e+06         4.692873e+06
# min              1.0  2.600000e+05         2.200000e+05
# 25%              1.0  1.492500e+06         1.500000e+06
# 50%              1.0  2.540000e+06         2.500000e+06
# 75%              1.0  4.000000e+06         4.000000e+06
# max              1.0  1.039350e+08         1.000000e+08

# %%
est1['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ    610
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %%
est1['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     476
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี    126
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน        6
# 1 ขายไม่ได้แน่นอน                       2
# Name: ให้คะแนนทรัพย์, dtype: int64

# %%
est2 = house[house['ID ผู้ประเมิน']==2]
est2
# Out:
#       ID ผู้ประเมิน                               post id property_type  \
# 1                 2    https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3                 2    https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5                 2   https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7                 2   https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9                 2   https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ...             ...                                   ...           ...
# 1210              2  https://nayoo.co/khonkaen/posts/6255    บ้านเดี่ยว
# 1212              2  https://nayoo.co/khonkaen/posts/6256    บ้านเดี่ยว
# 1214              2  https://nayoo.co/khonkaen/posts/6257    บ้านเดี่ยว
# 1216              2  https://nayoo.co/khonkaen/posts/6258    บ้านเดี่ยว
# 1218              2  https://nayoo.co/khonkaen/posts/6260    บ้านเดี่ยว
#
#      ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                           มั่นใจ     2890000            2700000.0
# 3                           มั่นใจ     2600000            2400000.0
# 5                           มั่นใจ     6050000            9000000.0
# 7                           มั่นใจ     4400000            3700000.0
# 9                           มั่นใจ     2750000            2500000.0
# ...                            ...         ...                  ...
# 1210                        มั่นใจ      260000             300000.0
# 1212                        มั่นใจ      610000             500000.0
# 1214                        มั่นใจ      295000             300000.0
# 1216                        มั่นใจ      615000             500000.0
# 1218                        มั่นใจ      620000             700000.0
#
#                          ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 1     โครงการนี้ราคาเสนอขาย 2,500,000-3,000,000 บาท/...
# 3      ราคาเสนอขายประมาณ 2,200,000 - 2,500,000 บาท/หลัง
# 5     โซนนี้ราคาซื้อขาย ประมาณ 10,000-20,000 บาท/ตาร...
# 7                เสนอขาย 3,500,000 - 4,200,000 บาท/หลัง
# 9           ราคาเสนอขาย 2,000,0000 - 2,800,000 บาท/หลัง
# ...                                                 ...
# 1210                     ราคาเสนอขาย 2-3 พันบาท/ตารางวา
# 1212                     ราคาเสนอขาย 4-6 พันบาท/ตารางวา
# 1214                     ราคาเสนอขาย 1-2 พันบาท/ตารางวา
# 1216                     ราคาเสนอขาย 3-5 พันบาท/ตารางวา
# 1218                     ราคาเสนอขาย 4-5 พันบาท/ตารางวา
#
#      เหตุผลไม่มั่นใจราคาประเมิน                     ให้คะแนนทรัพย์
# 1                           NaN   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน
# 3                           NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 5                           NaN  5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน
# 7                           NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 9                           NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# ...                         ...                                ...
# 1210                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 1212                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 1214                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 1216                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 1218                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
#
# [610 rows x 9 columns]

# %%
est2.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย
# count          610.0  6.100000e+02         4.980000e+02
# mean             2.0  3.369097e+06         3.449197e+06
# std              0.0  4.975575e+06         4.381048e+06
# min              2.0  2.600000e+05         2.500000e+05
# 25%              2.0  1.467500e+06         1.892500e+06
# 50%              2.0  2.530000e+06         2.600000e+06
# 75%              2.0  4.067500e+06         4.200000e+06
# max              2.0  1.039350e+08         8.000000e+07

# %%
est2['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ       499
# ไม่มั่นใจ    111
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %%
est2['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     367
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน      117
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี     14
# 5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน       1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %% [markdown]
# # HW1 เปรียบเทียบความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของนักประเมินแต่ละคนและของราคาตั้งขาย ใช้ MAPE เป็นเกณฑ์ในการเปรียบเทียบ

# %%
from sklearn.metrics import mean_absolute_percentage_error as mape

# %% [markdown]
# ##บ้านเดี่ยว

# %%
house
# Out:
#       ID ผู้ประเมิน                               post id property_type  \
# 0                 1    https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 1                 2    https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2                 1    https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 3                 2    https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4                 1   https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# ...             ...                                   ...           ...
# 1215              1  https://nayoo.co/khonkaen/posts/6257    บ้านเดี่ยว
# 1216              2  https://nayoo.co/khonkaen/posts/6258    บ้านเดี่ยว
# 1217              1  https://nayoo.co/khonkaen/posts/6258    บ้านเดี่ยว
# 1218              2  https://nayoo.co/khonkaen/posts/6260    บ้านเดี่ยว
# 1219              1  https://nayoo.co/khonkaen/posts/6260    บ้านเดี่ยว
#
#      ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                           มั่นใจ     2890000            2500000.0
# 1                           มั่นใจ     2890000            2700000.0
# 2                           มั่นใจ     2600000            2200000.0
# 3                           มั่นใจ     2600000            2400000.0
# 4                           มั่นใจ     6050000            5000000.0
# ...                            ...         ...                  ...
# 1215                        มั่นใจ      295000             500000.0
# 1216                        มั่นใจ      615000             500000.0
# 1217                        มั่นใจ      615000             600000.0
# 1218                        มั่นใจ      620000             700000.0
# 1219                        มั่นใจ      620000             750000.0
#
#                          ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0                                          5,000-15,000
# 1     โครงการนี้ราคาเสนอขาย 2,500,000-3,000,000 บาท/...
# 2                                          5,000-15,000
# 3      ราคาเสนอขายประมาณ 2,200,000 - 2,500,000 บาท/หลัง
# 4                                          5,000-15,000
# ...                                                 ...
# 1215  เพื่อป้องกันปัญหาที่อาจเกิดขึ้นภายหลังหากต้องม...
# 1216                     ราคาเสนอขาย 3-5 พันบาท/ตารางวา
# 1217  เพื่อป้องกันปัญหาที่อาจเกิดขึ้นภายหลังหากต้องม...
# 1218                     ราคาเสนอขาย 4-5 พันบาท/ตารางวา
# 1219  เพื่อป้องกันปัญหาที่อาจเกิดขึ้นภายหลังหากต้องม...
#
#      เหตุผลไม่มั่นใจราคาประเมิน                      ให้คะแนนทรัพย์
# 0                           NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 1                           NaN    4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน
# 2                           NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 3                           NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 4                           NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# ...                         ...                                 ...
# 1215                        NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 1216                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 1217                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 1218                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 1219                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
#
# [1220 rows x 9 columns]

# %%
est1_nodup = est1.drop_duplicates(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
est2_nodup = est2.drop_duplicates(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])

# %%
est2['ประเมิน1'] = est2['post id'].map(est1_nodup.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
est2
# Out:
# <ipython-input-16-44312c38cc6f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   est2['ประเมิน1'] = est2['post id'].map(est1_nodup.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#       ID ผู้ประเมิน                               post id property_type  \
# 1                 2    https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3                 2    https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5                 2   https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7                 2   https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9                 2   https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ...             ...                                   ...           ...
# 1210              2  https://nayoo.co/khonkaen/posts/6255    บ้านเดี่ยว
# 1212              2  https://nayoo.co/khonkaen/posts/6256    บ้านเดี่ยว
# 1214              2  https://nayoo.co/khonkaen/posts/6257    บ้านเดี่ยว
# 1216              2  https://nayoo.co/khonkaen/posts/6258    บ้านเดี่ยว
# 1218              2  https://nayoo.co/khonkaen/posts/6260    บ้านเดี่ยว
#
#      ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                           มั่นใจ     2890000            2700000.0
# 3                           มั่นใจ     2600000            2400000.0
# 5                           มั่นใจ     6050000            9000000.0
# 7                           มั่นใจ     4400000            3700000.0
# 9                           มั่นใจ     2750000            2500000.0
# ...                            ...         ...                  ...
# 1210                        มั่นใจ      260000             300000.0
# 1212                        มั่นใจ      610000             500000.0
# 1214                        มั่นใจ      295000             300000.0
# 1216                        มั่นใจ      615000             500000.0
# 1218                        มั่นใจ      620000             700000.0
#
#                          ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 1     โครงการนี้ราคาเสนอขาย 2,500,000-3,000,000 บาท/...
# 3      ราคาเสนอขายประมาณ 2,200,000 - 2,500,000 บาท/หลัง
# 5     โซนนี้ราคาซื้อขาย ประมาณ 10,000-20,000 บาท/ตาร...
# 7                เสนอขาย 3,500,000 - 4,200,000 บาท/หลัง
# 9           ราคาเสนอขาย 2,000,0000 - 2,800,000 บาท/หลัง
# ...                                                 ...
# 1210                     ราคาเสนอขาย 2-3 พันบาท/ตารางวา
# 1212                     ราคาเสนอขาย 4-6 พันบาท/ตารางวา
# 1214                     ราคาเสนอขาย 1-2 พันบาท/ตารางวา
# 1216                     ราคาเสนอขาย 3-5 พันบาท/ตารางวา
# 1218                     ราคาเสนอขาย 4-5 พันบาท/ตารางวา
#
#      เหตุผลไม่มั่นใจราคาประเมิน                     ให้คะแนนทรัพย์   ประเมิน1
# 1                           NaN   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน  2500000.0
# 3                           NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน  2200000.0
# 5                           NaN  5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน  5000000.0
# 7                           NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน  3500000.0
# 9                           NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน  2500000.0
# ...                         ...                                ...        ...
# 1210                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน   550000.0
# 1212                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน   700000.0
# 1214                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน   500000.0
# 1216                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน   600000.0
# 1218                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน   750000.0
#
# [610 rows x 10 columns]

# %%
est2['ประเมิน2'] = est2['post id'].map(est2_nodup.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
est2
# Out:
# <ipython-input-17-4ed808a4edab>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   est2['ประเมิน2'] = est2['post id'].map(est2_nodup.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#       ID ผู้ประเมิน                               post id property_type  \
# 1                 2    https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3                 2    https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5                 2   https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7                 2   https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9                 2   https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ...             ...                                   ...           ...
# 1210              2  https://nayoo.co/khonkaen/posts/6255    บ้านเดี่ยว
# 1212              2  https://nayoo.co/khonkaen/posts/6256    บ้านเดี่ยว
# 1214              2  https://nayoo.co/khonkaen/posts/6257    บ้านเดี่ยว
# 1216              2  https://nayoo.co/khonkaen/posts/6258    บ้านเดี่ยว
# 1218              2  https://nayoo.co/khonkaen/posts/6260    บ้านเดี่ยว
#
#      ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                           มั่นใจ     2890000            2700000.0
# 3                           มั่นใจ     2600000            2400000.0
# 5                           มั่นใจ     6050000            9000000.0
# 7                           มั่นใจ     4400000            3700000.0
# 9                           มั่นใจ     2750000            2500000.0
# ...                            ...         ...                  ...
# 1210                        มั่นใจ      260000             300000.0
# 1212                        มั่นใจ      610000             500000.0
# 1214                        มั่นใจ      295000             300000.0
# 1216                        มั่นใจ      615000             500000.0
# 1218                        มั่นใจ      620000             700000.0
#
#                          ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 1     โครงการนี้ราคาเสนอขาย 2,500,000-3,000,000 บาท/...
# 3      ราคาเสนอขายประมาณ 2,200,000 - 2,500,000 บาท/หลัง
# 5     โซนนี้ราคาซื้อขาย ประมาณ 10,000-20,000 บาท/ตาร...
# 7                เสนอขาย 3,500,000 - 4,200,000 บาท/หลัง
# 9           ราคาเสนอขาย 2,000,0000 - 2,800,000 บาท/หลัง
# ...                                                 ...
# 1210                     ราคาเสนอขาย 2-3 พันบาท/ตารางวา
# 1212                     ราคาเสนอขาย 4-6 พันบาท/ตารางวา
# 1214                     ราคาเสนอขาย 1-2 พันบาท/ตารางวา
# 1216                     ราคาเสนอขาย 3-5 พันบาท/ตารางวา
# 1218                     ราคาเสนอขาย 4-5 พันบาท/ตารางวา
#
#      เหตุผลไม่มั่นใจราคาประเมิน                     ให้คะแนนทรัพย์   ประเมิน1  \
# 1                           NaN   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน  2500000.0
# 3                           NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน  2200000.0
# 5                           NaN  5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน  5000000.0
# 7                           NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน  3500000.0
# 9                           NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน  2500000.0
# ...                         ...                                ...        ...
# 1210                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน   550000.0
# 1212                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน   700000.0
# 1214                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน   500000.0
# 1216                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน   600000.0
# 1218                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน   750000.0
#
#        ประเมิน2
# 1     2700000.0
# 3     2400000.0
# 5     9000000.0
# 7     3700000.0
# 9     2500000.0
# ...         ...
# 1210   300000.0
# 1212   500000.0
# 1214   300000.0
# 1216   500000.0
# 1218   700000.0
#
# [610 rows x 11 columns]

# %%
house1 = est2[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2','ให้คะแนนทรัพย์','ความมั่นใจในการเมินราคาทรัพย์']]
house1
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 1       https://nayoo.co/khonkaen/posts/25     2890000  2500000.0  2700000.0
# 3       https://nayoo.co/khonkaen/posts/33     2600000  2200000.0  2400000.0
# 5      https://nayoo.co/khonkaen/posts/495     6050000  5000000.0  9000000.0
# 7      https://nayoo.co/khonkaen/posts/564     4400000  3500000.0  3700000.0
# 9      https://nayoo.co/khonkaen/posts/566     2750000  2500000.0  2500000.0
# ...                                    ...         ...        ...        ...
# 1210  https://nayoo.co/khonkaen/posts/6255      260000   550000.0   300000.0
# 1212  https://nayoo.co/khonkaen/posts/6256      610000   700000.0   500000.0
# 1214  https://nayoo.co/khonkaen/posts/6257      295000   500000.0   300000.0
# 1216  https://nayoo.co/khonkaen/posts/6258      615000   600000.0   500000.0
# 1218  https://nayoo.co/khonkaen/posts/6260      620000   750000.0   700000.0
#
#                          ให้คะแนนทรัพย์ ความมั่นใจในการเมินราคาทรัพย์
# 1      4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                        มั่นใจ
# 3     3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 5     5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน                        มั่นใจ
# 7     3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 9     3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# ...                                 ...                           ...
# 1210  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 1212  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 1214  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 1216  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 1218  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
#
# [610 rows x 6 columns]

# %%
house1.isnull()
# Out:
#       post id  ราคาทรัพย์  ประเมิน1  ประเมิน2  ให้คะแนนทรัพย์  \
# 1       False       False     False     False           False
# 3       False       False     False     False           False
# 5       False       False     False     False           False
# 7       False       False     False     False           False
# 9       False       False     False     False           False
# ...       ...         ...       ...       ...             ...
# 1210    False       False     False     False           False
# 1212    False       False     False     False           False
# 1214    False       False     False     False           False
# 1216    False       False     False     False           False
# 1218    False       False     False     False           False
#
#       ความมั่นใจในการเมินราคาทรัพย์
# 1                             False
# 3                             False
# 5                             False
# 7                             False
# 9                             False
# ...                             ...
# 1210                          False
# 1212                          False
# 1214                          False
# 1216                          False
# 1218                          False
#
# [610 rows x 6 columns]

# %% [markdown]
# สรุป
# จะเห็นว่าค่า MAPE ที่ประเมินโดยคนที่ 2 มีค่าน้อยกว่าคนที่ 1
#
# ดังนั้น การประเมินโดยคนที่ 2 มีการประเมินราคาซื้อ-ขาย ได้ใกล้เคียงกับราคาทรัพย์ มากกว่าผู้ประเมินคนที่ 1

# %% [markdown]
# ##ที่ดิน

# %%
land
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 1                2   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 2                4   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 3                1   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 4                2   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# ..             ...                                    ...           ...
# 205              1  https://nayoo.co/khonkaen/posts/17093        ที่ดิน
# 206              2  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 207              1  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 208              2  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
# 209              1  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                          มั่นใจ     2800000            1800000.0
# 1                          มั่นใจ     2800000            2000000.0
# 2                          มั่นใจ     2800000            2200000.0
# 3                          มั่นใจ    14900000            8000000.0
# 4                          มั่นใจ    14900000           12000000.0
# ..                            ...         ...                  ...
# 205                        มั่นใจ     2650000            2000000.0
# 206                        มั่นใจ     1300000            1500000.0
# 207                        มั่นใจ     1300000            1500000.0
# 208                        มั่นใจ     3000000            2800000.0
# 209                        มั่นใจ     3000000            2500000.0
#
#               ปัจจัยในการประเมินราคาซื้อ-ขาย เหตุผลไม่มั่นใจราคาประเมิน  \
# 0                               8,000-25,000                        NaN
# 1      ราคาเสนอขาย 7,000-12,0000 บาท/ตารางวา                        NaN
# 2                                10000-22000                        NaN
# 3                              25,000-80,000                        NaN
# 4    ราคาเสนอขาย 100,000-150,000 บาท/ตารางวา                        NaN
# ..                                       ...                        ...
# 205                   500-15,000 บาท/ตารางวา                        NaN
# 206    ราคาเสนอขาย 3,000 - 5,000 บาท/ตารางวา                        NaN
# 207                   500-25,000 บาท/ตารางวา                        NaN
# 208  ราคาเสนอขาย 10,000 - 15,000 บาท/ตารางวา                        NaN
# 209                 1,000-25,000 บาท/ตารางวา                        NaN
#
#                          ให้คะแนนทรัพย์
# 0     3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 1    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 2    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 3    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 4    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# ..                                  ...
# 205  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 206   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 207   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 208  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 209   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
#
# [210 rows x 9 columns]

# %%
est1_land = land[land['ID ผู้ประเมิน']==1]
est1_land
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 3                1   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 6                1   https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 9                1   https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 12               1   https://nayoo.co/khonkaen/posts/1866        ที่ดิน
# ..             ...                                    ...           ...
# 201              1  https://nayoo.co/khonkaen/posts/14539        ที่ดิน
# 203              1  https://nayoo.co/khonkaen/posts/16072        ที่ดิน
# 205              1  https://nayoo.co/khonkaen/posts/17093        ที่ดิน
# 207              1  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 209              1  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                          มั่นใจ     2800000            1800000.0
# 3                          มั่นใจ    14900000            8000000.0
# 6                          มั่นใจ    90000000           18000000.0
# 9                          มั่นใจ    65000000           35000000.0
# 12                         มั่นใจ     3000000            2200000.0
# ..                            ...         ...                  ...
# 201                        มั่นใจ     5000000            4000000.0
# 203                        มั่นใจ      750000             500000.0
# 205                        มั่นใจ     2650000            2000000.0
# 207                        มั่นใจ     1300000            1500000.0
# 209                        มั่นใจ     3000000            2500000.0
#
#     ปัจจัยในการประเมินราคาซื้อ-ขาย เหตุผลไม่มั่นใจราคาประเมิน  \
# 0                     8,000-25,000                        NaN
# 3                    25,000-80,000                        NaN
# 6                     8,000-35,000                        NaN
# 9                    15,000-50,000                        NaN
# 12                   10,000-20,000                        NaN
# ..                             ...                        ...
# 201         800-25,000 บาท/ตารางวา                        NaN
# 203       3,000-25,000 บาท/ตารางวา                        NaN
# 205         500-15,000 บาท/ตารางวา                        NaN
# 207         500-25,000 บาท/ตารางวา                        NaN
# 209       1,000-25,000 บาท/ตารางวา                        NaN
#
#                          ให้คะแนนทรัพย์
# 0     3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 3    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 6    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 9    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 12    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# ..                                  ...
# 201   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 203  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 205  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 207   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 209   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
#
# [100 rows x 9 columns]

# %%
est2_land = land[land['ID ผู้ประเมิน']==2]
est2_land
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 4                2   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 7                2   https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 10               2   https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 13               2   https://nayoo.co/khonkaen/posts/1866        ที่ดิน
# ..             ...                                    ...           ...
# 200              2  https://nayoo.co/khonkaen/posts/14539        ที่ดิน
# 202              2  https://nayoo.co/khonkaen/posts/16072        ที่ดิน
# 204              2  https://nayoo.co/khonkaen/posts/17093        ที่ดิน
# 206              2  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 208              2  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                          มั่นใจ     2800000            2000000.0
# 4                          มั่นใจ    14900000           12000000.0
# 7                          มั่นใจ    90000000           70000000.0
# 10                         มั่นใจ    65000000           60000000.0
# 13                         มั่นใจ     3000000            2500000.0
# ..                            ...         ...                  ...
# 200                        มั่นใจ     5000000            4000000.0
# 202                        มั่นใจ      750000             750000.0
# 204                        มั่นใจ     2650000            2500000.0
# 206                        มั่นใจ     1300000            1500000.0
# 208                        มั่นใจ     3000000            2800000.0
#
#               ปัจจัยในการประเมินราคาซื้อ-ขาย เหตุผลไม่มั่นใจราคาประเมิน  \
# 1      ราคาเสนอขาย 7,000-12,0000 บาท/ตารางวา                        NaN
# 4    ราคาเสนอขาย 100,000-150,000 บาท/ตารางวา                        NaN
# 7                  30,000-40,000 บาท/ตารางวา                        NaN
# 10   ราคาเสนอขาย 12,000 - 15,000 บาท/ตารางวา                        NaN
# 13     ราคาเสนอขาย 2,000 - 4,000 บาท/ตารางวา                        NaN
# ..                                       ...                        ...
# 200   ราคาเสนอขาย 8,000 - 10,000 บาท/ตารางวา                        NaN
# 202      ราคาเสนอขาย 7,000-8,000 บาท/ตารางวา                        NaN
# 204    ราคาเสนอขาย 3,000 - 5,000 บาท/ตารางวา                        NaN
# 206    ราคาเสนอขาย 3,000 - 5,000 บาท/ตารางวา                        NaN
# 208  ราคาเสนอขาย 10,000 - 15,000 บาท/ตารางวา                        NaN
#
#                          ให้คะแนนทรัพย์
# 1    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 4    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 7    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 10   2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 13    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# ..                                  ...
# 200  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 202   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 204  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 206   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 208  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
#
# [100 rows x 9 columns]

# %%
est2_land['ประเมิน1'] = est2_land['post id'].map(est1_land.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
est2_land
# Out:
# <ipython-input-23-b8edd99a73ba>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   est2_land['ประเมิน1'] = est2_land['post id'].map(est1_land.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 4                2   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 7                2   https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 10               2   https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 13               2   https://nayoo.co/khonkaen/posts/1866        ที่ดิน
# ..             ...                                    ...           ...
# 200              2  https://nayoo.co/khonkaen/posts/14539        ที่ดิน
# 202              2  https://nayoo.co/khonkaen/posts/16072        ที่ดิน
# 204              2  https://nayoo.co/khonkaen/posts/17093        ที่ดิน
# 206              2  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 208              2  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                          มั่นใจ     2800000            2000000.0
# 4                          มั่นใจ    14900000           12000000.0
# 7                          มั่นใจ    90000000           70000000.0
# 10                         มั่นใจ    65000000           60000000.0
# 13                         มั่นใจ     3000000            2500000.0
# ..                            ...         ...                  ...
# 200                        มั่นใจ     5000000            4000000.0
# 202                        มั่นใจ      750000             750000.0
# 204                        มั่นใจ     2650000            2500000.0
# 206                        มั่นใจ     1300000            1500000.0
# 208                        มั่นใจ     3000000            2800000.0
#
#               ปัจจัยในการประเมินราคาซื้อ-ขาย เหตุผลไม่มั่นใจราคาประเมิน  \
# 1      ราคาเสนอขาย 7,000-12,0000 บาท/ตารางวา                        NaN
# 4    ราคาเสนอขาย 100,000-150,000 บาท/ตารางวา                        NaN
# 7                  30,000-40,000 บาท/ตารางวา                        NaN
# 10   ราคาเสนอขาย 12,000 - 15,000 บาท/ตารางวา                        NaN
# 13     ราคาเสนอขาย 2,000 - 4,000 บาท/ตารางวา                        NaN
# ..                                       ...                        ...
# 200   ราคาเสนอขาย 8,000 - 10,000 บาท/ตารางวา                        NaN
# 202      ราคาเสนอขาย 7,000-8,000 บาท/ตารางวา                        NaN
# 204    ราคาเสนอขาย 3,000 - 5,000 บาท/ตารางวา                        NaN
# 206    ราคาเสนอขาย 3,000 - 5,000 บาท/ตารางวา                        NaN
# 208  ราคาเสนอขาย 10,000 - 15,000 บาท/ตารางวา                        NaN
#
#                          ให้คะแนนทรัพย์    ประเมิน1
# 1    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี   1800000.0
# 4    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี   8000000.0
# 7    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี  18000000.0
# 10   2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี  35000000.0
# 13    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน   2200000.0
# ..                                  ...         ...
# 200  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี   4000000.0
# 202   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน    500000.0
# 204  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี   2000000.0
# 206   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน   1500000.0
# 208  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี   2500000.0
#
# [100 rows x 10 columns]

# %%
est2_land['ประเมิน2'] = est2_land['post id'].map(est2_land.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
est2_land
# Out:
# <ipython-input-24-83d4628773b1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   est2_land['ประเมิน2'] = est2_land['post id'].map(est2_land.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 4                2   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 7                2   https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 10               2   https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 13               2   https://nayoo.co/khonkaen/posts/1866        ที่ดิน
# ..             ...                                    ...           ...
# 200              2  https://nayoo.co/khonkaen/posts/14539        ที่ดิน
# 202              2  https://nayoo.co/khonkaen/posts/16072        ที่ดิน
# 204              2  https://nayoo.co/khonkaen/posts/17093        ที่ดิน
# 206              2  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 208              2  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                          มั่นใจ     2800000            2000000.0
# 4                          มั่นใจ    14900000           12000000.0
# 7                          มั่นใจ    90000000           70000000.0
# 10                         มั่นใจ    65000000           60000000.0
# 13                         มั่นใจ     3000000            2500000.0
# ..                            ...         ...                  ...
# 200                        มั่นใจ     5000000            4000000.0
# 202                        มั่นใจ      750000             750000.0
# 204                        มั่นใจ     2650000            2500000.0
# 206                        มั่นใจ     1300000            1500000.0
# 208                        มั่นใจ     3000000            2800000.0
#
#               ปัจจัยในการประเมินราคาซื้อ-ขาย เหตุผลไม่มั่นใจราคาประเมิน  \
# 1      ราคาเสนอขาย 7,000-12,0000 บาท/ตารางวา                        NaN
# 4    ราคาเสนอขาย 100,000-150,000 บาท/ตารางวา                        NaN
# 7                  30,000-40,000 บาท/ตารางวา                        NaN
# 10   ราคาเสนอขาย 12,000 - 15,000 บาท/ตารางวา                        NaN
# 13     ราคาเสนอขาย 2,000 - 4,000 บาท/ตารางวา                        NaN
# ..                                       ...                        ...
# 200   ราคาเสนอขาย 8,000 - 10,000 บาท/ตารางวา                        NaN
# 202      ราคาเสนอขาย 7,000-8,000 บาท/ตารางวา                        NaN
# 204    ราคาเสนอขาย 3,000 - 5,000 บาท/ตารางวา                        NaN
# 206    ราคาเสนอขาย 3,000 - 5,000 บาท/ตารางวา                        NaN
# 208  ราคาเสนอขาย 10,000 - 15,000 บาท/ตารางวา                        NaN
#
#                          ให้คะแนนทรัพย์    ประเมิน1    ประเมิน2
# 1    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี   1800000.0   2000000.0
# 4    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี   8000000.0  12000000.0
# 7    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี  18000000.0  70000000.0
# 10   2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี  35000000.0  60000000.0
# 13    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน   2200000.0   2500000.0
# ..                                  ...         ...         ...
# 200  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี   4000000.0   4000000.0
# 202   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน    500000.0    750000.0
# 204  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี   2000000.0   2500000.0
# 206   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน   1500000.0   1500000.0
# 208  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี   2500000.0   2800000.0
#
# [100 rows x 11 columns]

# %%
land1 = est2_land[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2','ให้คะแนนทรัพย์','ความมั่นใจในการเมินราคาทรัพย์']]
land1
# Out:
#                                    post id  ราคาทรัพย์    ประเมิน1  \
# 1     https://nayoo.co/khonkaen/posts/1033     2800000   1800000.0
# 4     https://nayoo.co/khonkaen/posts/1711    14900000   8000000.0
# 7     https://nayoo.co/khonkaen/posts/1726    90000000  18000000.0
# 10    https://nayoo.co/khonkaen/posts/1732    65000000  35000000.0
# 13    https://nayoo.co/khonkaen/posts/1866     3000000   2200000.0
# ..                                     ...         ...         ...
# 200  https://nayoo.co/khonkaen/posts/14539     5000000   4000000.0
# 202  https://nayoo.co/khonkaen/posts/16072      750000    500000.0
# 204  https://nayoo.co/khonkaen/posts/17093     2650000   2000000.0
# 206  https://nayoo.co/khonkaen/posts/17112     1300000   1500000.0
# 208  https://nayoo.co/khonkaen/posts/17145     3000000   2500000.0
#
#        ประเมิน2                      ให้คะแนนทรัพย์  \
# 1     2000000.0  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 4    12000000.0  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 7    70000000.0  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 10   60000000.0  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 13    2500000.0   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# ..          ...                                 ...
# 200   4000000.0  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 202    750000.0   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 204   2500000.0  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 206   1500000.0   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 208   2800000.0  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
#
#     ความมั่นใจในการเมินราคาทรัพย์
# 1                          มั่นใจ
# 4                          มั่นใจ
# 7                          มั่นใจ
# 10                         มั่นใจ
# 13                         มั่นใจ
# ..                            ...
# 200                        มั่นใจ
# 202                        มั่นใจ
# 204                        มั่นใจ
# 206                        มั่นใจ
# 208                        มั่นใจ
#
# [100 rows x 6 columns]

# %%
land1 = land1.fillna(value={'ประเมิน2':est2_land['ประเมิน2'].mean()})
land1
# Out:
#                                    post id  ราคาทรัพย์    ประเมิน1  \
# 1     https://nayoo.co/khonkaen/posts/1033     2800000   1800000.0
# 4     https://nayoo.co/khonkaen/posts/1711    14900000   8000000.0
# 7     https://nayoo.co/khonkaen/posts/1726    90000000  18000000.0
# 10    https://nayoo.co/khonkaen/posts/1732    65000000  35000000.0
# 13    https://nayoo.co/khonkaen/posts/1866     3000000   2200000.0
# ..                                     ...         ...         ...
# 200  https://nayoo.co/khonkaen/posts/14539     5000000   4000000.0
# 202  https://nayoo.co/khonkaen/posts/16072      750000    500000.0
# 204  https://nayoo.co/khonkaen/posts/17093     2650000   2000000.0
# 206  https://nayoo.co/khonkaen/posts/17112     1300000   1500000.0
# 208  https://nayoo.co/khonkaen/posts/17145     3000000   2500000.0
#
#        ประเมิน2                      ให้คะแนนทรัพย์  \
# 1     2000000.0  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 4    12000000.0  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 7    70000000.0  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 10   60000000.0  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 13    2500000.0   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# ..          ...                                 ...
# 200   4000000.0  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 202    750000.0   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 204   2500000.0  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 206   1500000.0   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 208   2800000.0  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
#
#     ความมั่นใจในการเมินราคาทรัพย์
# 1                          มั่นใจ
# 4                          มั่นใจ
# 7                          มั่นใจ
# 10                         มั่นใจ
# 13                         มั่นใจ
# ..                            ...
# 200                        มั่นใจ
# 202                        มั่นใจ
# 204                        มั่นใจ
# 206                        มั่นใจ
# 208                        มั่นใจ
#
# [100 rows x 6 columns]

# %%
land1.isnull()
# Out:
#      post id  ราคาทรัพย์  ประเมิน1  ประเมิน2  ให้คะแนนทรัพย์  \
# 1      False       False     False     False           False
# 4      False       False     False     False           False
# 7      False       False     False     False           False
# 10     False       False     False     False           False
# 13     False       False     False     False           False
# ..       ...         ...       ...       ...             ...
# 200    False       False     False     False           False
# 202    False       False     False     False           False
# 204    False       False     False     False           False
# 206    False       False     False     False           False
# 208    False       False     False     False           False
#
#      ความมั่นใจในการเมินราคาทรัพย์
# 1                            False
# 4                            False
# 7                            False
# 10                           False
# 13                           False
# ..                             ...
# 200                          False
# 202                          False
# 204                          False
# 206                          False
# 208                          False
#
# [100 rows x 6 columns]

# %%
price2 = land1['ราคาทรัพย์']
p_est1_land = land1['ประเมิน1']
ma02 = mape(price2, p_est1_land)

# %%
p_est2_land = land1['ประเมิน2']
ma002 = mape(price2, p_est2_land)
mape2 = mape(p_est2_land,p_est1_land)

# %%
mape2
# Out:
# 0.42747750827626985

# %%
print(f'ค่า MAPE ผู้ประเมินคนที่ 1 เท่ากับ {ma02} \nค่า MAPE ผู้ประเมินคนที่ 2 เท่ากับ {ma002}')
# Out:
# ค่า MAPE ผู้ประเมินคนที่ 1 เท่ากับ 0.4083141479071181
# ค่า MAPE ผู้ประเมินคนที่ 2 เท่ากับ 0.3955633058050656

# %% [markdown]
# สรุป
# จะเห็นว่าค่า MAPE ที่ประเมินโดยคนที่ 2 มีค่าน้อยกว่าคนที่ 1
#
# ดังนั้น การประเมินโดยคนที่ 2 มีการประเมินราคาซื้อ-ขาย ได้ใกล้เคียงกับราคาทรัพย์ มากกว่าผู้ประเมินคนที่ 1

# %% [markdown]
# ##คอนโด

# %%
condo
# Out:
#    ID ผู้ประเมิน  post id property_type ความมั่นใจในการเมินราคาทรัพย์  \
# 0              1     32.0         คอนโด                        มั่นใจ
# 1              1     36.0         คอนโด                        มั่นใจ
# 2              1    603.0         คอนโด                        มั่นใจ
# 3              1   1395.0         คอนโด                        มั่นใจ
# 4              1   1443.0         คอนโด                        มั่นใจ
# 5              1   1609.0         คอนโด                        มั่นใจ
# 6              1   1640.0         คอนโด                        มั่นใจ
# 7              1   1641.0         คอนโด                        มั่นใจ
# 8              1   1650.0         คอนโด                        มั่นใจ
# 9              1   1840.0         คอนโด                        มั่นใจ
#
#    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0     3500000            3500000.0   60,000-130,000 บาท/ตารางเมตร
# 1     1930000            2200000.0    50,000-90,000 บาท/ตารางเมตร
# 2     2438000            2800000.0    35,000-80,000 บาท/ตารางเมตร
# 3     1600000            2300000.0    30,000-80,000 บาท/ตารางเมตร
# 4     1860000            1800000.0    30,000-80,000 บาท/ตารางเมตร
# 5     1490000            1500000.0    30,000-80,000 บาท/ตารางเมตร
# 6     1280000            1600000.0    30,000-70,000 บาท/ตารางเมตร
# 7     4290000            2700000.0   60,000-130,000 บาท/ตารางเมตร
# 8     1700000            1550000.0    30,000-70,000 บาท/ตารางเมตร
# 9     3790000            2800000.0    30,000-80,000 บาท/ตารางเมตร
#
#    เหตุผลไม่มั่นใจราคาประเมิน                     ให้คะแนนทรัพย์  Unnamed: 9  \
# 0                         NaN   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         4.0
# 1                         NaN   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         4.0
# 2                         NaN   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         4.0
# 3                         NaN   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         4.0
# 4                         NaN   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         4.0
# 5                         NaN   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         4.0
# 6                         NaN   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         4.0
# 7                         NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         3.0
# 8                         NaN   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         4.0
# 9                         NaN   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         4.0
#
#                         Unnamed: 10
# 0  ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 1  ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 2  ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 3  ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 4  ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 5  ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 6  ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 7     ขายได้ ใช้ระยะเวลา 7-12 เดือน
# 8  ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 9  ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี

# %%
est1_condo = condo[condo['ID ผู้ประเมิน']==1]
est1_condo
# Out:
#    ID ผู้ประเมิน  post id property_type ความมั่นใจในการเมินราคาทรัพย์  \
# 0              1     32.0         คอนโด                        มั่นใจ
# 1              1     36.0         คอนโด                        มั่นใจ
# 2              1    603.0         คอนโด                        มั่นใจ
# 3              1   1395.0         คอนโด                        มั่นใจ
# 4              1   1443.0         คอนโด                        มั่นใจ
# 5              1   1609.0         คอนโด                        มั่นใจ
# 6              1   1640.0         คอนโด                        มั่นใจ
# 7              1   1641.0         คอนโด                        มั่นใจ
# 8              1   1650.0         คอนโด                        มั่นใจ
# 9              1   1840.0         คอนโด                        มั่นใจ
#
#    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0     3500000            3500000.0   60,000-130,000 บาท/ตารางเมตร
# 1     1930000            2200000.0    50,000-90,000 บาท/ตารางเมตร
# 2     2438000            2800000.0    35,000-80,000 บาท/ตารางเมตร
# 3     1600000            2300000.0    30,000-80,000 บาท/ตารางเมตร
# 4     1860000            1800000.0    30,000-80,000 บาท/ตารางเมตร
# 5     1490000            1500000.0    30,000-80,000 บาท/ตารางเมตร
# 6     1280000            1600000.0    30,000-70,000 บาท/ตารางเมตร
# 7     4290000            2700000.0   60,000-130,000 บาท/ตารางเมตร
# 8     1700000            1550000.0    30,000-70,000 บาท/ตารางเมตร
# 9     3790000            2800000.0    30,000-80,000 บาท/ตารางเมตร
#
#    เหตุผลไม่มั่นใจราคาประเมิน                     ให้คะแนนทรัพย์  Unnamed: 9  \
# 0                         NaN   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         4.0
# 1                         NaN   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         4.0
# 2                         NaN   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         4.0
# 3                         NaN   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         4.0
# 4                         NaN   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         4.0
# 5                         NaN   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         4.0
# 6                         NaN   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         4.0
# 7                         NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         3.0
# 8                         NaN   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         4.0
# 9                         NaN   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         4.0
#
#                         Unnamed: 10
# 0  ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 1  ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 2  ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 3  ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 4  ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 5  ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 6  ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 7     ขายได้ ใช้ระยะเวลา 7-12 เดือน
# 8  ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 9  ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี

# %%
est1_condo.rename(columns={'ประเมินราคาซื้อ-ขาย':'ประเมิน1'}, inplace=True)

# %%
condo1 = est1_condo[['post id','ราคาทรัพย์','ประเมิน1']]
condo1
# Out:
#    post id  ราคาทรัพย์   ประเมิน1
# 0     32.0     3500000  3500000.0
# 1     36.0     1930000  2200000.0
# 2    603.0     2438000  2800000.0
# 3   1395.0     1600000  2300000.0
# 4   1443.0     1860000  1800000.0
# 5   1609.0     1490000  1500000.0
# 6   1640.0     1280000  1600000.0
# 7   1641.0     4290000  2700000.0
# 8   1650.0     1700000  1550000.0
# 9   1840.0     3790000  2800000.0

# %%
condo1.isnull()
# Out:
#    post id  ราคาทรัพย์  ประเมิน1
# 0    False       False     False
# 1    False       False     False
# 2    False       False     False
# 3    False       False     False
# 4    False       False     False
# 5    False       False     False
# 6    False       False     False
# 7    False       False     False
# 8    False       False     False
# 9    False       False     False

# %%
price3 = condo1['ราคาทรัพย์']
p_est1_condo = condo1['ประเมิน1']
ma03 = mape(price3, p_est1_condo)

# %%
print(f'ค่า MAPE ผู้ประเมินคนที่ 1 เท่ากับ {ma03}')
# Out:
# ค่า MAPE ผู้ประเมินคนที่ 1 เท่ากับ 0.17349265946250259

# %% [markdown]
# ##ทาวน์โฮม

# %%
townhome
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 1                2    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 2                1    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 3                2    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 4                1    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# ..             ...                                    ...           ...
# 235              2  https://nayoo.co/khonkaen/posts/18547      ทาวน์โฮม
# 236              2  https://nayoo.co/khonkaen/posts/18551      ทาวน์โฮม
# 237              2  https://nayoo.co/khonkaen/posts/19434      ทาวน์โฮม
# 238              2  https://nayoo.co/khonkaen/posts/19501      ทาวน์โฮม
# 239              2  https://nayoo.co/khonkaen/posts/20367      ทาวน์โฮม
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                          มั่นใจ     1045000             700000.0
# 1                          มั่นใจ     1045000            1500000.0
# 2                          มั่นใจ      935000             700000.0
# 3                          มั่นใจ      935000            1500000.0
# 4                          มั่นใจ     2520000            3500000.0
# ..                            ...         ...                  ...
# 235                        มั่นใจ     1105000            1200000.0
# 236                        มั่นใจ     1440000            1700000.0
# 237                        มั่นใจ     2000000            1900000.0
# 238                        มั่นใจ     1790000            1700000.0
# 239                        มั่นใจ     1590000            1700000.0
#
#        ปัจจัยในการประเมินราคาซื้อ-ขาย  เหตุผลไม่มั่นใจราคาประเมิน  \
# 0                        5,000-15,000                         NaN
# 1           ราคาซื้อขาย 1-2 ล้าน/คูหา                         NaN
# 2                        5,000-15,000                         NaN
# 3           ราคาเสนอขาย 1-2 ล้าน/คูหา                         NaN
# 4                        8,000-80,000                         NaN
# ..                                ...                         ...
# 235    ราคาเสนอขาย1.2-1.5ล้านบาท/คูหา                         NaN
# 236   ราคาเสนอขาย 1.7-2.0ล้านบาท/คูหา                         NaN
# 237  ราคาเสนอขาย 1.8-2.0 ล้านบาท/คูหา                         NaN
# 238  ราคาเสนอขาย 1.7-1.9 ล้านบาท/คูหา                         NaN
# 239  ราคาเสนอขาย 1.7-2.0 ล้านบาท/คูหา                         NaN
#
#                          ให้คะแนนทรัพย์  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         NaN          NaN          NaN
# 1                     1 ขายไม่ได้แน่นอน         NaN          NaN          NaN
# 2    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         NaN          NaN          NaN
# 3                     1 ขายไม่ได้แน่นอน         NaN          NaN          NaN
# 4      4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         NaN          NaN          NaN
# ..                                  ...         ...          ...          ...
# 235   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 236   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 237   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 238   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 239   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
#
#      Unnamed: 12
# 0          120.0
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 235          NaN
# 236          NaN
# 237          NaN
# 238          NaN
# 239          NaN
#
# [240 rows x 13 columns]

# %%
est1_townhome = townhome[townhome['ID ผู้ประเมิน']==1]
est1_townhome
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 2                1    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 4                1    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# 6                1    https://nayoo.co/khonkaen/posts/580      ทาวน์โฮม
# 8                1    https://nayoo.co/khonkaen/posts/582      ทาวน์โฮม
# ..             ...                                    ...           ...
# 125              1  https://nayoo.co/khonkaen/posts/18547      ทาวน์โฮม
# 126              1  https://nayoo.co/khonkaen/posts/18551      ทาวน์โฮม
# 127              1  https://nayoo.co/khonkaen/posts/19434      ทาวน์โฮม
# 128              1  https://nayoo.co/khonkaen/posts/19501      ทาวน์โฮม
# 129              1  https://nayoo.co/khonkaen/posts/20367      ทาวน์โฮม
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                          มั่นใจ     1045000             700000.0
# 2                          มั่นใจ      935000             700000.0
# 4                          มั่นใจ     2520000            3500000.0
# 6                          มั่นใจ     3850000            3500000.0
# 8                          มั่นใจ      544000            1000000.0
# ..                            ...         ...                  ...
# 125                        มั่นใจ     1105000            1000000.0
# 126                        มั่นใจ     1440000            1500000.0
# 127                        มั่นใจ     2000000            1600000.0
# 128                        มั่นใจ     1790000            1600000.0
# 129                        มั่นใจ     1590000            1700000.0
#
#     ปัจจัยในการประเมินราคาซื้อ-ขาย  เหตุผลไม่มั่นใจราคาประเมิน  \
# 0                     5,000-15,000                         NaN
# 2                     5,000-15,000                         NaN
# 4                     8,000-80,000                         NaN
# 6                     8,000-80,000                         NaN
# 8                     8,000-80,000                         NaN
# ..                             ...                         ...
# 125       3,000-35,000 บาท/ตารางวา                         NaN
# 126       3,000-35,000 บาท/ตารางวา                         NaN
# 127       3,000-35,000 บาท/ตารางวา                         NaN
# 128       3,000-35,000 บาท/ตารางวา                         NaN
# 129       3,000-35,000 บาท/ตารางวา                         NaN
#
#                          ให้คะแนนทรัพย์  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         NaN          NaN          NaN
# 2    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         NaN          NaN          NaN
# 4      4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         NaN          NaN          NaN
# 6     3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 8     3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# ..                                  ...         ...          ...          ...
# 125   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 126   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 127   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 128   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 129   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
#
#      Unnamed: 12
# 0          120.0
# 2            NaN
# 4            NaN
# 6            NaN
# 8            NaN
# ..           ...
# 125          NaN
# 126          NaN
# 127          NaN
# 128          NaN
# 129          NaN
#
# [120 rows x 13 columns]

# %%
est2_townhome = townhome[townhome['ID ผู้ประเมิน']==2]
est2_townhome
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 3                2    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 5                2    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# 7                2    https://nayoo.co/khonkaen/posts/580      ทาวน์โฮม
# 9                2    https://nayoo.co/khonkaen/posts/582      ทาวน์โฮม
# ..             ...                                    ...           ...
# 235              2  https://nayoo.co/khonkaen/posts/18547      ทาวน์โฮม
# 236              2  https://nayoo.co/khonkaen/posts/18551      ทาวน์โฮม
# 237              2  https://nayoo.co/khonkaen/posts/19434      ทาวน์โฮม
# 238              2  https://nayoo.co/khonkaen/posts/19501      ทาวน์โฮม
# 239              2  https://nayoo.co/khonkaen/posts/20367      ทาวน์โฮม
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                          มั่นใจ     1045000            1500000.0
# 3                          มั่นใจ      935000            1500000.0
# 5                          มั่นใจ     2520000            4000000.0
# 7                          มั่นใจ     3850000            3200000.0
# 9                          มั่นใจ      544000             800000.0
# ..                            ...         ...                  ...
# 235                        มั่นใจ     1105000            1200000.0
# 236                        มั่นใจ     1440000            1700000.0
# 237                        มั่นใจ     2000000            1900000.0
# 238                        มั่นใจ     1790000            1700000.0
# 239                        มั่นใจ     1590000            1700000.0
#
#                  ปัจจัยในการประเมินราคาซื้อ-ขาย  เหตุผลไม่มั่นใจราคาประเมิน  \
# 1                     ราคาซื้อขาย 1-2 ล้าน/คูหา                         NaN
# 3                     ราคาเสนอขาย 1-2 ล้าน/คูหา                         NaN
# 5                  ราคาเสนอขาย 3-5 ล้านบาท/คูหา                         NaN
# 7              ราคาเสนอขาย 3 - 5 ล้านบาท / คูหา                         NaN
# 9    ราคาเสนอขาย 700,000 - 1,000,000 บาท / คูหา                         NaN
# ..                                          ...                         ...
# 235              ราคาเสนอขาย1.2-1.5ล้านบาท/คูหา                         NaN
# 236             ราคาเสนอขาย 1.7-2.0ล้านบาท/คูหา                         NaN
# 237            ราคาเสนอขาย 1.8-2.0 ล้านบาท/คูหา                         NaN
# 238            ราคาเสนอขาย 1.7-1.9 ล้านบาท/คูหา                         NaN
# 239            ราคาเสนอขาย 1.7-2.0 ล้านบาท/คูหา                         NaN
#
#                         ให้คะแนนทรัพย์  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 1                    1 ขายไม่ได้แน่นอน         NaN          NaN          NaN
# 3                    1 ขายไม่ได้แน่นอน         NaN          NaN          NaN
# 5    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 7    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 9    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# ..                                 ...         ...          ...          ...
# 235  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 236  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 237  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 238  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 239  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
#
#      Unnamed: 12
# 1            NaN
# 3            NaN
# 5            NaN
# 7            NaN
# 9            NaN
# ..           ...
# 235          NaN
# 236          NaN
# 237          NaN
# 238          NaN
# 239          NaN
#
# [120 rows x 13 columns]

# %%
est2_townhome['ประเมิน1'] = est2_townhome['post id'].map(est1_townhome.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
est2_townhome
# Out:
# <ipython-input-42-81af8b07a0e9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   est2_townhome['ประเมิน1'] = est2_townhome['post id'].map(est1_townhome.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 3                2    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 5                2    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# 7                2    https://nayoo.co/khonkaen/posts/580      ทาวน์โฮม
# 9                2    https://nayoo.co/khonkaen/posts/582      ทาวน์โฮม
# ..             ...                                    ...           ...
# 235              2  https://nayoo.co/khonkaen/posts/18547      ทาวน์โฮม
# 236              2  https://nayoo.co/khonkaen/posts/18551      ทาวน์โฮม
# 237              2  https://nayoo.co/khonkaen/posts/19434      ทาวน์โฮม
# 238              2  https://nayoo.co/khonkaen/posts/19501      ทาวน์โฮม
# 239              2  https://nayoo.co/khonkaen/posts/20367      ทาวน์โฮม
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                          มั่นใจ     1045000            1500000.0
# 3                          มั่นใจ      935000            1500000.0
# 5                          มั่นใจ     2520000            4000000.0
# 7                          มั่นใจ     3850000            3200000.0
# 9                          มั่นใจ      544000             800000.0
# ..                            ...         ...                  ...
# 235                        มั่นใจ     1105000            1200000.0
# 236                        มั่นใจ     1440000            1700000.0
# 237                        มั่นใจ     2000000            1900000.0
# 238                        มั่นใจ     1790000            1700000.0
# 239                        มั่นใจ     1590000            1700000.0
#
#                  ปัจจัยในการประเมินราคาซื้อ-ขาย  เหตุผลไม่มั่นใจราคาประเมิน  \
# 1                     ราคาซื้อขาย 1-2 ล้าน/คูหา                         NaN
# 3                     ราคาเสนอขาย 1-2 ล้าน/คูหา                         NaN
# 5                  ราคาเสนอขาย 3-5 ล้านบาท/คูหา                         NaN
# 7              ราคาเสนอขาย 3 - 5 ล้านบาท / คูหา                         NaN
# 9    ราคาเสนอขาย 700,000 - 1,000,000 บาท / คูหา                         NaN
# ..                                          ...                         ...
# 235              ราคาเสนอขาย1.2-1.5ล้านบาท/คูหา                         NaN
# 236             ราคาเสนอขาย 1.7-2.0ล้านบาท/คูหา                         NaN
# 237            ราคาเสนอขาย 1.8-2.0 ล้านบาท/คูหา                         NaN
# 238            ราคาเสนอขาย 1.7-1.9 ล้านบาท/คูหา                         NaN
# 239            ราคาเสนอขาย 1.7-2.0 ล้านบาท/คูหา                         NaN
#
#                         ให้คะแนนทรัพย์  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 1                    1 ขายไม่ได้แน่นอน         NaN          NaN          NaN
# 3                    1 ขายไม่ได้แน่นอน         NaN          NaN          NaN
# 5    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 7    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 9    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# ..                                 ...         ...          ...          ...
# 235  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 236  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 237  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 238  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 239  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
#
#      Unnamed: 12   ประเมิน1
# 1            NaN   700000.0
# 3            NaN   700000.0
# 5            NaN  3500000.0
# 7            NaN  3500000.0
# 9            NaN  1000000.0
# ..           ...        ...
# 235          NaN  1000000.0
# 236          NaN  1500000.0
# 237          NaN  1600000.0
# 238          NaN  1600000.0
# 239          NaN  1700000.0
#
# [120 rows x 14 columns]

# %%
est2_townhome['ประเมิน2'] = est2_townhome['post id'].map(est2_townhome.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
est2_townhome
# Out:
# <ipython-input-43-e209b7f7c1ba>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   est2_townhome['ประเมิน2'] = est2_townhome['post id'].map(est2_townhome.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 3                2    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 5                2    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# 7                2    https://nayoo.co/khonkaen/posts/580      ทาวน์โฮม
# 9                2    https://nayoo.co/khonkaen/posts/582      ทาวน์โฮม
# ..             ...                                    ...           ...
# 235              2  https://nayoo.co/khonkaen/posts/18547      ทาวน์โฮม
# 236              2  https://nayoo.co/khonkaen/posts/18551      ทาวน์โฮม
# 237              2  https://nayoo.co/khonkaen/posts/19434      ทาวน์โฮม
# 238              2  https://nayoo.co/khonkaen/posts/19501      ทาวน์โฮม
# 239              2  https://nayoo.co/khonkaen/posts/20367      ทาวน์โฮม
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                          มั่นใจ     1045000            1500000.0
# 3                          มั่นใจ      935000            1500000.0
# 5                          มั่นใจ     2520000            4000000.0
# 7                          มั่นใจ     3850000            3200000.0
# 9                          มั่นใจ      544000             800000.0
# ..                            ...         ...                  ...
# 235                        มั่นใจ     1105000            1200000.0
# 236                        มั่นใจ     1440000            1700000.0
# 237                        มั่นใจ     2000000            1900000.0
# 238                        มั่นใจ     1790000            1700000.0
# 239                        มั่นใจ     1590000            1700000.0
#
#                  ปัจจัยในการประเมินราคาซื้อ-ขาย  เหตุผลไม่มั่นใจราคาประเมิน  \
# 1                     ราคาซื้อขาย 1-2 ล้าน/คูหา                         NaN
# 3                     ราคาเสนอขาย 1-2 ล้าน/คูหา                         NaN
# 5                  ราคาเสนอขาย 3-5 ล้านบาท/คูหา                         NaN
# 7              ราคาเสนอขาย 3 - 5 ล้านบาท / คูหา                         NaN
# 9    ราคาเสนอขาย 700,000 - 1,000,000 บาท / คูหา                         NaN
# ..                                          ...                         ...
# 235              ราคาเสนอขาย1.2-1.5ล้านบาท/คูหา                         NaN
# 236             ราคาเสนอขาย 1.7-2.0ล้านบาท/คูหา                         NaN
# 237            ราคาเสนอขาย 1.8-2.0 ล้านบาท/คูหา                         NaN
# 238            ราคาเสนอขาย 1.7-1.9 ล้านบาท/คูหา                         NaN
# 239            ราคาเสนอขาย 1.7-2.0 ล้านบาท/คูหา                         NaN
#
#                         ให้คะแนนทรัพย์  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 1                    1 ขายไม่ได้แน่นอน         NaN          NaN          NaN
# 3                    1 ขายไม่ได้แน่นอน         NaN          NaN          NaN
# 5    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 7    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 9    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# ..                                 ...         ...          ...          ...
# 235  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 236  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 237  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 238  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 239  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
#
#      Unnamed: 12   ประเมิน1   ประเมิน2
# 1            NaN   700000.0  1500000.0
# 3            NaN   700000.0  1500000.0
# 5            NaN  3500000.0  4000000.0
# 7            NaN  3500000.0  3200000.0
# 9            NaN  1000000.0   800000.0
# ..           ...        ...        ...
# 235          NaN  1000000.0  1200000.0
# 236          NaN  1500000.0  1700000.0
# 237          NaN  1600000.0  1900000.0
# 238          NaN  1600000.0  1700000.0
# 239          NaN  1700000.0  1700000.0
#
# [120 rows x 15 columns]

# %%
townhome1 = est2_townhome[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2','ให้คะแนนทรัพย์','ความมั่นใจในการเมินราคาทรัพย์']]
townhome1
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 1      https://nayoo.co/khonkaen/posts/548     1045000   700000.0  1500000.0
# 3      https://nayoo.co/khonkaen/posts/549      935000   700000.0  1500000.0
# 5      https://nayoo.co/khonkaen/posts/579     2520000  3500000.0  4000000.0
# 7      https://nayoo.co/khonkaen/posts/580     3850000  3500000.0  3200000.0
# 9      https://nayoo.co/khonkaen/posts/582      544000  1000000.0   800000.0
# ..                                     ...         ...        ...        ...
# 235  https://nayoo.co/khonkaen/posts/18547     1105000  1000000.0  1200000.0
# 236  https://nayoo.co/khonkaen/posts/18551     1440000  1500000.0  1700000.0
# 237  https://nayoo.co/khonkaen/posts/19434     2000000  1600000.0  1900000.0
# 238  https://nayoo.co/khonkaen/posts/19501     1790000  1600000.0  1700000.0
# 239  https://nayoo.co/khonkaen/posts/20367     1590000  1700000.0  1700000.0
#
#                         ให้คะแนนทรัพย์ ความมั่นใจในการเมินราคาทรัพย์
# 1                    1 ขายไม่ได้แน่นอน                        มั่นใจ
# 3                    1 ขายไม่ได้แน่นอน                        มั่นใจ
# 5    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 7    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 9    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# ..                                 ...                           ...
# 235  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 236  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 237  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 238  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 239  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
#
# [120 rows x 6 columns]

# %%
townhome1 = townhome1.fillna(value={'ประเมิน2':est2_townhome['ประเมิน2'].mean()})
townhome1
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 1      https://nayoo.co/khonkaen/posts/548     1045000   700000.0  1500000.0
# 3      https://nayoo.co/khonkaen/posts/549      935000   700000.0  1500000.0
# 5      https://nayoo.co/khonkaen/posts/579     2520000  3500000.0  4000000.0
# 7      https://nayoo.co/khonkaen/posts/580     3850000  3500000.0  3200000.0
# 9      https://nayoo.co/khonkaen/posts/582      544000  1000000.0   800000.0
# ..                                     ...         ...        ...        ...
# 235  https://nayoo.co/khonkaen/posts/18547     1105000  1000000.0  1200000.0
# 236  https://nayoo.co/khonkaen/posts/18551     1440000  1500000.0  1700000.0
# 237  https://nayoo.co/khonkaen/posts/19434     2000000  1600000.0  1900000.0
# 238  https://nayoo.co/khonkaen/posts/19501     1790000  1600000.0  1700000.0
# 239  https://nayoo.co/khonkaen/posts/20367     1590000  1700000.0  1700000.0
#
#                         ให้คะแนนทรัพย์ ความมั่นใจในการเมินราคาทรัพย์
# 1                    1 ขายไม่ได้แน่นอน                        มั่นใจ
# 3                    1 ขายไม่ได้แน่นอน                        มั่นใจ
# 5    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 7    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 9    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# ..                                 ...                           ...
# 235  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 236  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 237  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 238  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 239  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
#
# [120 rows x 6 columns]

# %%
townhome1.isnull()
# Out:
#      post id  ราคาทรัพย์  ประเมิน1  ประเมิน2  ให้คะแนนทรัพย์  \
# 1      False       False     False     False           False
# 3      False       False     False     False           False
# 5      False       False     False     False           False
# 7      False       False     False     False           False
# 9      False       False     False     False           False
# ..       ...         ...       ...       ...             ...
# 235    False       False     False     False           False
# 236    False       False     False     False           False
# 237    False       False     False     False           False
# 238    False       False     False     False           False
# 239    False       False     False     False           False
#
#      ความมั่นใจในการเมินราคาทรัพย์
# 1                            False
# 3                            False
# 5                            False
# 7                            False
# 9                            False
# ..                             ...
# 235                          False
# 236                          False
# 237                          False
# 238                          False
# 239                          False
#
# [120 rows x 6 columns]

# %%
price4 = townhome1['ราคาทรัพย์']
p_est1_townhome = townhome1['ประเมิน1']
ma04 = mape(price4, p_est1_townhome)

# %%
p_est2_townhome = townhome1['ประเมิน2']
ma004 = mape(price4, p_est2_townhome)
mape4 = mape(p_est2_townhome,p_est1_townhome)

# %%
mape4
# Out:
# 0.10619748830198178

# %%
print(f'ค่า MAPE ผู้ประเมินคนที่ 1 เท่ากับ {ma04} \nค่า MAPE ผู้ประเมินคนที่ 2 เท่ากับ {ma004}')
# Out:
# ค่า MAPE ผู้ประเมินคนที่ 1 เท่ากับ 0.11573478246014954
# ค่า MAPE ผู้ประเมินคนที่ 2 เท่ากับ 0.09255174455679427

# %% [markdown]
# สรุป จะเห็นว่าค่า MAPE ที่ประเมินโดยคนที่ 2 มีค่าน้อยกว่าคนที่ 1
#
# ดังนั้น การประเมินโดยคนที่ 2 มีการประเมินราคาซื้อ-ขาย ได้ใกล้เคียงกับราคาทรัพย์ มากกว่าผู้ประเมินคนที่ 1

# %% [markdown]
# ##อาคารพาณิชย์

# %%
commercial
# Out:
#      ID ผู้ประเมิน                               post id  \
# 0                1     https://nayoo.co/khonkaen/posts/6
# 1                2     https://nayoo.co/khonkaen/posts/6
# 2                1    https://nayoo.co/khonkaen/posts/17
# 3                2    https://nayoo.co/khonkaen/posts/17
# 4                1    https://nayoo.co/khonkaen/posts/21
# ..             ...                                   ...
# 195              2  https://nayoo.co/khonkaen/posts/7439
# 196              1  https://nayoo.co/khonkaen/posts/7668
# 197              2  https://nayoo.co/khonkaen/posts/7668
# 198              1  https://nayoo.co/khonkaen/posts/7705
# 199              2  https://nayoo.co/khonkaen/posts/7705
#
#              property_type ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  \
# 0    อาคารพาณิชย์/สำนักงาน                        มั่นใจ     6600000
# 1    อาคารพาณิชย์/สำนักงาน                        มั่นใจ     6600000
# 2    อาคารพาณิชย์/สำนักงาน                        มั่นใจ    11400000
# 3    อาคารพาณิชย์/สำนักงาน                        มั่นใจ    11400000
# 4    อาคารพาณิชย์/สำนักงาน                        มั่นใจ    22500000
# ..                     ...                           ...         ...
# 195  อาคารพาณิชย์/สำนักงาน                     ไม่มั่นใจ     6900000
# 196  อาคารพาณิชย์/สำนักงาน                        มั่นใจ    12000000
# 197  อาคารพาณิชย์/สำนักงาน                     ไม่มั่นใจ    12000000
# 198  อาคารพาณิชย์/สำนักงาน                        มั่นใจ     2200000
# 199  อาคารพาณิชย์/สำนักงาน                        มั่นใจ     2200000
#
#      ประเมินราคาซื้อ-ขาย            ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0              6000000.0                              8,000-30,000
# 1              8000000.0  ราคาเสนอขาย 4,000,000-6,000,000 บาท/คูหา
# 2             12000000.0                              8,000-40,000
# 3             12000000.0            ราคาเสนอขาย 4 - 5 ล้านบาท/คูหา
# 4             13500000.0                              8,000-50,000
# ..                   ...                                       ...
# 195                  NaN                                       NaN
# 196            1500000.0                 3,000-120,000 บาท/ตารางวา
# 197                  NaN                                       NaN
# 198            2500000.0                  3,000-80,000 บาท/ตารางวา
# 199            2000000.0           ราคาเสนอขาย 2.0-2.2ล้านบาท/คูหา
#
#     เหตุผลไม่มั่นใจราคาประเมิน                      ให้คะแนนทรัพย์
# 0                          NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 1                          NaN    4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน
# 2                          NaN    4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน
# 3                          NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 4                          NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# ..                         ...                                 ...
# 195    ไม่มีฐานข้อมูลบริเวณนี้                                 NaN
# 196                        NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 197             ไม่มีฐานข้อมูล                                 NaN
# 198                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 199                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
#
# [200 rows x 9 columns]

# %%
est1_commercial = commercial[commercial['ID ผู้ประเมิน']==1]
est1_commercial
# Out:
#      ID ผู้ประเมิน                               post id  \
# 0                1     https://nayoo.co/khonkaen/posts/6
# 2                1    https://nayoo.co/khonkaen/posts/17
# 4                1    https://nayoo.co/khonkaen/posts/21
# 6                1    https://nayoo.co/khonkaen/posts/22
# 8                1    https://nayoo.co/khonkaen/posts/24
# ..             ...                                   ...
# 190              1  https://nayoo.co/khonkaen/posts/7137
# 192              1  https://nayoo.co/khonkaen/posts/7138
# 194              1  https://nayoo.co/khonkaen/posts/7439
# 196              1  https://nayoo.co/khonkaen/posts/7668
# 198              1  https://nayoo.co/khonkaen/posts/7705
#
#              property_type ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  \
# 0    อาคารพาณิชย์/สำนักงาน                        มั่นใจ     6600000
# 2    อาคารพาณิชย์/สำนักงาน                        มั่นใจ    11400000
# 4    อาคารพาณิชย์/สำนักงาน                        มั่นใจ    22500000
# 6    อาคารพาณิชย์/สำนักงาน                        มั่นใจ     3500000
# 8    อาคารพาณิชย์/สำนักงาน                        มั่นใจ     3900000
# ..                     ...                           ...         ...
# 190  อาคารพาณิชย์/สำนักงาน                        มั่นใจ     3900000
# 192  อาคารพาณิชย์/สำนักงาน                        มั่นใจ     4500000
# 194  อาคารพาณิชย์/สำนักงาน                        มั่นใจ     6900000
# 196  อาคารพาณิชย์/สำนักงาน                        มั่นใจ    12000000
# 198  อาคารพาณิชย์/สำนักงาน                        มั่นใจ     2200000
#
#      ประเมินราคาซื้อ-ขาย ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0              6000000.0                   8,000-30,000
# 2             12000000.0                   8,000-40,000
# 4             13500000.0                   8,000-50,000
# 6              4000000.0                   8,000-60,000
# 8              2200000.0                   8,000-50,000
# ..                   ...                            ...
# 190            3600000.0       3,000-50,000 บาท/ตารางวา
# 192            2300000.0       3,000-40,000 บาท/ตารางวา
# 194            3300000.0       3,000-80,000 บาท/ตารางวา
# 196            1500000.0      3,000-120,000 บาท/ตารางวา
# 198            2500000.0       3,000-80,000 บาท/ตารางวา
#
#     เหตุผลไม่มั่นใจราคาประเมิน                      ให้คะแนนทรัพย์
# 0                          NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 2                          NaN    4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน
# 4                          NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 6                          NaN    4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน
# 8                          NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# ..                         ...                                 ...
# 190                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 192                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 194                        NaN                   1 ขายไม่ได้แน่นอน
# 196                        NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 198                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
#
# [100 rows x 9 columns]

# %%
est2_commercial = commercial[commercial['ID ผู้ประเมิน']==2]
est2_commercial
# Out:
#      ID ผู้ประเมิน                               post id  \
# 1                2     https://nayoo.co/khonkaen/posts/6
# 3                2    https://nayoo.co/khonkaen/posts/17
# 5                2    https://nayoo.co/khonkaen/posts/21
# 7                2    https://nayoo.co/khonkaen/posts/22
# 9                2    https://nayoo.co/khonkaen/posts/24
# ..             ...                                   ...
# 191              2  https://nayoo.co/khonkaen/posts/7137
# 193              2  https://nayoo.co/khonkaen/posts/7138
# 195              2  https://nayoo.co/khonkaen/posts/7439
# 197              2  https://nayoo.co/khonkaen/posts/7668
# 199              2  https://nayoo.co/khonkaen/posts/7705
#
#              property_type ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  \
# 1    อาคารพาณิชย์/สำนักงาน                        มั่นใจ     6600000
# 3    อาคารพาณิชย์/สำนักงาน                        มั่นใจ    11400000
# 5    อาคารพาณิชย์/สำนักงาน                        มั่นใจ    22500000
# 7    อาคารพาณิชย์/สำนักงาน                        มั่นใจ     3500000
# 9    อาคารพาณิชย์/สำนักงาน                        มั่นใจ     3900000
# ..                     ...                           ...         ...
# 191  อาคารพาณิชย์/สำนักงาน                        มั่นใจ     3900000
# 193  อาคารพาณิชย์/สำนักงาน                     ไม่มั่นใจ     4500000
# 195  อาคารพาณิชย์/สำนักงาน                     ไม่มั่นใจ     6900000
# 197  อาคารพาณิชย์/สำนักงาน                     ไม่มั่นใจ    12000000
# 199  อาคารพาณิชย์/สำนักงาน                        มั่นใจ     2200000
#
#      ประเมินราคาซื้อ-ขาย            ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 1              8000000.0  ราคาเสนอขาย 4,000,000-6,000,000 บาท/คูหา
# 3             12000000.0            ราคาเสนอขาย 4 - 5 ล้านบาท/คูหา
# 5             20000000.0            ราคาเสนอขาย 6-8 ล้านบาท / คูหา
# 7              4000000.0              ราคาเสนอขาย 3-5 ล้านบาท/คูหา
# 9              3000000.0            ราคาซื้อขาย 3-4 ล้านบาท / คูหา
# ..                   ...                                       ...
# 191            4000000.0           ราคาเสนอขาย 3.9-4.5ล้านบาท/คูหา
# 193                  NaN                                       NaN
# 195                  NaN                                       NaN
# 197                  NaN                                       NaN
# 199            2000000.0           ราคาเสนอขาย 2.0-2.2ล้านบาท/คูหา
#
#     เหตุผลไม่มั่นใจราคาประเมิน                      ให้คะแนนทรัพย์
# 1                          NaN    4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน
# 3                          NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 5                          NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 7                          NaN    4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน
# 9                          NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# ..                         ...                                 ...
# 191                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 193    ไม่มีฐานข้อมูลบริเวณนี้                                 NaN
# 195    ไม่มีฐานข้อมูลบริเวณนี้                                 NaN
# 197             ไม่มีฐานข้อมูล                                 NaN
# 199                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
#
# [100 rows x 9 columns]

# %%
est2_commercial['ประเมิน1'] = est2_commercial['post id'].map(est1_commercial.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
est2_commercial
# Out:
# <ipython-input-54-7da4b1eb5e75>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   est2_commercial['ประเมิน1'] = est2_commercial['post id'].map(est1_commercial.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      ID ผู้ประเมิน                               post id  \
# 1                2     https://nayoo.co/khonkaen/posts/6
# 3                2    https://nayoo.co/khonkaen/posts/17
# 5                2    https://nayoo.co/khonkaen/posts/21
# 7                2    https://nayoo.co/khonkaen/posts/22
# 9                2    https://nayoo.co/khonkaen/posts/24
# ..             ...                                   ...
# 191              2  https://nayoo.co/khonkaen/posts/7137
# 193              2  https://nayoo.co/khonkaen/posts/7138
# 195              2  https://nayoo.co/khonkaen/posts/7439
# 197              2  https://nayoo.co/khonkaen/posts/7668
# 199              2  https://nayoo.co/khonkaen/posts/7705
#
#              property_type ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  \
# 1    อาคารพาณิชย์/สำนักงาน                        มั่นใจ     6600000
# 3    อาคารพาณิชย์/สำนักงาน                        มั่นใจ    11400000
# 5    อาคารพาณิชย์/สำนักงาน                        มั่นใจ    22500000
# 7    อาคารพาณิชย์/สำนักงาน                        มั่นใจ     3500000
# 9    อาคารพาณิชย์/สำนักงาน                        มั่นใจ     3900000
# ..                     ...                           ...         ...
# 191  อาคารพาณิชย์/สำนักงาน                        มั่นใจ     3900000
# 193  อาคารพาณิชย์/สำนักงาน                     ไม่มั่นใจ     4500000
# 195  อาคารพาณิชย์/สำนักงาน                     ไม่มั่นใจ     6900000
# 197  อาคารพาณิชย์/สำนักงาน                     ไม่มั่นใจ    12000000
# 199  อาคารพาณิชย์/สำนักงาน                        มั่นใจ     2200000
#
#      ประเมินราคาซื้อ-ขาย            ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 1              8000000.0  ราคาเสนอขาย 4,000,000-6,000,000 บาท/คูหา
# 3             12000000.0            ราคาเสนอขาย 4 - 5 ล้านบาท/คูหา
# 5             20000000.0            ราคาเสนอขาย 6-8 ล้านบาท / คูหา
# 7              4000000.0              ราคาเสนอขาย 3-5 ล้านบาท/คูหา
# 9              3000000.0            ราคาซื้อขาย 3-4 ล้านบาท / คูหา
# ..                   ...                                       ...
# 191            4000000.0           ราคาเสนอขาย 3.9-4.5ล้านบาท/คูหา
# 193                  NaN                                       NaN
# 195                  NaN                                       NaN
# 197                  NaN                                       NaN
# 199            2000000.0           ราคาเสนอขาย 2.0-2.2ล้านบาท/คูหา
#
#     เหตุผลไม่มั่นใจราคาประเมิน                      ให้คะแนนทรัพย์    ประเมิน1
# 1                          NaN    4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน   6000000.0
# 3                          NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี  12000000.0
# 5                          NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน  13500000.0
# 7                          NaN    4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน   4000000.0
# 9                          NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี   2200000.0
# ..                         ...                                 ...         ...
# 191                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน   3600000.0
# 193    ไม่มีฐานข้อมูลบริเวณนี้                                 NaN   2300000.0
# 195    ไม่มีฐานข้อมูลบริเวณนี้                                 NaN   3300000.0
# 197             ไม่มีฐานข้อมูล                                 NaN   1500000.0
# 199                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน   2500000.0
#
# [100 rows x 10 columns]

# %%
est2_commercial['ประเมิน2'] = est2_commercial['post id'].map(est2_commercial.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
est2_commercial
# Out:
# <ipython-input-55-2b8f7c88fe13>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   est2_commercial['ประเมิน2'] = est2_commercial['post id'].map(est2_commercial.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      ID ผู้ประเมิน                               post id  \
# 1                2     https://nayoo.co/khonkaen/posts/6
# 3                2    https://nayoo.co/khonkaen/posts/17
# 5                2    https://nayoo.co/khonkaen/posts/21
# 7                2    https://nayoo.co/khonkaen/posts/22
# 9                2    https://nayoo.co/khonkaen/posts/24
# ..             ...                                   ...
# 191              2  https://nayoo.co/khonkaen/posts/7137
# 193              2  https://nayoo.co/khonkaen/posts/7138
# 195              2  https://nayoo.co/khonkaen/posts/7439
# 197              2  https://nayoo.co/khonkaen/posts/7668
# 199              2  https://nayoo.co/khonkaen/posts/7705
#
#              property_type ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  \
# 1    อาคารพาณิชย์/สำนักงาน                        มั่นใจ     6600000
# 3    อาคารพาณิชย์/สำนักงาน                        มั่นใจ    11400000
# 5    อาคารพาณิชย์/สำนักงาน                        มั่นใจ    22500000
# 7    อาคารพาณิชย์/สำนักงาน                        มั่นใจ     3500000
# 9    อาคารพาณิชย์/สำนักงาน                        มั่นใจ     3900000
# ..                     ...                           ...         ...
# 191  อาคารพาณิชย์/สำนักงาน                        มั่นใจ     3900000
# 193  อาคารพาณิชย์/สำนักงาน                     ไม่มั่นใจ     4500000
# 195  อาคารพาณิชย์/สำนักงาน                     ไม่มั่นใจ     6900000
# 197  อาคารพาณิชย์/สำนักงาน                     ไม่มั่นใจ    12000000
# 199  อาคารพาณิชย์/สำนักงาน                        มั่นใจ     2200000
#
#      ประเมินราคาซื้อ-ขาย            ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 1              8000000.0  ราคาเสนอขาย 4,000,000-6,000,000 บาท/คูหา
# 3             12000000.0            ราคาเสนอขาย 4 - 5 ล้านบาท/คูหา
# 5             20000000.0            ราคาเสนอขาย 6-8 ล้านบาท / คูหา
# 7              4000000.0              ราคาเสนอขาย 3-5 ล้านบาท/คูหา
# 9              3000000.0            ราคาซื้อขาย 3-4 ล้านบาท / คูหา
# ..                   ...                                       ...
# 191            4000000.0           ราคาเสนอขาย 3.9-4.5ล้านบาท/คูหา
# 193                  NaN                                       NaN
# 195                  NaN                                       NaN
# 197                  NaN                                       NaN
# 199            2000000.0           ราคาเสนอขาย 2.0-2.2ล้านบาท/คูหา
#
#     เหตุผลไม่มั่นใจราคาประเมิน                      ให้คะแนนทรัพย์  \
# 1                          NaN    4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน
# 3                          NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 5                          NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 7                          NaN    4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน
# 9                          NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# ..                         ...                                 ...
# 191                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 193    ไม่มีฐานข้อมูลบริเวณนี้                                 NaN
# 195    ไม่มีฐานข้อมูลบริเวณนี้                                 NaN
# 197             ไม่มีฐานข้อมูล                                 NaN
# 199                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
#
#        ประเมิน1    ประเมิน2
# 1     6000000.0   8000000.0
# 3    12000000.0  12000000.0
# 5    13500000.0  20000000.0
# 7     4000000.0   4000000.0
# 9     2200000.0   3000000.0
# ..          ...         ...
# 191   3600000.0   4000000.0
# 193   2300000.0         NaN
# 195   3300000.0         NaN
# 197   1500000.0         NaN
# 199   2500000.0   2000000.0
#
# [100 rows x 11 columns]

# %%
commercial1  = est2_commercial[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2','ให้คะแนนทรัพย์','ความมั่นใจในการเมินราคาทรัพย์']]
commercial1
# Out:
#                                   post id  ราคาทรัพย์    ประเมิน1    ประเมิน2  \
# 1       https://nayoo.co/khonkaen/posts/6     6600000   6000000.0   8000000.0
# 3      https://nayoo.co/khonkaen/posts/17    11400000  12000000.0  12000000.0
# 5      https://nayoo.co/khonkaen/posts/21    22500000  13500000.0  20000000.0
# 7      https://nayoo.co/khonkaen/posts/22     3500000   4000000.0   4000000.0
# 9      https://nayoo.co/khonkaen/posts/24     3900000   2200000.0   3000000.0
# ..                                    ...         ...         ...         ...
# 191  https://nayoo.co/khonkaen/posts/7137     3900000   3600000.0   4000000.0
# 193  https://nayoo.co/khonkaen/posts/7138     4500000   2300000.0         NaN
# 195  https://nayoo.co/khonkaen/posts/7439     6900000   3300000.0         NaN
# 197  https://nayoo.co/khonkaen/posts/7668    12000000   1500000.0         NaN
# 199  https://nayoo.co/khonkaen/posts/7705     2200000   2500000.0   2000000.0
#
#                          ให้คะแนนทรัพย์ ความมั่นใจในการเมินราคาทรัพย์
# 1      4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                        มั่นใจ
# 3    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี                        มั่นใจ
# 5     3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 7      4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                        มั่นใจ
# 9    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี                        มั่นใจ
# ..                                  ...                           ...
# 191   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 193                                 NaN                     ไม่มั่นใจ
# 195                                 NaN                     ไม่มั่นใจ
# 197                                 NaN                     ไม่มั่นใจ
# 199   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
#
# [100 rows x 6 columns]

# %%
commercial1 = commercial1.fillna(value={'ประเมิน2':est2_commercial['ประเมิน2'].mean()})
commercial1
# Out:
#                                   post id  ราคาทรัพย์    ประเมิน1  \
# 1       https://nayoo.co/khonkaen/posts/6     6600000   6000000.0
# 3      https://nayoo.co/khonkaen/posts/17    11400000  12000000.0
# 5      https://nayoo.co/khonkaen/posts/21    22500000  13500000.0
# 7      https://nayoo.co/khonkaen/posts/22     3500000   4000000.0
# 9      https://nayoo.co/khonkaen/posts/24     3900000   2200000.0
# ..                                    ...         ...         ...
# 191  https://nayoo.co/khonkaen/posts/7137     3900000   3600000.0
# 193  https://nayoo.co/khonkaen/posts/7138     4500000   2300000.0
# 195  https://nayoo.co/khonkaen/posts/7439     6900000   3300000.0
# 197  https://nayoo.co/khonkaen/posts/7668    12000000   1500000.0
# 199  https://nayoo.co/khonkaen/posts/7705     2200000   2500000.0
#
#          ประเมิน2                      ให้คะแนนทรัพย์  \
# 1    8.000000e+06    4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน
# 3    1.200000e+07  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 5    2.000000e+07   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 7    4.000000e+06    4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน
# 9    3.000000e+06  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# ..            ...                                 ...
# 191  4.000000e+06   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 193  4.725275e+06                                 NaN
# 195  4.725275e+06                                 NaN
# 197  4.725275e+06                                 NaN
# 199  2.000000e+06   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
#
#     ความมั่นใจในการเมินราคาทรัพย์
# 1                          มั่นใจ
# 3                          มั่นใจ
# 5                          มั่นใจ
# 7                          มั่นใจ
# 9                          มั่นใจ
# ..                            ...
# 191                        มั่นใจ
# 193                     ไม่มั่นใจ
# 195                     ไม่มั่นใจ
# 197                     ไม่มั่นใจ
# 199                        มั่นใจ
#
# [100 rows x 6 columns]

# %% [markdown]
# # New Section

# %%
commercial1.isnull()
# Out:
#      post id  ราคาทรัพย์  ประเมิน1  ประเมิน2  ให้คะแนนทรัพย์  \
# 1      False       False     False     False           False
# 3      False       False     False     False           False
# 5      False       False     False     False           False
# 7      False       False     False     False           False
# 9      False       False     False     False           False
# ..       ...         ...       ...       ...             ...
# 191    False       False     False     False           False
# 193    False       False     False     False            True
# 195    False       False     False     False            True
# 197    False       False     False     False            True
# 199    False       False     False     False           False
#
#      ความมั่นใจในการเมินราคาทรัพย์
# 1                            False
# 3                            False
# 5                            False
# 7                            False
# 9                            False
# ..                             ...
# 191                          False
# 193                          False
# 195                          False
# 197                          False
# 199                          False
#
# [100 rows x 6 columns]

# %%
price5 = commercial1['ราคาทรัพย์']
p_est1_office = commercial1['ประเมิน1']
ma05 = mape(price5, p_est1_office)

# %%
p_est2_office = commercial1['ประเมิน2']
ma005 = mape(price5, p_est2_office)
mape5 = mape(p_est2_office,p_est1_office)

# %%
mape5
# Out:
# 0.1417028802827348

# %%
print(f'ค่า MAPE ผู้ประเมินคนที่ 1 เท่ากับ {ma05} \nค่า MAPE ผู้ประเมินคนที่ 2 เท่ากับ {ma005}')
# Out:
# ค่า MAPE ผู้ประเมินคนที่ 1 เท่ากับ 0.13227450703608717
# ค่า MAPE ผู้ประเมินคนที่ 2 เท่ากับ 0.1391528619829938

# %% [markdown]
# สรุป จะเห็นว่าค่า MAPE ที่ประเมินโดยคนที่ 2 มีค่าน้อยกว่าคนที่ 1
#
# ดังนั้น การประเมินโดยคนที่ 2 มีการประเมินราคาซื้อ-ขาย ได้ใกล้เคียงกับราคาทรัพย์ มากกว่าผู้ประเมินคนที่ 1

# %% [markdown]
# #เขียน funtion ตรวจสอบค่าที่เติม 0 ผิด

# %% [markdown]
# ##บ้านเดี่ยว

# %%
def check(in1,in2) :
    return max(in1/in2,in2/in1)

# %%
check(100,12)
# Out:
# 8.333333333333334

# %%
check(100,1200)
# Out:
# 12.0

# %%
check1 = list()
for row in house1.iterrows():
  check1.append(check(row[1]['ราคาทรัพย์'],row[1]['ประเมิน1']))
check1
# Out:
# [1.156,
#  1.1818181818181819,
#  1.21,
#  1.2571428571428571,
#  1.1,
#  1.271111111111111,
#  1.36,
#  1.0153846153846153,
#  1.3684,
#  1.031941031941032,
#  1.0476190476190477,
#  1.1785714285714286,
#  1.0592592592592593,
#  1.188,
#  1.1275,
#  1.1,
#  1.1157142857142857,
#  1.0371428571428571,
#  1.0588235294117647,
#  1.2571428571428571,
#  1.13125,
#  1.0,
#  1.0888888888888888,
#  1.0892333472978635,
#  1.0444444444444445,
#  1.0,
#  1.0434782608695652,
#  1.02,
#  1.25,
#  1.13,
#  1.0714285714285714,
#  1.0,
#  1.0,
#  1.3833333333333333,
#  1.03125,
#  1.1611111111111112,
#  1.0526315789473684,
#  1.5384615384615385,
#  1.0227272727272727,
#  1.1363636363636365,
#  1.1111111111111112,
#  1.1290322580645162,
#  1.1388888888888888,
#  nan,
#  1.24,
#  1.3093125,
#  1.21,
#  1.0123636363636364,
#  1.0692857142857144,
#  1.0158013544018059,
#  1.4685314685314685,
#  1.1777777777777778,
#  1.1942857142857144,
#  1.0714285714285714,
#  1.0710526315789475,
#  1.036,
#  1.046,
#  1.09375,
#  1.2140833670578712,
#  1.1090909090909091,
#  1.1333333333333333,
#  1.1866666666666668,
#  1.036,
#  1.0031347962382444,
#  1.0606060606060606,
#  1.2,
#  1.2340425531914894,
#  1.0,
#  1.0857142857142856,
#  1.1607142857142858,
#  1.1290322580645162,
#  1.0263929618768328,
#  1.0839269123567667,
#  1.0218631178707225,
#  1.1333333333333333,
#  1.0526315789473684,
#  1.1111111111111112,
#  1.693121693121693,
#  1.0,
#  1.0227563283047814,
#  1.1111111111111112,
#  nan,
#  1.0083333333333333,
#  1.0697727272727273,
#  1.1,
#  1.2222222222222223,
#  1.1346153846153846,
#  1.8,
#  nan,
#  1.1458333333333333,
#  1.1111111111111112,
#  nan,
#  1.0083333333333333,
#  1.0697727272727273,
#  1.1,
#  1.2222222222222223,
#  1.1346153846153846,
#  1.8,
#  nan,
#  1.1458333333333333,
#  nan,
#  1.119047619047619,
#  1.1818181818181819,
#  1.1923076923076923,
#  1.0695187165775402,
#  1.1143695014662756,
#  1.0421052631578946,
#  1.0932142857142857,
#  1.4255555555555555,
#  1.1165,
#  1.0477299185098952,
#  1.1236538461538461,
#  1.1,
#  1.0582010582010581,
#  2.3289156626506022,
#  1.0143198090692125,
#  1.0810810810810811,
#  1.099706744868035,
#  1.0256410256410255,
#  1.1523809523809523,
#  1.038338658146965,
#  1.09375,
#  1.0606060606060606,
#  1.0606060606060606,
#  1.0478846153846153,
#  1.2727272727272727,
#  1.1965811965811965,
#  1.317829457364341,
#  1.1218636363636363,
#  1.0047846889952152,
#  1.0287081339712918,
#  1.0266666666666666,
#  1.0214285714285714,
#  nan,
#  1.1230434782608696,
#  1.0153846153846153,
#  1.0232558139534884,
#  1.012,
#  1.0025714285714287,
#  1.0266666666666666,
#  1.15,
#  1.0195121951219512,
#  1.1,
#  nan,
#  1.0403333333333333,
#  nan,
#  1.0150632911392405,
#  1.056,
#  1.0694444444444444,
#  1.1407407407407408,
#  1.1,
#  1.3055555555555556,
#  1.0389610389610389,
#  1.088,
#  1.0431428571428571,
#  1.1120833333333333,
#  1.0384090909090908,
#  1.1317857142857144,
#  1.08,
#  1.1257894736842105,
#  1.0909090909090908,
#  1.1082142857142858,
#  1.2257142857142858,
#  nan,
#  1.1385185185185185,
#  1.0866315789473684,
#  1.1067816091954024,
#  1.1752941176470588,
#  1.2074643249176729,
#  1.0671936758893281,
#  1.1066666666666667,
#  1.0824,
#  nan,
#  1.0057142857142858,
#  nan,
#  1.0146103896103895,
#  nan,
#  1.1275,
#  1.2083333333333333,
#  1.05275,
#  nan,
#  1.05,
#  1.018181818181818,
#  1.0684375,
#  1.1,
#  1.053191489361702,
#  1.0755555555555556,
#  1.0276679841897234,
#  1.1676470588235295,
#  1.2137931034482758,
#  1.2178260869565218,
#  1.072857142857143,
#  1.0754545454545454,
#  1.0541110330288124,
#  1.0568181818181819,
#  1.0813559322033899,
#  1.1538461538461537,
#  1.1627906976744187,
#  1.5355086372360844,
#  1.2,
#  1.0366666666666666,
#  1.1071428571428572,
#  1.2618296529968454,
#  1.2263099219620959,
#  1.11,
#  1.2572222222222222,
#  1.103448275862069,
#  1.0745,
#  1.0131712259371835,
#  1.0714285714285714,
#  1.0640666666666667,
#  1.1556240369799693,
#  1.0375,
#  1.1605415860735009,
#  1.038888888888889,
#  1.053370786516854,
#  1.0144927536231885,
#  nan,
#  1.0606060606060606,
#  1.0526315789473684,
#  1.0346153846153847,
#  1.0317021276595744,
#  9.018181818181818,
#  1.050656660412758,
#  1.30625,
#  1.068125,
#  1.0101010101010102,
#  1.0325,
#  1.0231316725978647,
#  1.7408333333333332,
#  1.0526315789473684,
#  1.09,
#  1.1583333333333334,
#  1.0521739130434782,
#  1.0793984962406016,
#  1.035,
#  1.1244444444444444,
#  nan,
#  1.0,
#  1.0114285714285713,
#  1.0628205128205128,
#  1.0214285714285714,
#  1.0909090909090908,
#  1.1019283746556474,
#  1.1930769230769231,
#  1.2844444444444445,
#  1.0666666666666667,
#  1.125703564727955,
#  1.1428571428571428,
#  1.0769230769230769,
#  1.1029411764705883,
#  1.2032085561497325,
#  1.0515247108307044,
#  1.1275,
#  1.1553333333333333,
#  1.0942857142857143,
#  1.2066666666666668,
#  1.3871428571428572,
#  1.1904761904761905,
#  1.015,
#  nan,
#  2.36,
#  1.0603448275862069,
#  1.0863636363636364,
#  1.0196078431372548,
#  1.0844827586206895,
#  1.0638297872340425,
#  1.0,
#  1.02,
#  1.0227272727272727,
#  nan,
#  1.0,
#  1.14,
#  nan,
#  1.0,
#  1.0434782608695652,
#  1.0769230769230769,
#  1.0040160642570282,
#  1.0576923076923077,
#  1.0333333333333334,
#  1.1676923076923076,
#  1.105263157894737,
#  1.1333333333333333,
#  1.0238095238095237,
#  1.0576923076923077,
#  nan,
#  1.0606060606060606,
#  1.0277777777777777,
#  1.0526315789473684,
#  1.0769230769230769,
#  1.125,
#  1.1111111111111112,
#  nan,
#  1.0743589743589743,
#  1.1,
#  1.0615384615384615,
#  1.0377358490566038,
#  1.1333333333333333,
#  1.037037037037037,
#  nan,
#  1.0702341137123745,
#  1.1538461538461537,
#  1.0888888888888888,
#  1.0476190476190477,
#  1.3333333333333333,
#  1.1,
#  1.0128205128205128,
#  1.0909090909090908,
#  nan,
#  1.206896551724138,
#  1.0476190476190477,
#  nan,
#  1.0384615384615385,
#  nan,
#  nan,
#  1.0483870967741935,
#  1.073076923076923,
#  1.0285714285714285,
#  1.2272727272727273,
#  1.0033444816053512,
#  1.0805555555555555,
#  1.0612244897959184,
#  1.037037037037037,
#  1.024390243902439,
#  1.027027027027027,
#  1.125,
#  nan,
#  1.1428571428571428,
#  nan,
#  nan,
#  1.1615384615384616,
#  1.0153846153846153,
#  1.1764705882352942,
#  1.1666666666666667,
#  1.2903225806451613,
#  1.1111111111111112,
#  1.2195121951219512,
#  1.1625,
#  1.3114754098360655,
#  1.1764705882352942,
#  1.0169491525423728,
#  1.14,
#  1.2333333333333334,
#  1.33,
#  1.1055276381909547,
#  1.3125,
#  1.0291666666666666,
#  1.6470588235294117,
#  1.0555555555555556,
#  1.05,
#  1.0705882352941176,
#  1.1570247933884297,
#  1.3333333333333333,
#  1.2285714285714286,
#  1.1538461538461537,
#  1.28,
#  1.0204081632653061,
#  1.0169491525423728,
#  1.4814814814814814,
#  1.16,
#  1.35625,
#  1.1428571428571428,
#  1.0695652173913044,
#  1.1891891891891893,
#  nan,
#  1.2,
#  1.476923076923077,
#  1.0273972602739727,
#  1.1105263157894736,
#  1.25,
#  1.1123595505617978,
#  1.5873015873015872,
#  1.0344827586206897,
#  1.261111111111111,
#  1.1176470588235294,
#  nan,
#  1.1,
#  1.9230769230769231,
#  1.3445378151260505,
#  1.1111111111111112,
#  1.7073170731707317,
#  nan,
#  1.0833333333333333,
#  1.935483870967742,
#  1.05,
#  1.0126582278481013,
#  1.2583333333333333,
#  1.07,
#  1.4492753623188406,
#  1.1,
#  1.0277777777777777,
#  1.5,
#  1.0571428571428572,
#  1.1688311688311688,
#  1.111764705882353,
#  1.0666666666666667,
#  1.0050251256281406,
#  1.095,
#  1.0212765957446808,
#  1.0324483775811208,
#  nan,
#  10.391304347826088,
#  1.0582010582010581,
#  1.0460251046025104,
#  1.0196078431372548,
#  1.0666666666666667,
#  1.0582010582010581,
#  1.0833333333333333,
#  nan,
#  1.0847457627118644,
#  1.1382113821138211,
#  1.3333333333333333,
#  nan,
#  1.0714285714285714,
#  1.0703703703703704,
#  nan,
#  1.1428571428571428,
#  nan,
#  1.076,
#  nan,
#  nan,
#  1.3829787234042554,
#  nan,
#  1.1,
#  1.103448275862069,
#  1.040909090909091,
#  1.0,
#  nan,
#  1.0309278350515463,
#  1.0263157894736843,
#  nan,
#  1.1142857142857143,
#  nan,
#  1.4,
#  1.6666666666666667,
#  1.0043668122270741,
#  1.1538461538461537,
#  1.0208333333333333,
#  1.08,
#  1.094890510948905,
#  1.0535714285714286,
#  1.0644444444444445,
#  1.1666666666666667,
#  1.2052631578947368,
#  nan,
#  nan,
#  1.0204081632653061,
#  1.25,
#  1.146953405017921,
#  1.368421052631579,
#  nan,
#  nan,
#  1.0714285714285714,
#  1.0853658536585367,
#  1.1473684210526316,
#  1.1153846153846154,
#  1.0067114093959733,
#  1.1590909090909092,
#  1.126086956521739,
#  1.0681818181818181,
#  1.2222222222222223,
#  1.0,
#  1.1666666666666667,
#  nan,
#  nan,
#  1.0833333333333333,
#  nan,
#  1.1733333333333333,
#  nan,
#  1.0227272727272727,
#  1.0217391304347827,
#  nan,
#  1.0416666666666667,
#  1.0266666666666666,
#  1.194947080914988,
#  1.0153846153846153,
#  1.6018306636155606,
#  1.0442857142857143,
#  1.2307692307692308,
#  1.125,
#  1.159,
#  nan,
#  1.078,
#  nan,
#  1.077,
#  1.0150375939849625,
#  nan,
#  nan,
#  1.25,
#  3.0755711775043935,
#  1.0363636363636364,
#  1.3473684210526315,
#  1.5236567762630313,
#  2.037037037037037,
#  1.171875,
#  nan,
#  1.1188888888888888,
#  1.0822510822510822,
#  1.0577272727272726,
#  1.3183333333333334,
#  1.1524822695035462,
#  1.0751111111111111,
#  1.0583333333333333,
#  1.1764705882352942,
#  1.134,
#  1.03935,
#  1.0685714285714285,
#  1.0421601136901941,
#  1.1624527753560012,
#  1.0116906474820144,
#  1.0842,
#  1.045,
#  1.0330578512396693,
#  1.009493670886076,
#  1.0317460317460319,
#  1.019,
#  1.0523809523809524,
#  1.1834883720930232,
#  1.027111111111111,
#  nan,
#  1.028918918918919,
#  1.0,
#  1.094391244870041,
#  1.0521885521885521,
#  1.0008333333333332,
#  1.0152777777777777,
#  1.0563636363636364,
#  nan,
#  nan,
#  1.0833333333333333,
#  1.0999083409715857,
#  1.1145510835913313,
#  1.5126050420168067,
#  1.008125,
#  1.0344827586206897,
#  2.413793103448276,
#  1.09717868338558,
#  1.1872222222222222,
#  1.07,
#  1.0513636363636363,
#  1.1,
#  1.0714285714285714,
#  1.02,
#  1.1423076923076922,
#  nan,
#  1.0185185185185186,
#  1.079090909090909,
#  nan,
#  1.0891666666666666,
#  1.2019230769230769,
#  1.0736842105263158,
#  nan,
#  1.0947368421052632,
#  1.0666666666666667,
#  1.058873358746294,
#  nan,
#  1.0045454545454546,
#  1.035294117647059,
#  1.1538461538461537,
#  nan,
#  1.11875,
#  1.0431484115694643,
#  1.1160714285714286,
#  1.0741687979539642,
#  1.4892443463872036,
#  1.2304250559284116,
#  nan,
#  1.353846153846154,
#  nan,
#  1.0068649885583525,
#  1.0330578512396693,
#  1.0094736842105263,
#  1.161524500907441,
#  1.2987012987012987,
#  1.0,
#  1.2941176470588236,
#  1.0227272727272727,
#  nan,
#  1.0416666666666667,
#  1.4583333333333333,
#  nan,
#  1.0625,
#  nan,
#  1.1117974058060531,
#  1.2055555555555555,
#  1.4901960784313726,
#  1.1764705882352942,
#  1.1940298507462686,
#  1.4492753623188406,
#  2.807017543859649,
#  1.133888888888889,
#  nan,
#  1.8623481781376519,
#  1.0526315789473684,
#  1.2327777777777778,
#  1.0136847440446022,
#  1.3235294117647058,
#  nan,
#  1.013157894736842,
#  1.2903225806451613,
#  nan,
#  1.0721153846153846,
#  1.171875,
#  nan,
#  1.0333333333333334,
#  2.1153846153846154,
#  1.1475409836065573,
#  1.694915254237288,
#  1.025,
#  1.2096774193548387]

# %%
check2 = list()
for row in house1.iterrows():
  check2.append(check(row[1]['ราคาทรัพย์'],row[1]['ประเมิน2']))
check2
# Out:
# [1.0703703703703704,
#  1.0833333333333333,
#  1.487603305785124,
#  1.1891891891891893,
#  1.1,
#  1.0314685314685315,
#  1.050420168067227,
#  1.0416666666666667,
#  1.1403333333333334,
#  1.0175,
#  1.0476190476190477,
#  1.03125,
#  1.0214285714285714,
#  1.0607142857142857,
#  1.025,
#  nan,
#  1.0847222222222221,
#  1.0371428571428571,
#  1.0,
#  1.125,
#  1.1049723756906078,
#  1.1904761904761905,
#  1.0888888888888888,
#  1.0054461667364893,
#  1.0425531914893618,
#  1.125,
#  1.0434782608695652,
#  1.0364145658263306,
#  1.0,
#  1.0324483775811208,
#  1.04,
#  1.2,
#  1.04,
#  1.1318181818181818,
#  1.0,
#  1.045,
#  1.0526315789473684,
#  3.3333333333333335,
#  1.0227272727272727,
#  1.04,
#  1.08,
#  1.2903225806451613,
#  1.1219512195121952,
#  1.125,
#  1.075268817204301,
#  1.2322941176470588,
#  1.0755555555555556,
#  1.0775862068965518,
#  1.169004676018704,
#  1.0158013544018059,
#  1.048951048951049,
#  1.1777777777777778,
#  1.045,
#  1.0666666666666667,
#  1.0435897435897437,
#  1.036,
#  1.046,
#  1.0857142857142856,
#  1.0117361392148927,
#  1.1090909090909091,
#  1.0408163265306123,
#  1.1125,
#  1.036,
#  1.0031347962382444,
#  1.1,
#  1.1666666666666667,
#  1.0344827586206897,
#  1.0285714285714285,
#  1.0857142857142856,
#  1.0,
#  1.0769230769230769,
#  1.0263929618768328,
#  1.3007122948281202,
#  1.0693916349809887,
#  1.0625,
#  1.1578947368421053,
#  nan,
#  1.164021164021164,
#  1.0909090909090908,
#  1.0227563283047814,
#  1.25,
#  1.05,
#  1.05875,
#  1.046,
#  1.056,
#  1.1,
#  1.2542372881355932,
#  1.25,
#  1.0256410256410255,
#  1.018181818181818,
#  1.25,
#  1.05,
#  1.05875,
#  1.046,
#  1.056,
#  1.1,
#  1.2542372881355932,
#  1.25,
#  1.0256410256410255,
#  1.018181818181818,
#  nan,
#  1.0444444444444445,
#  nan,
#  1.04,
#  nan,
#  1.2316715542521994,
#  1.0606060606060606,
#  nan,
#  nan,
#  nan,
#  1.07375,
#  nan,
#  1.1,
#  1.26,
#  1.1381272633212622,
#  nan,
#  1.0810810810810811,
#  1.364,
#  1.17,
#  nan,
#  1.0433333333333332,
#  nan,
#  nan,
#  nan,
#  1.0898,
#  nan,
#  nan,
#  nan,
#  nan,
#  1.0047846889952152,
#  nan,
#  1.1,
#  1.048951048951049,
#  1.0606060606060606,
#  1.174090909090909,
#  1.056,
#  nan,
#  1.0276679841897234,
#  1.1969222000569963,
#  1.0266666666666666,
#  nan,
#  1.045,
#  1.0822510822510822,
#  1.0330578512396693,
#  nan,
#  1.15,
#  9.976306272602569,
#  1.0153846153846153,
#  1.0909090909090908,
#  1.1,
#  nan,
#  1.175,
#  1.1688311688311688,
#  nan,
#  1.0431428571428571,
#  nan,
#  nan,
#  1.0563333333333333,
#  nan,
#  1.0695,
#  1.0909090909090908,
#  1.0343333333333333,
#  1.0725,
#  nan,
#  1.0246666666666666,
#  1.0323,
#  1.0385294423096896,
#  1.1011011011011012,
#  1.0976948408342482,
#  1.383399209486166,
#  1.355421686746988,
#  1.0824,
#  nan,
#  1.1079545454545454,
#  nan,
#  1.0146103896103895,
#  nan,
#  nan,
#  nan,
#  1.05275,
#  1.1730205278592376,
#  nan,
#  nan,
#  1.0684375,
#  1.1647058823529413,
#  1.0101010101010102,
#  nan,
#  1.012,
#  1.2594458438287153,
#  nan,
#  nan,
#  1.072857142857143,
#  1.098901098901099,
#  nan,
#  nan,
#  1.0633333333333332,
#  1.2666666666666666,
#  1.1627906976744187,
#  nan,
#  nan,
#  1.2057877813504823,
#  1.1612903225806452,
#  1.025236593059937,
#  1.0033444816053512,
#  1.0237510237510237,
#  nan,
#  1.206896551724138,
#  1.0469986040018613,
#  nan,
#  1.0714285714285714,
#  1.3300833333333333,
#  1.2326656394453004,
#  1.0120481927710843,
#  1.1605415860735009,
#  1.0427807486631016,
#  1.053370786516854,
#  1.0144927536231885,
#  nan,
#  1.0101010101010102,
#  1.0526315789473684,
#  1.1208333333333333,
#  1.031140441328109,
#  nan,
#  1.066,
#  1.0047846889952152,
#  nan,
#  1.0101010101010102,
#  nan,
#  1.112099644128114,
#  1.0531354715174726,
#  1.0291666666666666,
#  1.1009174311926606,
#  1.079136690647482,
#  nan,
#  1.0448592922819726,
#  1.1187388761759471,
#  1.331578947368421,
#  1.0344827586206897,
#  1.1,
#  nan,
#  1.03625,
#  1.43,
#  1.03125,
#  1.1019283746556474,
#  1.0315925209542232,
#  nan,
#  1.024,
#  1.1104166666666666,
#  1.1428571428571428,
#  1.0714285714285714,
#  1.02,
#  1.0695187165775402,
#  nan,
#  1.1086474501108647,
#  1.154068090017311,
#  nan,
#  1.1049723756906078,
#  1.21375,
#  1.1904761904761905,
#  1.015,
#  nan,
#  nan,
#  nan,
#  1.0878661087866108,
#  1.0196078431372548,
#  1.0483333333333333,
#  1.1111111111111112,
#  1.0588235294117647,
#  1.0893246187363834,
#  1.125,
#  1.0727272727272728,
#  nan,
#  10.175438596491228,
#  1.0526315789473684,
#  1.0,
#  1.0416666666666667,
#  1.037037037037037,
#  1.0040160642570282,
#  1.0909090909090908,
#  1.075268817204301,
#  1.0540184453227932,
#  nan,
#  1.0,
#  1.0238095238095237,
#  1.0,
#  nan,
#  nan,
#  1.0810810810810811,
#  nan,
#  nan,
#  1.1111111111111112,
#  1.0,
#  1.0526315789473684,
#  1.0023866348448687,
#  1.0101010101010102,
#  1.0,
#  nan,
#  nan,
#  1.037037037037037,
#  1.0576923076923077,
#  1.0702341137123745,
#  1.0833333333333333,
#  1.0315789473684212,
#  1.0,
#  1.25,
#  1.1,
#  nan,
#  nan,
#  nan,
#  1.103448275862069,
#  1.1904761904761905,
#  1.0,
#  1.0769230769230769,
#  1.1111111111111112,
#  nan,
#  nan,
#  1.075268817204301,
#  1.0833333333333333,
#  1.0909090909090908,
#  1.0678571428571428,
#  nan,
#  1.0204081632653061,
#  nan,
#  1.0975609756097562,
#  1.135135135135135,
#  nan,
#  nan,
#  1.1666666666666667,
#  1.1728395061728396,
#  nan,
#  1.0066666666666666,
#  1.2923076923076924,
#  nan,
#  1.1666666666666667,
#  1.075268817204301,
#  1.35,
#  1.024390243902439,
#  1.075268817204301,
#  nan,
#  1.680672268907563,
#  1.10625,
#  1.0526315789473684,
#  1.2333333333333334,
#  nan,
#  nan,
#  1.0666666666666667,
#  1.214574898785425,
#  nan,
#  nan,
#  nan,
#  nan,
#  1.21,
#  1.0714285714285714,
#  1.075,
#  1.0576923076923077,
#  1.0416666666666667,
#  1.0204081632653061,
#  1.18,
#  1.0125,
#  1.0875,
#  1.1059907834101383,
#  1.5238095238095237,
#  1.1181818181818182,
#  nan,
#  nan,
#  1.12,
#  nan,
#  1.0273972602739727,
#  1.1374407582938388,
#  1.125,
#  nan,
#  nan,
#  1.1494252873563218,
#  1.0572687224669604,
#  1.0555555555555556,
#  nan,
#  nan,
#  1.04,
#  1.0924369747899159,
#  1.0526315789473684,
#  1.2195121951219512,
#  nan,
#  nan,
#  1.1625,
#  1.0317460317460319,
#  nan,
#  1.1615384615384616,
#  1.1214953271028036,
#  1.4492753623188406,
#  1.0909090909090908,
#  nan,
#  1.25,
#  1.1384615384615384,
#  1.1,
#  nan,
#  1.0666666666666667,
#  1.1055276381909547,
#  1.095,
#  1.0416666666666667,
#  nan,
#  1.09375,
#  10.863636363636363,
#  1.0052910052910053,
#  1.0,
#  nan,
#  nan,
#  1.0582010582010581,
#  1.0666666666666667,
#  nan,
#  1.0169491525423728,
#  1.056910569105691,
#  nan,
#  nan,
#  nan,
#  1.0,
#  nan,
#  1.0,
#  1.0,
#  1.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  1.09375,
#  1.040909090909091,
#  1.1538461538461537,
#  nan,
#  1.1111111111111112,
#  1.0256410256410255,
#  nan,
#  1.0256410256410255,
#  nan,
#  1.05,
#  1.0,
#  1.091703056768559,
#  1.0,
#  1.0208333333333333,
#  1.0,
#  1.013787510137875,
#  nan,
#  nan,
#  nan,
#  nan,
#  1.0285714285714285,
#  1.0612244897959184,
#  1.0204081632653061,
#  nan,
#  nan,
#  1.0,
#  nan,
#  1.0,
#  1.0714285714285714,
#  nan,
#  1.1009174311926606,
#  1.0545454545454545,
#  nan,
#  1.0588235294117647,
#  nan,
#  1.0638297872340425,
#  1.1,
#  1.0454545454545454,
#  1.05,
#  nan,
#  1.16,
#  1.0769230769230769,
#  1.0,
#  1.2571428571428571,
#  nan,
#  1.0227272727272727,
#  nan,
#  nan,
#  1.0416666666666667,
#  1.103896103896104,
#  1.0242403550699897,
#  1.0153846153846153,
#  1.0297482837528604,
#  1.0442857142857143,
#  1.5384615384615385,
#  nan,
#  nan,
#  1.0774410774410774,
#  1.078,
#  1.012,
#  nan,
#  1.064,
#  nan,
#  nan,
#  nan,
#  nan,
#  1.0363636363636364,
#  1.0795454545454546,
#  nan,
#  nan,
#  1.0666666666666667,
#  nan,
#  1.1188888888888888,
#  1.05,
#  nan,
#  nan,
#  nan,
#  nan,
#  1.1023622047244095,
#  1.278772378516624,
#  1.0005882352941176,
#  nan,
#  1.0695187165775402,
#  nan,
#  nan,
#  1.1241007194244603,
#  1.0842,
#  nan,
#  1.0330578512396693,
#  1.0031347962382444,
#  1.05,
#  nan,
#  1.1312217194570136,
#  nan,
#  nan,
#  1.1705685618729098,
#  1.0877142857142856,
#  1.0277777777777777,
#  1.094391244870041,
#  nan,
#  1.2489592006661117,
#  1.231190150478796,
#  nan,
#  nan,
#  nan,
#  nan,
#  1.2832263978001832,
#  1.08359133126935,
#  1.2100840336134453,
#  nan,
#  1.09717868338558,
#  2.0689655172413794,
#  1.0633333333333332,
#  1.169864295741694,
#  1.0136842105263157,
#  nan,
#  1.1407407407407408,
#  1.0389610389610389,
#  nan,
#  nan,
#  nan,
#  1.0185185185185186,
#  nan,
#  1.0476190476190477,
#  nan,
#  1.5024038461538463,
#  1.0784313725490196,
#  1.1067193675889329,
#  1.0526315789473684,
#  1.3333333333333333,
#  nan,
#  nan,
#  1.0045454545454546,
#  1.1764705882352942,
#  1.6025641025641026,
#  1.0909090909090908,
#  1.0614525139664805,
#  nan,
#  1.4285714285714286,
#  nan,
#  1.2134583563154993,
#  1.3982102908277405,
#  nan,
#  nan,
#  1.2222222222222223,
#  1.1441647597254005,
#  nan,
#  nan,
#  1.0889292196007259,
#  1.4757969303423848,
#  nan,
#  1.2941176470588236,
#  1.1363636363636365,
#  nan,
#  1.1666666666666667,
#  nan,
#  nan,
#  1.0588235294117647,
#  nan,
#  nan,
#  nan,
#  1.0625,
#  1.1764705882352942,
#  1.1940298507462686,
#  1.2077294685990339,
#  nan,
#  1.224889759921607,
#  1.018181818181818,
#  1.6194331983805668,
#  1.6541353383458646,
#  1.0086363636363636,
#  1.2671059300557526,
#  1.1029411764705883,
#  1.2857142857142858,
#  nan,
#  nan,
#  nan,
#  1.0762331838565022,
#  1.25,
#  1.0833333333333333,
#  nan,
#  1.1538461538461537,
#  1.22,
#  1.0169491525423728,
#  1.23,
#  1.1290322580645162]

# %%
house1['check1'] = check1
house1['check2'] = check2
house1
# Out:
# <ipython-input-68-f70529ae8681>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house1['check1'] = check1
# <ipython-input-68-f70529ae8681>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house1['check2'] = check2
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 1       https://nayoo.co/khonkaen/posts/25     2890000  2500000.0  2700000.0
# 3       https://nayoo.co/khonkaen/posts/33     2600000  2200000.0  2400000.0
# 5      https://nayoo.co/khonkaen/posts/495     6050000  5000000.0  9000000.0
# 7      https://nayoo.co/khonkaen/posts/564     4400000  3500000.0  3700000.0
# 9      https://nayoo.co/khonkaen/posts/566     2750000  2500000.0  2500000.0
# ...                                    ...         ...        ...        ...
# 1210  https://nayoo.co/khonkaen/posts/6255      260000   550000.0   300000.0
# 1212  https://nayoo.co/khonkaen/posts/6256      610000   700000.0   500000.0
# 1214  https://nayoo.co/khonkaen/posts/6257      295000   500000.0   300000.0
# 1216  https://nayoo.co/khonkaen/posts/6258      615000   600000.0   500000.0
# 1218  https://nayoo.co/khonkaen/posts/6260      620000   750000.0   700000.0
#
#                          ให้คะแนนทรัพย์ ความมั่นใจในการเมินราคาทรัพย์  \
# 1      4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                        มั่นใจ
# 3     3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 5     5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน                        มั่นใจ
# 7     3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 9     3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# ...                                 ...                           ...
# 1210  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 1212  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 1214  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 1216  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 1218  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
#
#         check1    check2
# 1     1.156000  1.070370
# 3     1.181818  1.083333
# 5     1.210000  1.487603
# 7     1.257143  1.189189
# 9     1.100000  1.100000
# ...        ...       ...
# 1210  2.115385  1.153846
# 1212  1.147541  1.220000
# 1214  1.694915  1.016949
# 1216  1.025000  1.230000
# 1218  1.209677  1.129032
#
# [610 rows x 8 columns]

# %%
house1.sort_values(by=['check1'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 802   https://nayoo.co/khonkaen/posts/3208    23900000  2300000.0  2200000.0
# 444   https://nayoo.co/khonkaen/posts/1133     1984000   220000.0        NaN
# 978   https://nayoo.co/khonkaen/posts/5959     1138000  3500000.0        NaN
# 1179  https://nayoo.co/khonkaen/posts/6117      570000  1600000.0        NaN
# 1070  https://nayoo.co/khonkaen/posts/6037     1450000  3500000.0  3000000.0
# ...                                    ...         ...        ...        ...
# 1165  https://nayoo.co/khonkaen/posts/6106     2200000        NaN        NaN
# 1183  https://nayoo.co/khonkaen/posts/6126     2240000        NaN  2200000.0
# 1195  https://nayoo.co/khonkaen/posts/6156     3500000        NaN  4500000.0
# 1200  https://nayoo.co/khonkaen/posts/6158     3850000        NaN        NaN
# 1206  https://nayoo.co/khonkaen/posts/6178     2400000        NaN  2600000.0
#
#                          ให้คะแนนทรัพย์ ความมั่นใจในการเมินราคาทรัพย์  \
# 802   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 444                                 NaN                     ไม่มั่นใจ
# 978                                 NaN                     ไม่มั่นใจ
# 1179                                NaN                     ไม่มั่นใจ
# 1070  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# ...                                 ...                           ...
# 1165  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 1183  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 1195   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                        มั่นใจ
# 1200   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                        มั่นใจ
# 1206   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                        มั่นใจ
#
#          check1     check2
# 802   10.391304  10.863636
# 444    9.018182        NaN
# 978    3.075571        NaN
# 1179   2.807018        NaN
# 1070   2.413793   2.068966
# ...         ...        ...
# 1165        NaN        NaN
# 1183        NaN   1.018182
# 1195        NaN   1.285714
# 1200        NaN        NaN
# 1206        NaN   1.083333
#
# [610 rows x 8 columns]

# %%
house1.sort_values(by=['check2'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1    ประเมิน2  \
# 802   https://nayoo.co/khonkaen/posts/3208    23900000  2300000.0   2200000.0
# 544   https://nayoo.co/khonkaen/posts/1619     2850000  2500000.0  29000000.0
# 292    https://nayoo.co/khonkaen/posts/622     8019000  7900000.0  80000000.0
# 75       https://nayoo.co/khonkaen/posts/1      390000   600000.0   1300000.0
# 1070  https://nayoo.co/khonkaen/posts/6037     1450000  3500000.0   3000000.0
# ...                                    ...         ...        ...         ...
# 1179  https://nayoo.co/khonkaen/posts/6117      570000  1600000.0         NaN
# 1197  https://nayoo.co/khonkaen/posts/6157     3850000  3800000.0         NaN
# 1199  https://nayoo.co/khonkaen/posts/6261      620000   800000.0         NaN
# 1200  https://nayoo.co/khonkaen/posts/6158     3850000        NaN         NaN
# 1208  https://nayoo.co/khonkaen/posts/6242      930000   900000.0         NaN
#
#                           ให้คะแนนทรัพย์ ความมั่นใจในการเมินราคาทรัพย์  \
# 802    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 544    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 292   2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี                        มั่นใจ
# 75      4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                        มั่นใจ
# 1070   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# ...                                  ...                           ...
# 1179                                 NaN                     ไม่มั่นใจ
# 1197    4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                        มั่นใจ
# 1199                                 NaN                     ไม่มั่นใจ
# 1200    4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                        มั่นใจ
# 1208                                 NaN                     ไม่มั่นใจ
#
#          check1     check2
# 802   10.391304  10.863636
# 544    1.140000  10.175439
# 292    1.015063   9.976306
# 75     1.538462   3.333333
# 1070   2.413793   2.068966
# ...         ...        ...
# 1179   2.807018        NaN
# 1197   1.013158        NaN
# 1199   1.290323        NaN
# 1200        NaN        NaN
# 1208   1.033333        NaN
#
# [610 rows x 8 columns]

# %% [markdown]
# ##ที่ดิน

# %%
land1 = est2_land[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2']]
land1
# Out:
#                                    post id  ราคาทรัพย์    ประเมิน1    ประเมิน2
# 1     https://nayoo.co/khonkaen/posts/1033     2800000   1800000.0   2000000.0
# 4     https://nayoo.co/khonkaen/posts/1711    14900000   8000000.0  12000000.0
# 7     https://nayoo.co/khonkaen/posts/1726    90000000  18000000.0  70000000.0
# 10    https://nayoo.co/khonkaen/posts/1732    65000000  35000000.0  60000000.0
# 13    https://nayoo.co/khonkaen/posts/1866     3000000   2200000.0   2500000.0
# ..                                     ...         ...         ...         ...
# 200  https://nayoo.co/khonkaen/posts/14539     5000000   4000000.0   4000000.0
# 202  https://nayoo.co/khonkaen/posts/16072      750000    500000.0    750000.0
# 204  https://nayoo.co/khonkaen/posts/17093     2650000   2000000.0   2500000.0
# 206  https://nayoo.co/khonkaen/posts/17112     1300000   1500000.0   1500000.0
# 208  https://nayoo.co/khonkaen/posts/17145     3000000   2500000.0   2800000.0
#
# [100 rows x 4 columns]

# %%
check1 = list()
for row in land1.iterrows():
  check1.append(check(row[1]['ราคาทรัพย์'],row[1]['ประเมิน1']))
check1
# Out:
# [1.5555555555555556,
#  1.8625,
#  5.0,
#  1.8571428571428572,
#  1.3636363636363635,
#  1.5,
#  4.714285714285714,
#  1.1363636363636365,
#  1.6,
#  1.1964285714285714,
#  1.2,
#  1.2,
#  1.125,
#  1.1666666666666667,
#  1.0476190476190477,
#  1.2105263157894737,
#  1.2,
#  1.1666666666666667,
#  10.208333333333334,
#  1.35,
#  1.1428571428571428,
#  1.1,
#  1.411764705882353,
#  1.5,
#  8.571428571428571,
#  1.2515644555694618,
#  2.25,
#  1.4074074074074074,
#  4.7825,
#  1.25,
#  4.0,
#  1.2,
#  2.5,
#  1.2727272727272727,
#  1.0204081632653061,
#  1.2666666666666666,
#  1.0833333333333333,
#  1.0416666666666667,
#  2.5,
#  1.2882882882882882,
#  1.6666666666666667,
#  1.1111111111111112,
#  1.25,
#  1.2363636363636363,
#  1.2857142857142858,
#  1.0101010101010102,
#  1.8125,
#  2.8857142857142857,
#  1.39,
#  1.3,
#  1.39,
#  12.307692307692308,
#  1.2380952380952381,
#  1.25,
#  1.29,
#  1.481111111111111,
#  1.0,
#  1.4285714285714286,
#  1.2761363636363636,
#  1.0968333333333333,
#  1.0,
#  2.25,
#  1.1764705882352942,
#  1.1346153846153846,
#  1.25,
#  1.1875,
#  1.5,
#  1.0625,
#  1.2075,
#  1.2290916666666667,
#  1.25,
#  1.28,
#  1.2075,
#  1.1333333333333333,
#  1.25,
#  1.2765,
#  1.3333333333333333,
#  1.3277714285714286,
#  1.2307692307692308,
#  1.2727272727272727,
#  1.2173913043478262,
#  1.0415714285714286,
#  1.8181818181818181,
#  1.1142857142857143,
#  1.328,
#  1.1426785714285714,
#  1.0256410256410255,
#  1.05,
#  1.0714285714285714,
#  1.0869565217391304,
#  1.0529411764705883,
#  2.5714285714285716,
#  20.0,
#  1.66,
#  1.125,
#  1.25,
#  1.5,
#  1.325,
#  1.1538461538461537,
#  1.2]

# %%
check2 = list()
for row in land1.iterrows():
  check2.append(check(row[1]['ราคาทรัพย์'],row[1]['ประเมิน2']))
check2
# Out:
# [1.4,
#  1.2416666666666667,
#  1.2857142857142858,
#  1.0833333333333333,
#  1.2,
#  1.2,
#  1.2692307692307692,
#  1.1363636363636365,
#  1.2,
#  1.1166666666666667,
#  1.3333333333333333,
#  1.0909090909090908,
#  2.8125,
#  1.0,
#  1.0606060606060606,
#  1.9166666666666667,
#  1.0416666666666667,
#  1.0285714285714285,
#  13.61111111111111,
#  1.9285714285714286,
#  1.1111111111111112,
#  1.1,
#  1.1764705882352942,
#  1.25,
#  10.909090909090908,
#  1.0012515644555695,
#  1.1111111111111112,
#  1.35,
#  1.2753333333333334,
#  1.25,
#  1.1666666666666667,
#  1.2,
#  1.1904761904761905,
#  1.12,
#  1.225,
#  1.2666666666666666,
#  1.2,
#  1.2,
#  1.1363636363636365,
#  1.144,
#  1.2,
#  1.1627906976744187,
#  1.0666666666666667,
#  1.0588235294117647,
#  1.2352941176470589,
#  1.2375,
#  1.16,
#  1.01,
#  1.1583333333333334,
#  1.0833333333333333,
#  1.1583333333333334,
#  1.3,
#  1.0476190476190477,
#  1.0714285714285714,
#  1.075,
#  1.333,
#  1.0769230769230769,
#  1.25,
#  1.40375,
#  1.0968333333333333,
#  1.1363636363636365,
#  1.125,
#  1.0625,
#  1.18,
#  1.25,
#  1.0555555555555556,
#  1.2,
#  5.294117647058823,
#  1.2075,
#  10.8481195462774,
#  1.1,
#  1.1363636363636365,
#  1.2075,
#  1.1176470588235294,
#  1.0,
#  1.4183333333333332,
#  1.3333333333333333,
#  1.1618,
#  1.0666666666666667,
#  1.0714285714285714,
#  1.0769230769230769,
#  1.4582,
#  1.3636363636363635,
#  1.0833333333333333,
#  1.0375,
#  1.0665,
#  1.0256410256410255,
#  1.05,
#  1.0344827586206897,
#  10.434782608695652,
#  1.11875,
#  1.8,
#  1.2,
#  1.1066666666666667,
#  1.0555555555555556,
#  1.25,
#  1.0,
#  1.06,
#  1.1538461538461537,
#  1.0714285714285714]

# %%
land1['check1'] = check1
land1['check2'] = check2
land1
# Out:
# <ipython-input-74-cc88797ae58b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   land1['check1'] = check1
# <ipython-input-74-cc88797ae58b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   land1['check2'] = check2
#                                    post id  ราคาทรัพย์    ประเมิน1  \
# 1     https://nayoo.co/khonkaen/posts/1033     2800000   1800000.0
# 4     https://nayoo.co/khonkaen/posts/1711    14900000   8000000.0
# 7     https://nayoo.co/khonkaen/posts/1726    90000000  18000000.0
# 10    https://nayoo.co/khonkaen/posts/1732    65000000  35000000.0
# 13    https://nayoo.co/khonkaen/posts/1866     3000000   2200000.0
# ..                                     ...         ...         ...
# 200  https://nayoo.co/khonkaen/posts/14539     5000000   4000000.0
# 202  https://nayoo.co/khonkaen/posts/16072      750000    500000.0
# 204  https://nayoo.co/khonkaen/posts/17093     2650000   2000000.0
# 206  https://nayoo.co/khonkaen/posts/17112     1300000   1500000.0
# 208  https://nayoo.co/khonkaen/posts/17145     3000000   2500000.0
#
#        ประเมิน2    check1    check2
# 1     2000000.0  1.555556  1.400000
# 4    12000000.0  1.862500  1.241667
# 7    70000000.0  5.000000  1.285714
# 10   60000000.0  1.857143  1.083333
# 13    2500000.0  1.363636  1.200000
# ..          ...       ...       ...
# 200   4000000.0  1.250000  1.250000
# 202    750000.0  1.500000  1.000000
# 204   2500000.0  1.325000  1.060000
# 206   1500000.0  1.153846  1.153846
# 208   2800000.0  1.200000  1.071429
#
# [100 rows x 6 columns]

# %%
land1.sort_values(by=['check1'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์    ประเมิน1  \
# 194  https://nayoo.co/khonkaen/posts/13702    90000000   4500000.0
# 112   https://nayoo.co/khonkaen/posts/7955     2600000  32000000.0
# 47    https://nayoo.co/khonkaen/posts/7349   245000000  24000000.0
# 58    https://nayoo.co/khonkaen/posts/9203   120000000  14000000.0
# 7     https://nayoo.co/khonkaen/posts/1726    90000000  18000000.0
# ..                                     ...         ...         ...
# 182   https://nayoo.co/khonkaen/posts/9598     3900000   4000000.0
# 78    https://nayoo.co/khonkaen/posts/3447      980000   1000000.0
# 100   https://nayoo.co/khonkaen/posts/1663     1485000   1500000.0
# 122  https://nayoo.co/khonkaen/posts/12762      650000    650000.0
# 130   https://nayoo.co/khonkaen/posts/1599     2500000   2500000.0
#
#        ประเมิน2     check1     check2
# 194  75000000.0  20.000000   1.200000
# 112   2000000.0  12.307692   1.300000
# 47   18000000.0  10.208333  13.611111
# 58   11000000.0   8.571429  10.909091
# 7    70000000.0   5.000000   1.285714
# ..          ...        ...        ...
# 182   4000000.0   1.025641   1.025641
# 78     800000.0   1.020408   1.225000
# 100   1200000.0   1.010101   1.237500
# 122    700000.0   1.000000   1.076923
# 130   2200000.0   1.000000   1.136364
#
# [100 rows x 6 columns]

# %%
land1.sort_values(by=['check2'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์    ประเมิน1  \
# 47    https://nayoo.co/khonkaen/posts/7349   245000000  24000000.0
# 58    https://nayoo.co/khonkaen/posts/9203   120000000  14000000.0
# 148   https://nayoo.co/khonkaen/posts/3561     7374550   6000000.0
# 188  https://nayoo.co/khonkaen/posts/12250     2300000   2500000.0
# 144   https://nayoo.co/khonkaen/posts/3341     1700000   1600000.0
# ..                                     ...         ...         ...
# 104   https://nayoo.co/khonkaen/posts/1921     8080000   2800000.0
# 60   https://nayoo.co/khonkaen/posts/12607     7990000  10000000.0
# 202  https://nayoo.co/khonkaen/posts/16072      750000    500000.0
# 158   https://nayoo.co/khonkaen/posts/6732     3500000   2800000.0
# 37    https://nayoo.co/khonkaen/posts/3305    14000000  12000000.0
#
#        ประเมิน2     check1     check2
# 47   18000000.0  10.208333  13.611111
# 58   11000000.0   8.571429  10.909091
# 148  80000000.0   1.229092  10.848120
# 188  24000000.0   1.086957  10.434783
# 144   9000000.0   1.062500   5.294118
# ..          ...        ...        ...
# 104   8000000.0   2.885714   1.010000
# 60    8000000.0   1.251564   1.001252
# 202    750000.0   1.500000   1.000000
# 158   3500000.0   1.250000   1.000000
# 37   14000000.0   1.166667   1.000000
#
# [100 rows x 6 columns]

# %% [markdown]
# ## คอนโด

# %%
condo1 = est1_condo[['post id','ราคาทรัพย์','ประเมิน1']]
condo1
# Out:
#    post id  ราคาทรัพย์   ประเมิน1
# 0     32.0     3500000  3500000.0
# 1     36.0     1930000  2200000.0
# 2    603.0     2438000  2800000.0
# 3   1395.0     1600000  2300000.0
# 4   1443.0     1860000  1800000.0
# 5   1609.0     1490000  1500000.0
# 6   1640.0     1280000  1600000.0
# 7   1641.0     4290000  2700000.0
# 8   1650.0     1700000  1550000.0
# 9   1840.0     3790000  2800000.0

# %%
check1 = list()
for row in condo1.iterrows():
  check1.append(check(row[1]['ราคาทรัพย์'],row[1]['ประเมิน1']))
check1
# Out:
# [1.0,
#  1.1398963730569949,
#  1.1484823625922889,
#  1.4375,
#  1.0333333333333334,
#  1.0067114093959733,
#  1.25,
#  1.5888888888888888,
#  1.096774193548387,
#  1.3535714285714286]

# %%
condo1['check1'] = check1
condo1
# Out:
# <ipython-input-79-5f1dab82e761>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condo1['check1'] = check1
#    post id  ราคาทรัพย์   ประเมิน1    check1
# 0     32.0     3500000  3500000.0  1.000000
# 1     36.0     1930000  2200000.0  1.139896
# 2    603.0     2438000  2800000.0  1.148482
# 3   1395.0     1600000  2300000.0  1.437500
# 4   1443.0     1860000  1800000.0  1.033333
# 5   1609.0     1490000  1500000.0  1.006711
# 6   1640.0     1280000  1600000.0  1.250000
# 7   1641.0     4290000  2700000.0  1.588889
# 8   1650.0     1700000  1550000.0  1.096774
# 9   1840.0     3790000  2800000.0  1.353571

# %%
condo1.sort_values(by=['check1'],ascending=False)
# Out:
#    post id  ราคาทรัพย์   ประเมิน1    check1
# 7   1641.0     4290000  2700000.0  1.588889
# 3   1395.0     1600000  2300000.0  1.437500
# 9   1840.0     3790000  2800000.0  1.353571
# 6   1640.0     1280000  1600000.0  1.250000
# 2    603.0     2438000  2800000.0  1.148482
# 1     36.0     1930000  2200000.0  1.139896
# 8   1650.0     1700000  1550000.0  1.096774
# 4   1443.0     1860000  1800000.0  1.033333
# 5   1609.0     1490000  1500000.0  1.006711
# 0     32.0     3500000  3500000.0  1.000000

# %% [markdown]
# ## ทาวน์โฮม

# %%
townhome1 = est2_townhome[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2']]
townhome1
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2
# 1      https://nayoo.co/khonkaen/posts/548     1045000   700000.0  1500000.0
# 3      https://nayoo.co/khonkaen/posts/549      935000   700000.0  1500000.0
# 5      https://nayoo.co/khonkaen/posts/579     2520000  3500000.0  4000000.0
# 7      https://nayoo.co/khonkaen/posts/580     3850000  3500000.0  3200000.0
# 9      https://nayoo.co/khonkaen/posts/582      544000  1000000.0   800000.0
# ..                                     ...         ...        ...        ...
# 235  https://nayoo.co/khonkaen/posts/18547     1105000  1000000.0  1200000.0
# 236  https://nayoo.co/khonkaen/posts/18551     1440000  1500000.0  1700000.0
# 237  https://nayoo.co/khonkaen/posts/19434     2000000  1600000.0  1900000.0
# 238  https://nayoo.co/khonkaen/posts/19501     1790000  1600000.0  1700000.0
# 239  https://nayoo.co/khonkaen/posts/20367     1590000  1700000.0  1700000.0
#
# [120 rows x 4 columns]

# %%
check1 = list()
for row in townhome1.iterrows():
  check1.append(check(row[1]['ราคาทรัพย์'],row[1]['ประเมิน1']))
check1
# Out:
# [1.4928571428571429,
#  1.3357142857142856,
#  1.3888888888888888,
#  1.1,
#  1.838235294117647,
#  1.0263929618768328,
#  1.0330578512396693,
#  1.2820512820512822,
#  1.3138888888888889,
#  1.1363636363636365,
#  1.1,
#  1.144,
#  1.0263157894736843,
#  1.0083333333333333,
#  1.0476190476190477,
#  1.0666666666666667,
#  1.0266666666666666,
#  1.05,
#  1.1,
#  1.1560693641618498,
#  1.1,
#  1.322314049586777,
#  1.048951048951049,
#  1.1,
#  1.12,
#  1.1428571428571428,
#  1.0666666666666667,
#  1.069182389937107,
#  1.1083333333333334,
#  1.037037037037037,
#  1.040909090909091,
#  1.08,
#  1.2222222222222223,
#  1.0416666666666667,
#  1.036,
#  1.1538461538461537,
#  1.1235955056179776,
#  1.04,
#  1.0502283105022832,
#  1.079136690647482,
#  1.02,
#  1.0714285714285714,
#  1.00625,
#  1.3333333333333333,
#  1.25,
#  1.0416666666666667,
#  1.2,
#  1.0040160642570282,
#  1.1510791366906474,
#  1.0391304347826087,
#  1.0681818181818181,
#  1.1428571428571428,
#  1.0833333333333333,
#  1.07,
#  1.46,
#  1.125,
#  6.257142857142857,
#  1.0588235294117647,
#  1.0526315789473684,
#  1.1071428571428572,
#  1.047486033519553,
#  1.1363636363636365,
#  1.045,
#  1.09375,
#  1.065625,
#  1.0692307692307692,
#  1.0285714285714285,
#  1.0588235294117647,
#  1.03125,
#  1.103448275862069,
#  1.08,
#  1.037037037037037,
#  1.0666666666666667,
#  1.0285714285714285,
#  1.1705882352941177,
#  1.0535714285714286,
#  1.0266666666666666,
#  1.0740740740740742,
#  1.0416666666666667,
#  1.0666666666666667,
#  1.0,
#  1.0588235294117647,
#  1.1363636363636365,
#  1.0,
#  1.02,
#  1.0186666666666666,
#  1.6692307692307693,
#  1.0333333333333334,
#  1.0666666666666667,
#  1.1333333333333333,
#  1.1066666666666667,
#  1.06875,
#  1.0588235294117647,
#  1.0909090909090908,
#  1.35,
#  1.2285714285714286,
#  1.5476190476190477,
#  1.2244897959183674,
#  1.125,
#  1.0084033613445378,
#  1.037037037037037,
#  1.1666666666666667,
#  1.125,
#  1.1428571428571428,
#  1.1495,
#  1.1363636363636365,
#  1.1818181818181819,
#  1.0625,
#  1.0050251256281406,
#  1.0606060606060606,
#  1.1,
#  1.044932079414838,
#  1.3636363636363635,
#  1.037037037037037,
#  1.0178571428571428,
#  1.105,
#  1.0416666666666667,
#  1.25,
#  1.11875,
#  1.069182389937107]

# %%
check2 = list()
for row in townhome1.iterrows():
  check2.append(check(row[1]['ราคาทรัพย์'],row[1]['ประเมิน2']))
check2
# Out:
# [1.4354066985645932,
#  1.6042780748663101,
#  1.5873015873015872,
#  1.203125,
#  1.4705882352941178,
#  1.065625,
#  1.1,
#  1.2820512820512822,
#  1.1825,
#  1.0620689655172413,
#  1.1,
#  1.144,
#  1.0256410256410255,
#  1.0371428571428571,
#  1.1,
#  1.0666666666666667,
#  1.0266666666666666,
#  1.05,
#  1.0909090909090908,
#  1.4450867052023122,
#  1.1,
#  1.0743801652892562,
#  1.1916666666666667,
#  1.03125,
#  1.12,
#  1.0294117647058822,
#  1.0666666666666667,
#  1.069182389937107,
#  1.1083333333333334,
#  1.037037037037037,
#  1.0043668122270741,
#  1.0,
#  1.0,
#  1.04,
#  1.036,
#  1.0833333333333333,
#  1.0112359550561798,
#  1.0,
#  1.004566210045662,
#  1.0692307692307692,
#  1.0784313725490196,
#  1.0714285714285714,
#  1.00625,
#  1.288888888888889,
#  1.0,
#  1.2083333333333333,
#  1.0416666666666667,
#  1.0826086956521739,
#  1.0692307692307692,
#  1.0391304347826087,
#  1.0217391304347827,
#  1.0294117647058822,
#  1.0,
#  1.1214953271028036,
#  1.004566210045662,
#  1.0,
#  5.475,
#  1.0,
#  1.0,
#  1.0333333333333334,
#  1.047486033519553,
#  1.0,
#  1.045,
#  1.0666666666666667,
#  1.065625,
#  1.0692307692307692,
#  1.0294117647058822,
#  1.1333333333333333,
#  1.0,
#  1.103448275862069,
#  1.08,
#  1.125,
#  1.0,
#  1.0294117647058822,
#  1.0473684210526315,
#  1.0925925925925926,
#  1.0266666666666666,
#  1.0740740740740742,
#  1.0434782608695652,
#  1.0,
#  1.0,
#  1.02,
#  1.0,
#  1.1538461538461537,
#  1.0196078431372548,
#  1.0186666666666666,
#  1.55,
#  1.032258064516129,
#  1.0666666666666667,
#  1.0,
#  1.0240963855421688,
#  1.0058823529411764,
#  1.0,
#  1.0,
#  1.08,
#  1.075,
#  1.1904761904761905,
#  1.0,
#  1.1111111111111112,
#  1.0084033613445378,
#  1.037037037037037,
#  1.0769230769230769,
#  1.0666666666666667,
#  1.0,
#  1.0947619047619048,
#  1.4705882352941178,
#  1.04,
#  1.0,
#  1.1055276381909547,
#  1.0153846153846153,
#  1.0214285714285714,
#  1.2539184952978057,
#  1.0909090909090908,
#  1.1111111111111112,
#  1.9,
#  1.085972850678733,
#  1.1805555555555556,
#  1.0526315789473684,
#  1.0529411764705883,
#  1.069182389937107]

# %%
townhome1['check1'] = check1
townhome1['check2'] = check2
townhome1
# Out:
# <ipython-input-84-02563dc6de27>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   townhome1['check1'] = check1
# <ipython-input-84-02563dc6de27>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   townhome1['check2'] = check2
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 1      https://nayoo.co/khonkaen/posts/548     1045000   700000.0  1500000.0
# 3      https://nayoo.co/khonkaen/posts/549      935000   700000.0  1500000.0
# 5      https://nayoo.co/khonkaen/posts/579     2520000  3500000.0  4000000.0
# 7      https://nayoo.co/khonkaen/posts/580     3850000  3500000.0  3200000.0
# 9      https://nayoo.co/khonkaen/posts/582      544000  1000000.0   800000.0
# ..                                     ...         ...        ...        ...
# 235  https://nayoo.co/khonkaen/posts/18547     1105000  1000000.0  1200000.0
# 236  https://nayoo.co/khonkaen/posts/18551     1440000  1500000.0  1700000.0
# 237  https://nayoo.co/khonkaen/posts/19434     2000000  1600000.0  1900000.0
# 238  https://nayoo.co/khonkaen/posts/19501     1790000  1600000.0  1700000.0
# 239  https://nayoo.co/khonkaen/posts/20367     1590000  1700000.0  1700000.0
#
#        check1    check2
# 1    1.492857  1.435407
# 3    1.335714  1.604278
# 5    1.388889  1.587302
# 7    1.100000  1.203125
# 9    1.838235  1.470588
# ..        ...       ...
# 235  1.105000  1.085973
# 236  1.041667  1.180556
# 237  1.250000  1.052632
# 238  1.118750  1.052941
# 239  1.069182  1.069182
#
# [120 rows x 6 columns]

# %%
townhome1.sort_values(by=['check1'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 176   https://nayoo.co/khonkaen/posts/3528     2190000   350000.0   400000.0
# 9      https://nayoo.co/khonkaen/posts/582      544000  1000000.0   800000.0
# 206  https://nayoo.co/khonkaen/posts/17507     1085000   650000.0   700000.0
# 216  https://nayoo.co/khonkaen/posts/17535      840000  1300000.0  1000000.0
# 1      https://nayoo.co/khonkaen/posts/548     1045000   700000.0  1500000.0
# ..                                     ...         ...        ...        ...
# 162   https://nayoo.co/khonkaen/posts/2242     1610000  1600000.0  1600000.0
# 228  https://nayoo.co/khonkaen/posts/17923     1990000  2000000.0  2200000.0
# 167   https://nayoo.co/khonkaen/posts/2829     2490000  2500000.0  2300000.0
# 200  https://nayoo.co/khonkaen/posts/13411     3200000  3200000.0  3200000.0
# 203  https://nayoo.co/khonkaen/posts/17503     1500000  1500000.0  1300000.0
#
#        check1    check2
# 176  6.257143  5.475000
# 9    1.838235  1.470588
# 206  1.669231  1.550000
# 216  1.547619  1.190476
# 1    1.492857  1.435407
# ..        ...       ...
# 162  1.006250  1.006250
# 228  1.005025  1.105528
# 167  1.004016  1.082609
# 200  1.000000  1.000000
# 203  1.000000  1.153846
#
# [120 rows x 6 columns]

# %%
townhome1.sort_values(by=['check2'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 176   https://nayoo.co/khonkaen/posts/3528     2190000   350000.0   400000.0
# 234  https://nayoo.co/khonkaen/posts/18090     2850000  2800000.0  1500000.0
# 3      https://nayoo.co/khonkaen/posts/549      935000   700000.0  1500000.0
# 5      https://nayoo.co/khonkaen/posts/579     2520000  3500000.0  4000000.0
# 206  https://nayoo.co/khonkaen/posts/17507     1085000   650000.0   700000.0
# ..                                     ...         ...        ...        ...
# 202  https://nayoo.co/khonkaen/posts/15111     2200000  2500000.0  2200000.0
# 209  https://nayoo.co/khonkaen/posts/17511     1700000  1500000.0  1700000.0
# 212  https://nayoo.co/khonkaen/posts/17516     1800000  1700000.0  1800000.0
# 213  https://nayoo.co/khonkaen/posts/17518     1200000  1100000.0  1200000.0
# 152   https://nayoo.co/khonkaen/posts/2011     1100000   900000.0  1100000.0
#
#        check1    check2
# 176  6.257143  5.475000
# 234  1.017857  1.900000
# 3    1.335714  1.604278
# 5    1.388889  1.587302
# 206  1.669231  1.550000
# ..        ...       ...
# 202  1.136364  1.000000
# 209  1.133333  1.000000
# 212  1.058824  1.000000
# 213  1.090909  1.000000
# 152  1.222222  1.000000
#
# [120 rows x 6 columns]

# %% [markdown]
# ## อาคารพาณิชย์

# %%
commercial1 = est2_commercial[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2']]
commercial1
# Out:
#                                   post id  ราคาทรัพย์    ประเมิน1    ประเมิน2
# 1       https://nayoo.co/khonkaen/posts/6     6600000   6000000.0   8000000.0
# 3      https://nayoo.co/khonkaen/posts/17    11400000  12000000.0  12000000.0
# 5      https://nayoo.co/khonkaen/posts/21    22500000  13500000.0  20000000.0
# 7      https://nayoo.co/khonkaen/posts/22     3500000   4000000.0   4000000.0
# 9      https://nayoo.co/khonkaen/posts/24     3900000   2200000.0   3000000.0
# ..                                    ...         ...         ...         ...
# 191  https://nayoo.co/khonkaen/posts/7137     3900000   3600000.0   4000000.0
# 193  https://nayoo.co/khonkaen/posts/7138     4500000   2300000.0         NaN
# 195  https://nayoo.co/khonkaen/posts/7439     6900000   3300000.0         NaN
# 197  https://nayoo.co/khonkaen/posts/7668    12000000   1500000.0         NaN
# 199  https://nayoo.co/khonkaen/posts/7705     2200000   2500000.0   2000000.0
#
# [100 rows x 4 columns]

# %%
check1 = list()
for row in commercial1.iterrows():
  check1.append(check(row[1]['ราคาทรัพย์'],row[1]['ประเมิน1']))
check1
# Out:
# [1.1,
#  1.0526315789473684,
#  1.6666666666666667,
#  1.1428571428571428,
#  1.7727272727272727,
#  1.3333333333333333,
#  1.0869565217391304,
#  1.105263157894737,
#  1.0,
#  1.075,
#  1.0330578512396693,
#  1.1,
#  1.0101010101010102,
#  1.1,
#  1.1611111111111112,
#  1.2833333333333334,
#  1.2999411764705882,
#  1.023391812865497,
#  1.0256410256410255,
#  1.0048076923076923,
#  1.083076923076923,
#  1.1,
#  1.02880658436214,
#  1.0227272727272727,
#  1.3095238095238095,
#  1.2839506172839505,
#  1.0153846153846153,
#  1.0227272727272727,
#  1.1366666666666667,
#  1.1366666666666667,
#  1.0047846889952152,
#  1.0371401902109394,
#  1.0,
#  1.120625,
#  1.0671936758893281,
#  1.0266666666666666,
#  1.034,
#  1.0421052631578946,
#  1.0476190476190477,
#  1.0214285714285714,
#  1.4025974025974026,
#  1.0526315789473684,
#  1.1511627906976745,
#  1.5172413793103448,
#  1.1363636363636365,
#  1.064516129032258,
#  1.1297297297297297,
#  1.04875,
#  1.3333333333333333,
#  1.0833333333333333,
#  1.08,
#  1.1176470588235294,
#  1.0285714285714285,
#  1.3333333333333333,
#  1.0294117647058822,
#  1.24999975,
#  1.15,
#  1.0833333333333333,
#  1.0144927536231885,
#  1.1764705882352942,
#  1.25,
#  1.0476190476190477,
#  1.25,
#  1.3157894736842106,
#  1.2072434607645874,
#  1.2953367875647668,
#  1.09375,
#  1.0483870967741935,
#  1.0666666666666667,
#  1.0666666666666667,
#  1.0714285714285714,
#  1.1343283582089552,
#  1.1666666666666667,
#  1.0576923076923077,
#  1.04,
#  1.03125,
#  1.1111111111111112,
#  1.050377358490566,
#  1.05,
#  1.1,
#  1.0,
#  1.2,
#  1.098901098901099,
#  1.0047846889952152,
#  1.5625,
#  1.08359133126935,
#  1.1,
#  1.1111111111111112,
#  1.0,
#  1.0416666666666667,
#  1.2039903680770554,
#  1.1312217194570136,
#  1.013421052631579,
#  1.065625,
#  1.1363636363636365,
#  1.0833333333333333,
#  1.9565217391304348,
#  2.090909090909091,
#  8.0,
#  1.1363636363636365]

# %%
check2 = list()
for row in commercial1.iterrows():
  check2.append(check(row[1]['ราคาทรัพย์'],row[1]['ประเมิน2']))
check2
# Out:
# [1.2121212121212122,
#  1.0526315789473684,
#  1.125,
#  1.1428571428571428,
#  1.3,
#  1.2,
#  1.0952380952380953,
#  1.1904761904761905,
#  1.1428571428571428,
#  1.1627906976744187,
#  1.0330578512396693,
#  1.134375,
#  1.1,
#  1.0576923076923077,
#  1.0047846889952152,
#  1.2833333333333334,
#  1.0860219919453369,
#  1.023391812865497,
#  1.0256410256410255,
#  1.1117021276595744,
#  1.0057142857142858,
#  1.2222222222222223,
#  1.02880658436214,
#  1.1733333333333333,
#  1.3888888888888888,
#  1.0125,
#  1.32,
#  1.0227272727272727,
#  1.0263929618768328,
#  1.0263929618768328,
#  1.0047846889952152,
#  1.21,
#  1.1,
#  1.0245714285714285,
#  1.0671936758893281,
#  1.0266666666666666,
#  1.175,
#  1.0606060606060606,
#  1.0227272727272727,
#  1.0214285714285714,
#  1.0389610389610389,
#  1.0526315789473684,
#  1.0101010101010102,
#  2.206896551724138,
#  1.0389610389610389,
#  1.1,
#  1.0047846889952152,
#  nan,
#  nan,
#  1.0833333333333333,
#  1.0,
#  1.0526315789473684,
#  1.09375,
#  1.0,
#  1.0,
#  1.00000020000004,
#  1.0144927536231885,
#  1.3,
#  1.0144927536231885,
#  1.1764705882352942,
#  1.0,
#  1.05,
#  1.0795454545454546,
#  1.0,
#  1.1670020120724347,
#  1.0157894736842106,
#  1.0666666666666667,
#  1.015625,
#  1.09375,
#  1.0666666666666667,
#  1.0,
#  1.046875,
#  1.25,
#  1.04,
#  1.1142857142857143,
#  nan,
#  1.0285714285714285,
#  nan,
#  nan,
#  1.0214285714285714,
#  2.0,
#  2.2222222222222223,
#  1.098901098901099,
#  1.0047846889952152,
#  1.3392857142857142,
#  1.009375,
#  1.1,
#  1.1111111111111112,
#  1.0,
#  1.1111111111111112,
#  1.1007911936704506,
#  1.0180995475113122,
#  1.038691249026227,
#  1.0263929618768328,
#  nan,
#  1.0256410256410255,
#  nan,
#  nan,
#  nan,
#  1.1]

# %%
commercial1['check1'] = check1
commercial1['check2'] = check2
commercial1
# Out:
# <ipython-input-90-fe3914ca23b2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commercial1['check1'] = check1
# <ipython-input-90-fe3914ca23b2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commercial1['check2'] = check2
#                                   post id  ราคาทรัพย์    ประเมิน1    ประเมิน2  \
# 1       https://nayoo.co/khonkaen/posts/6     6600000   6000000.0   8000000.0
# 3      https://nayoo.co/khonkaen/posts/17    11400000  12000000.0  12000000.0
# 5      https://nayoo.co/khonkaen/posts/21    22500000  13500000.0  20000000.0
# 7      https://nayoo.co/khonkaen/posts/22     3500000   4000000.0   4000000.0
# 9      https://nayoo.co/khonkaen/posts/24     3900000   2200000.0   3000000.0
# ..                                    ...         ...         ...         ...
# 191  https://nayoo.co/khonkaen/posts/7137     3900000   3600000.0   4000000.0
# 193  https://nayoo.co/khonkaen/posts/7138     4500000   2300000.0         NaN
# 195  https://nayoo.co/khonkaen/posts/7439     6900000   3300000.0         NaN
# 197  https://nayoo.co/khonkaen/posts/7668    12000000   1500000.0         NaN
# 199  https://nayoo.co/khonkaen/posts/7705     2200000   2500000.0   2000000.0
#
#        check1    check2
# 1    1.100000  1.212121
# 3    1.052632  1.052632
# 5    1.666667  1.125000
# 7    1.142857  1.142857
# 9    1.772727  1.300000
# ..        ...       ...
# 191  1.083333  1.025641
# 193  1.956522       NaN
# 195  2.090909       NaN
# 197  8.000000       NaN
# 199  1.136364  1.100000
#
# [100 rows x 6 columns]

# %%
commercial1.sort_values(by=['check1'],ascending=False)
# Out:
#                                   post id  ราคาทรัพย์    ประเมิน1    ประเมิน2  \
# 197  https://nayoo.co/khonkaen/posts/7668    12000000   1500000.0         NaN
# 195  https://nayoo.co/khonkaen/posts/7439     6900000   3300000.0         NaN
# 193  https://nayoo.co/khonkaen/posts/7138     4500000   2300000.0         NaN
# 9      https://nayoo.co/khonkaen/posts/24     3900000   2200000.0   3000000.0
# 5      https://nayoo.co/khonkaen/posts/21    22500000  13500000.0  20000000.0
# ..                                    ...         ...         ...         ...
# 61    https://nayoo.co/khonkaen/posts/643     4180000   4200000.0   4200000.0
# 177  https://nayoo.co/khonkaen/posts/6123     2200000   2200000.0   2200000.0
# 161  https://nayoo.co/khonkaen/posts/5995     3000000   3000000.0   6000000.0
# 65    https://nayoo.co/khonkaen/posts/651     2200000   2200000.0   2000000.0
# 17    https://nayoo.co/khonkaen/posts/498     7000000   7000000.0   8000000.0
#
#        check1    check2
# 197  8.000000       NaN
# 195  2.090909       NaN
# 193  1.956522       NaN
# 9    1.772727  1.300000
# 5    1.666667  1.125000
# ..        ...       ...
# 61   1.004785  1.004785
# 177  1.000000  1.000000
# 161  1.000000  2.000000
# 65   1.000000  1.100000
# 17   1.000000  1.142857
#
# [100 rows x 6 columns]

# %%
commercial1.sort_values(by=['check2'],ascending=False)
# Out:
#                                   post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 163  https://nayoo.co/khonkaen/posts/6009     2250000  2700000.0  5000000.0
# 87    https://nayoo.co/khonkaen/posts/707     1450000  2200000.0  3200000.0
# 161  https://nayoo.co/khonkaen/posts/5995     3000000  3000000.0  6000000.0
# 49    https://nayoo.co/khonkaen/posts/602     2520000  3300000.0  3500000.0
# 169  https://nayoo.co/khonkaen/posts/6043     2240000  3500000.0  3000000.0
# ..                                    ...         ...        ...        ...
# 157  https://nayoo.co/khonkaen/posts/3898     4200000  4000000.0        NaN
# 189  https://nayoo.co/khonkaen/posts/6354     2200000  2500000.0        NaN
# 193  https://nayoo.co/khonkaen/posts/7138     4500000  2300000.0        NaN
# 195  https://nayoo.co/khonkaen/posts/7439     6900000  3300000.0        NaN
# 197  https://nayoo.co/khonkaen/posts/7668    12000000  1500000.0        NaN
#
#        check1    check2
# 163  1.200000  2.222222
# 87   1.517241  2.206897
# 161  1.000000  2.000000
# 49   1.309524  1.388889
# 169  1.562500  1.339286
# ..        ...       ...
# 157  1.050000       NaN
# 189  1.136364       NaN
# 193  1.956522       NaN
# 195  2.090909       NaN
# 197  8.000000       NaN
#
# [100 rows x 6 columns]

# %% [markdown]
# # HW2 แก้ไข ข้อมูลแล้วคำนวณ MAPE ใหม่อีกรอบมาเทียบกัน

# %%
link = 'https://docs.google.com/spreadsheets/d/1xOUyJLF4NZTDkYCDTIj5bCuumi6d5ZnQT7-e7LpEe4o/export?format=xlsx'
link2 = 'https://docs.google.com/spreadsheets/d/16T7fGzEHtsY-qEb5JikQyNkL57EzuRChAUIFY6iQ0RI/export?format=xlsx'

# %% [markdown]
# ##บ้านเดี่ยว

# %%
#ก่อนแก้
house = pd.read_excel(link,sheet_name='บ้าน')
id1 = house[house['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id2 = house[house['ID ผู้ประเมิน']==2]
id2 = id2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = mape(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
id2MAPE = mape(id2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nบ้าน\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id2MAPE*100:.2f}%')
id2['ประเมิน2'] = id2['post id'].map(id1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_d = id2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# บ้าน
# นักประเมิน คนที่ 1 = 14.50%
# นักประเมิน คนที่ 2 = 11.14%

# %%
#หลังแก้
house2 = pd.read_excel(link2,sheet_name='บ้าน')
id1 = house2[house2['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id2 = house2[house2['ID ผู้ประเมิน']==2]
id2 = id2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = mape(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
id2MAPE = mape(id2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nบ้าน\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id2MAPE*100:.2f}%')
id2['ประเมิน2'] = id2['post id'].map(id1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_d = id2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# บ้าน
# นักประเมิน คนที่ 1 = 11.67%
# นักประเมิน คนที่ 2 = 9.08%

# %% [markdown]
# ##ที่ดิน

# %%
#ก่อนแก้
land = pd.read_excel(link,sheet_name='ที่ดิน')
id12 = land[land['ID ผู้ประเมิน']==1]
id12 = id12.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id22 = land[land['ID ผู้ประเมิน']==2]
id22 = id22.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id12MAPE = mape(id12['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id12['ราคาทรัพย์']))
id22MAPE = mape(id22['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id22['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nที่ดิน\nนักประเมิน คนที่ 1 = {id12MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id22MAPE*100:.2f}%')
id22['ประเมิน2'] = id22['post id'].map(id12.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id22_d = id22.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ที่ดิน
# นักประเมิน คนที่ 1 = 79.74%
# นักประเมิน คนที่ 2 = 43.70%

# %%
#หลังแก้
land2 = pd.read_excel(link2,sheet_name='ที่ดิน')
id12 = land2[land2['ID ผู้ประเมิน']==1]
id12 = id12.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id22 = land2[land2['ID ผู้ประเมิน']==2]
id22 = id22.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id12MAPE = mape(id12['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id12['ราคาทรัพย์']))
id22MAPE = mape(id22['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id22['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nที่ดิน\nนักประเมิน คนที่ 1 = {id12MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id22MAPE*100:.2f}%')
id22['ประเมิน2'] = id22['post id'].map(id12.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id22_d = id22.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ที่ดิน
# นักประเมิน คนที่ 1 = 44.82%
# นักประเมิน คนที่ 2 = 19.78%

# %% [markdown]
# ## ทาวน์โฮม

# %%
#ก่อนแก้
townhome = pd.read_excel(link,sheet_name='ทาวน์โฮม')
id13 = townhome[townhome['ID ผู้ประเมิน']==1]
id13 = id13.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id23 = townhome[townhome['ID ผู้ประเมิน']==2]
id23 = id23.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id13MAPE = mape(id13['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id13['ราคาทรัพย์']))
id23MAPE = mape(id23['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id23['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nทาวน์โฮม\nนักประเมิน คนที่ 1 = {id13MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id23MAPE*100:.2f}%')
id23['ประเมิน2'] = id23['post id'].map(id13.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id23_d = id23.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ทาวน์โฮม
# นักประเมิน คนที่ 1 = 15.26%
# นักประเมิน คนที่ 2 = 12.20%

# %%
#หลังแก้
townhome2 = pd.read_excel(link2,sheet_name='ทาวน์โฮม')
id13 = townhome2[townhome2['ID ผู้ประเมิน']==1]
id13 = id13.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id23 = townhome2[townhome2['ID ผู้ประเมิน']==2]
id23 = id23.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id13MAPE = mape(id13['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id13['ราคาทรัพย์']))
id23MAPE = mape(id23['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id23['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nทาวน์โฮม\nนักประเมิน คนที่ 1 = {id13MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id23MAPE*100:.2f}%')
id23['ประเมิน2'] = id23['post id'].map(id13.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id23_d = id23.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ทาวน์โฮม
# นักประเมิน คนที่ 1 = 11.19%
# นักประเมิน คนที่ 2 = 8.85%

# %% [markdown]
# ## อาคารพาณิชย์

# %%
#ก่อนแก้
commercial = pd.read_excel(link,sheet_name='อาคารพาณิชย์')
id14 = commercial[commercial['ID ผู้ประเมิน']==1]
id14 = id14.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id24 = commercial[commercial['ID ผู้ประเมิน']==2]
id24 = id24.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id14MAPE = mape(id14['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id14['ราคาทรัพย์']))
id24MAPE = mape(id24['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id24['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nอาคารพาณิชย์\nนักประเมิน คนที่ 1 = {id14MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id24MAPE*100:.2f}%')
id24['ประเมิน2'] = id24['post id'].map(id14.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id24_d = id24.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# อาคารพาณิชย์
# นักประเมิน คนที่ 1 = 20.25%
# นักประเมิน คนที่ 2 = 9.49%

# %%
#หลังแก้
commercial2 = pd.read_excel(link2,sheet_name='อาคารพาณิชย์')
id14 = commercial2[commercial2['ID ผู้ประเมิน']==1]
id14 = id14.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id24 = commercial2[commercial2['ID ผู้ประเมิน']==2]
id24 = id24.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id14MAPE = mape(id14['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id14['ราคาทรัพย์']))
id24MAPE = mape(id24['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id24['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nอาคารพาณิชย์\nนักประเมิน คนที่ 1 = {id14MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id24MAPE*100:.2f}%')
id24['ประเมิน2'] = id24['post id'].map(id14.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id24_d = id24.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# อาคารพาณิชย์
# นักประเมิน คนที่ 1 = 13.45%
# นักประเมิน คนที่ 2 = 9.49%

# %% [markdown]
# # HW3 visualize แสดงความสัมพันธ์ ราคา(ตั้งขายและประเมิน)-ความมั่นใจ-ให้คะแนนทรัพย์

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=[12,6]

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
house1 = est2[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2','ให้คะแนนทรัพย์','ความมั่นใจในการเมินราคาทรัพย์']]
house1
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 1       https://nayoo.co/khonkaen/posts/25     2890000  2500000.0  2700000.0
# 3       https://nayoo.co/khonkaen/posts/33     2600000  2200000.0  2400000.0
# 5      https://nayoo.co/khonkaen/posts/495     6050000  5000000.0  9000000.0
# 7      https://nayoo.co/khonkaen/posts/564     4400000  3500000.0  3700000.0
# 9      https://nayoo.co/khonkaen/posts/566     2750000  2500000.0  2500000.0
# ...                                    ...         ...        ...        ...
# 1210  https://nayoo.co/khonkaen/posts/6255      260000   550000.0   300000.0
# 1212  https://nayoo.co/khonkaen/posts/6256      610000   700000.0   500000.0
# 1214  https://nayoo.co/khonkaen/posts/6257      295000   500000.0   300000.0
# 1216  https://nayoo.co/khonkaen/posts/6258      615000   600000.0   500000.0
# 1218  https://nayoo.co/khonkaen/posts/6260      620000   750000.0   700000.0
#
#                          ให้คะแนนทรัพย์ ความมั่นใจในการเมินราคาทรัพย์
# 1      4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                        มั่นใจ
# 3     3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 5     5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน                        มั่นใจ
# 7     3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 9     3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# ...                                 ...                           ...
# 1210  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 1212  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 1214  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 1216  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 1218  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
#
# [610 rows x 6 columns]

# %%
land1 = est2[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2','ให้คะแนนทรัพย์','ความมั่นใจในการเมินราคาทรัพย์']]
land1
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 1       https://nayoo.co/khonkaen/posts/25     2890000  2500000.0  2700000.0
# 3       https://nayoo.co/khonkaen/posts/33     2600000  2200000.0  2400000.0
# 5      https://nayoo.co/khonkaen/posts/495     6050000  5000000.0  9000000.0
# 7      https://nayoo.co/khonkaen/posts/564     4400000  3500000.0  3700000.0
# 9      https://nayoo.co/khonkaen/posts/566     2750000  2500000.0  2500000.0
# ...                                    ...         ...        ...        ...
# 1210  https://nayoo.co/khonkaen/posts/6255      260000   550000.0   300000.0
# 1212  https://nayoo.co/khonkaen/posts/6256      610000   700000.0   500000.0
# 1214  https://nayoo.co/khonkaen/posts/6257      295000   500000.0   300000.0
# 1216  https://nayoo.co/khonkaen/posts/6258      615000   600000.0   500000.0
# 1218  https://nayoo.co/khonkaen/posts/6260      620000   750000.0   700000.0
#
#                          ให้คะแนนทรัพย์ ความมั่นใจในการเมินราคาทรัพย์
# 1      4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                        มั่นใจ
# 3     3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 5     5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน                        มั่นใจ
# 7     3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 9     3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# ...                                 ...                           ...
# 1210  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 1212  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 1214  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 1216  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 1218  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
#
# [610 rows x 6 columns]

# %%
townhome1 = est2_townhome[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2','ให้คะแนนทรัพย์','ความมั่นใจในการเมินราคาทรัพย์']]
townhome1
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 1      https://nayoo.co/khonkaen/posts/548     1045000   700000.0  1500000.0
# 3      https://nayoo.co/khonkaen/posts/549      935000   700000.0  1500000.0
# 5      https://nayoo.co/khonkaen/posts/579     2520000  3500000.0  4000000.0
# 7      https://nayoo.co/khonkaen/posts/580     3850000  3500000.0  3200000.0
# 9      https://nayoo.co/khonkaen/posts/582      544000  1000000.0   800000.0
# ..                                     ...         ...        ...        ...
# 235  https://nayoo.co/khonkaen/posts/18547     1105000  1000000.0  1200000.0
# 236  https://nayoo.co/khonkaen/posts/18551     1440000  1500000.0  1700000.0
# 237  https://nayoo.co/khonkaen/posts/19434     2000000  1600000.0  1900000.0
# 238  https://nayoo.co/khonkaen/posts/19501     1790000  1600000.0  1700000.0
# 239  https://nayoo.co/khonkaen/posts/20367     1590000  1700000.0  1700000.0
#
#                         ให้คะแนนทรัพย์ ความมั่นใจในการเมินราคาทรัพย์
# 1                    1 ขายไม่ได้แน่นอน                        มั่นใจ
# 3                    1 ขายไม่ได้แน่นอน                        มั่นใจ
# 5    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 7    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 9    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# ..                                 ...                           ...
# 235  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 236  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 237  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 238  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 239  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
#
# [120 rows x 6 columns]

# %%
commercial1  = est2_commercial[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2','ให้คะแนนทรัพย์','ความมั่นใจในการเมินราคาทรัพย์']]
commercial1
# Out:
#                                   post id  ราคาทรัพย์    ประเมิน1    ประเมิน2  \
# 1       https://nayoo.co/khonkaen/posts/6     6600000   6000000.0   8000000.0
# 3      https://nayoo.co/khonkaen/posts/17    11400000  12000000.0  12000000.0
# 5      https://nayoo.co/khonkaen/posts/21    22500000  13500000.0  20000000.0
# 7      https://nayoo.co/khonkaen/posts/22     3500000   4000000.0   4000000.0
# 9      https://nayoo.co/khonkaen/posts/24     3900000   2200000.0   3000000.0
# ..                                    ...         ...         ...         ...
# 191  https://nayoo.co/khonkaen/posts/7137     3900000   3600000.0   4000000.0
# 193  https://nayoo.co/khonkaen/posts/7138     4500000   2300000.0         NaN
# 195  https://nayoo.co/khonkaen/posts/7439     6900000   3300000.0         NaN
# 197  https://nayoo.co/khonkaen/posts/7668    12000000   1500000.0         NaN
# 199  https://nayoo.co/khonkaen/posts/7705     2200000   2500000.0   2000000.0
#
#                          ให้คะแนนทรัพย์ ความมั่นใจในการเมินราคาทรัพย์
# 1      4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                        มั่นใจ
# 3    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี                        มั่นใจ
# 5     3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 7      4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                        มั่นใจ
# 9    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี                        มั่นใจ
# ..                                  ...                           ...
# 191   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 193                                 NaN                     ไม่มั่นใจ
# 195                                 NaN                     ไม่มั่นใจ
# 197                                 NaN                     ไม่มั่นใจ
# 199   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
#
# [100 rows x 6 columns]

# %%
#house1.head(10)

# %%
house11 = house1.head(10).sort_values('ราคาทรัพย์', ascending=False)
house11
# Out:
#                                 post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 17  https://nayoo.co/khonkaen/posts/634    10263000  7500000.0  9000000.0
# 5   https://nayoo.co/khonkaen/posts/495     6050000  5000000.0  9000000.0
# 11  https://nayoo.co/khonkaen/posts/568     5720000  4500000.0  5900000.0
# 13  https://nayoo.co/khonkaen/posts/597     5712000  4200000.0  6000000.0
# 15  https://nayoo.co/khonkaen/posts/624     5280000  5200000.0  5500000.0
# 7   https://nayoo.co/khonkaen/posts/564     4400000  3500000.0  3700000.0
# 19  https://nayoo.co/khonkaen/posts/656     4070000  4200000.0  4000000.0
# 1    https://nayoo.co/khonkaen/posts/25     2890000  2500000.0  2700000.0
# 9   https://nayoo.co/khonkaen/posts/566     2750000  2500000.0  2500000.0
# 3    https://nayoo.co/khonkaen/posts/33     2600000  2200000.0  2400000.0
#
#                         ให้คะแนนทรัพย์ ความมั่นใจในการเมินราคาทรัพย์
# 17  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี                        มั่นใจ
# 5    5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน                        มั่นใจ
# 11   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 13    4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                        มั่นใจ
# 15    4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                        มั่นใจ
# 7    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 19   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 1     4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                        มั่นใจ
# 9    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ
# 3    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                        มั่นใจ

# %% [markdown]
# ###ความสัมพันธ์ของราคาตั้งขายและราคาประเมิน

# %% [markdown]
# ####ลอง Histrogram

# %%
house1.plot(kind="hist", x = 'post id')
plt.title('บ้าน' ,fontsize = 20,)
plt.xlabel('post id')
plt.ylabel('ราคาประเมิน')
plt.show()

# %% [markdown]
# ##ความสัมพันธ์ของราคาตั้งขายและราคาประเมิน

# %%
mpl.rcParams['figure.figsize']=[15,10]
plt.suptitle('ความสัมพันธ์ของราคาทรัพย์และราคาประเมิน',fontsize = 30)


house1.plot(kind="line", x = 'post id') 
plt.title('บ้าน' ,fontsize = 20,)
plt.xlabel('post id')
plt.ylabel('ราคาประเมิน')
plt.legend(loc='upper right' ,fontsize = 15)
#plt.show()

land1.plot(kind="line", x = 'post id') 
plt.title('ที่ดิน',fontsize = 20,)
plt.xlabel('post id')
plt.ylabel('ราคาประเมิน')
plt.legend(loc='upper right' ,fontsize = 15)
#plt.show()


townhome1.plot(kind="line", x = 'post id')
plt.title('ทาวน์โฮม',fontsize = 20,)
plt.xlabel('post id')
plt.ylabel('ราคาประเมิน')
plt.legend(loc='upper right' ,fontsize = 15)
#plt.show()


commercial1.plot(kind="line", x = 'post id')
plt.title('อาคารพาณิชย์',fontsize = 20)
plt.xlabel('post id')
plt.ylabel('ราคาประเมิน')
plt.legend(loc='upper right' ,fontsize = 15)
#plt.show()

# %% [markdown]
# ##ความมั่นใจในการเมินราคาทรัพย์

# %%
from matplotlib import pyplot

# %%
import numpy as np
import pandas as pd  #import pandas มาเพราะข้อมูลจะเกี่ยวกับตาราง

import matplotlib.pyplot as plt
from math import pi #import math มาเนื่องจากเกี่ยวกับวงกลมนำมาใช้เพื่อดึงค่าพาย คำนวณว่าแต่ละส่วนของdataจะทำมุมเท่าไหร่

# %%
house1[house1['ความมั่นใจในการเมินราคาทรัพย์']== 'ไม่มั่นใจ'].count()
# Out:
# post id                          111
# ราคาทรัพย์                       111
# ประเมิน1                         104
# ประเมิน2                           0
# ให้คะแนนทรัพย์                     0
# ความมั่นใจในการเมินราคาทรัพย์    111
# dtype: int64

# %%
house1[house1['ความมั่นใจในการเมินราคาทรัพย์']== 'มั่นใจ'].count()
# Out:
# post id                          499
# ราคาทรัพย์                       499
# ประเมิน1                         432
# ประเมิน2                         433
# ให้คะแนนทรัพย์                   499
# ความมั่นใจในการเมินราคาทรัพย์    499
# dtype: int64

# %%
import matplotlib.pyplot as plt
colors = ['tab:blue', 'tab:red']
mpl.rcParams['figure.figsize']=[15,10]

plt.suptitle('ความมั่นใจในการประเมินราคาทรัพย์',fontsize = 25)


plt.subplot(2,2,1)
plt.title('ความมั่นใจในการประเมินราคาทรัพย์_บ้าน' ,fontsize = 15)
house_type = ['มั่นใจ', 'ไม่มั่นใจ']
house_count = [499,111]

plt.pie(house_count, labels=house_type, autopct='%.2f%%', pctdistance=0.6)
#plt.show()

plt.subplot(2,2,2)
plt.title('ความมั่นใจในการประเมินราคาทรัพย์_ที่ดิน',fontsize = 15)
land_type = ['มั่นใจ']
land_count = [100]

plt.pie(land_count, labels=land_type, autopct='%.2f%%', pctdistance=0.05);
#plt.show()

plt.subplot(2,2,3)
plt.title('ความมั่นใจในการประเมินราคาทรัพย์_ทาวน์โฮม' ,fontsize = 15)
townhome_type = ['มั่นใจ'];
townhome_count = [120]

plt.pie(townhome_count, labels=townhome_type, autopct='%.2f%%', pctdistance=0.05);
#plt.show()

plt.subplot(2,2,4)
plt.title('ความมั่นใจในการประเมินราคาทรัพย์_อาคารพาณิชย์' ,fontsize = 15)
commercial_type = ['มั่นใจ', 'ไม่มั่นใจ'];
commercial_count = [91,9]

plt.pie(commercial_count, labels=commercial_type, autopct='%.2f%%', pctdistance=0.6);
#plt.show()

# %%
import seaborn as sns

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ##ให้คะแนนทรัพย์วิธีที่ 1

# %% [markdown]
# ###บ้าน

# %%
house1 = est2[(est2['ให้คะแนนทรัพย์']=='5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน') | (est2['ให้คะแนนทรัพย์']=='4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน') | (est2['ให้คะแนนทรัพย์']=='3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน') | (est2['ให้คะแนนทรัพย์']=='2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี') | (est2['ให้คะแนนทรัพย์']=='1 ขายไม่ได้แน่นอน')]
house1.groupby('ให้คะแนนทรัพย์').count()
# Out:
#                                     ID ผู้ประเมิน  post id  property_type  \
# ให้คะแนนทรัพย์
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี             14       14             14
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน             367      367            367
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน              117      117            117
# 5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน               1        1              1
#
#                                     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  \
# ให้คะแนนทรัพย์
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี                             14          14
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                             367         367
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                              117         117
# 5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน                               1           1
#
#                                     ประเมินราคาซื้อ-ขาย  \
# ให้คะแนนทรัพย์
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี                   14
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                   366
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                    117
# 5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน                     1
#
#                                     ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# ให้คะแนนทรัพย์
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี                              14
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                              367
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                               117
# 5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน                                1
#
#                                     เหตุผลไม่มั่นใจราคาประเมิน  ประเมิน1  \
# ให้คะแนนทรัพย์
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี                           0        13
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                            1       316
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                             0       102
# 5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน                            0         1
#
#                                     ประเมิน2
# ให้คะแนนทรัพย์
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี        14
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน        317
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         101
# 5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน          1

# %%
house1.plot.scatter(x='ให้คะแนนทรัพย์', y='ราคาทรัพย์')

# %% [markdown]
# ###ที่ดิน

# %%
land1 = est2_land[(est2_land['ให้คะแนนทรัพย์']=='5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน') | (est2_land['ให้คะแนนทรัพย์']=='4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน') | (est2_land['ให้คะแนนทรัพย์']=='3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน') | (est2_land['ให้คะแนนทรัพย์']=='2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี') | (est2_land['ให้คะแนนทรัพย์']=='1 ขายไม่ได้แน่นอน')]
land1.groupby('ให้คะแนนทรัพย์').count()
land1.plot.scatter(x='ให้คะแนนทรัพย์', y='ราคาทรัพย์')

# %% [markdown]
# ###ทาวน์โฮม

# %%
townhome1 = est2_townhome[(est2_townhome['ให้คะแนนทรัพย์']=='5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน') | (est2_townhome['ให้คะแนนทรัพย์']=='4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน') | (est2_townhome['ให้คะแนนทรัพย์']=='3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน') | (est2_townhome['ให้คะแนนทรัพย์']=='2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี') | (est2_townhome['ให้คะแนนทรัพย์']=='1 ขายไม่ได้แน่นอน')]
townhome1.groupby('ให้คะแนนทรัพย์').count()
townhome1.plot.scatter(x='ให้คะแนนทรัพย์', y='ราคาทรัพย์')

# %% [markdown]
# ###อาคารพาณิชย์

# %%
commercial1 = est2_commercial[(est2_commercial['ให้คะแนนทรัพย์']=='5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน') | (est2_commercial['ให้คะแนนทรัพย์']=='4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน') | (est2_commercial['ให้คะแนนทรัพย์']=='3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน') | (est2_commercial['ให้คะแนนทรัพย์']=='2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี') | (est2_commercial['ให้คะแนนทรัพย์']=='1 ขายไม่ได้แน่นอน')]
commercial1.groupby('ให้คะแนนทรัพย์').count()
commercial1.plot.scatter(x='ให้คะแนนทรัพย์', y='ราคาทรัพย์')

# %% [markdown]
# ####รวม เรียงตามลำดับ บ้าน ที่ดิน ทาวน์โฮม อาคารพาณิชย์

# %%
mpl.rcParams['figure.figsize']=[10,10]

house1.plot.scatter(x='ให้คะแนนทรัพย์', y='ราคาทรัพย์')

land1.plot.scatter(x='ให้คะแนนทรัพย์', y='ราคาทรัพย์')

townhome1.plot.scatter(x='ให้คะแนนทรัพย์', y='ราคาทรัพย์')

commercial1.plot.scatter(x='ให้คะแนนทรัพย์', y='ราคาทรัพย์')

# %% [markdown]
# ##ให้คะแนนทรัพย์วิธีที่ 2

# %% [markdown]
# ###ให้คะแนนทรัพย์ บ้าน

# %% [markdown]
# https://www.bluebirz.net/th/note-of-data-science-training-ep-3-th/

# %%
sns.pairplot(house1, hue='ให้คะแนนทรัพย์', diag_kind='hist')

# %% [markdown]
# ###ให้คะแนนทรัพย์ ที่ดิน

# %%
sns.pairplot(land1, hue='ให้คะแนนทรัพย์', diag_kind='hist')

# %% [markdown]
# ###ให้คะแนนทรัพย์ ทาวน์โฮม

# %%
sns.pairplot(townhome1, hue='ให้คะแนนทรัพย์', diag_kind='hist')

# %% [markdown]
# ###ให้คะแนนทรัพย์ อาคารพาณิชย์

# %%
sns.pairplot(commercial1, hue='ให้คะแนนทรัพย์', diag_kind='hist')
